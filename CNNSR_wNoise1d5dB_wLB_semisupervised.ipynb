# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.fftpack import fft, fftshift
import os
import h5py
import random as rn
import cmath as cm
from statistics import mean
from matplotlib import rcParams
from scipy.io import savemat, loadmat
import nitime.timeseries as nts
import time
from scipy.io import savemat, loadmat

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import Adam, SGD
import torch.nn.functional as func
from torch.utils.data import TensorDataset, DataLoader, random_split
import torchvision
import torchvision.transforms as transforms
from statistics import mean
from torch.nn import MSELoss, L1Loss, SmoothL1Loss
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
import warnings
from tqdm import tqdm

# %% [markdown]
# # Loading simulated dataset

# %%
# Load Simulated FIDs, which were simulated using FID-A
arrays = {}
f = h5py.File('../../Data for DL-FPC/TrainingData.mat','r')#need to add 'r' mode here to avoid warning
for k, v in f.items():
    arrays[k] = np.array(v)
FidsOFFtemp = np.transpose(arrays['OFF_fids']) 
FidsONtemp = np.transpose(arrays['ON_fids'])

FidsOFF = np.empty((len(FidsOFFtemp[:,0]), len(FidsOFFtemp[0,:])), dtype = np.complex_)
FidsON = np.empty((len(FidsONtemp[:,0]), len(FidsONtemp[0,:])), dtype = np.complex_)
for pp in range(len(FidsOFF[:,0])):
    for kk in range(len(FidsOFF[0,:])):
        FidsOFF[pp,kk] = FidsOFFtemp[pp,kk][0] + 1j * FidsOFFtemp[pp,kk][1] 
        FidsON[pp,kk] = FidsONtemp[pp,kk][0] + 1j * FidsONtemp[pp,kk][1]
     
# Concatenate OFF and ON data - Training is performed using both OFF and ON
Fids = np.concatenate((FidsOFF, FidsON), axis=1)     

# Define Offsets - Randomize 
Phs = np.arange(-90, 90.001, (180/(len(Fids[0])-1)))
F0 = np.arange(-20, 20.0000001, (40/(len(Fids[0])-1)))

# %%
# Define Line broadening magnitudes - Randomize
lb_parameter = np.arange(0, 0.0200001, (0.02/(len(Fids[0])-1)))
rn.shuffle(lb_parameter)
rn.shuffle(Phs) #Randomize
rn.shuffle(F0) #Randomize

time = np.arange(2048)/2000

def line_broadening(ts,width):
    n_dims=len(ts.shape)
    win=np.exp(-width*ts.time/np.float(ts.time._conversion_factor))
    new_data=ts.data*win
    
    return nts.TimeSeries(new_data, sampling_rate=ts.sampling_rate)

# %%
# Fids and Spec for the Unaligned data
FidsUnAligned = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)
FidsUnAlignedPhase = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)
spectUnAligned = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)
spectUnAlignedPhase = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)

# Spec for the Aligned data
spectAligned = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)
spectAlignedPhase = np.empty((len(Fids[:,0]), len(Fids[0,:])), dtype = np.complex_)

# %%
# applying LB
for kk in range(len(Fids[0,:])):
    Fids_kk = Fids[:,kk]
    
    if 18000 <= kk <= 20000 or 38000 <= kk <=  40000:
        arr=Fids_kk*np.exp(1j*np.pi)*(-1) 
        ts=nts.TimeSeries(data=arr, sampling_rate=1)
        width=lb_parameter[kk] 
    
        Fids_kk_lb=line_broadening(ts, width)
    else:
        Fids_kk_lb=Fids_kk
    
    # get the phase and freq offsets
    phasePart = np.exp(-1j * Phs[kk] * cm.pi / 180)
    freqPart = np.exp(-1j * time * F0[kk] * 2 * cm.pi)
    correction = np.multiply(freqPart,phasePart)
    
    # apply the phase and freq offsets on the FID after LB
    FidsUnAligned[:,kk] = np.multiply(Fids_kk_lb, correction) #[2048, 10000]
    FidsUnAlignedPhase[:,kk] = np.multiply(Fids_kk_lb, phasePart) #[2048, 10000]
    
    # get the single spectra of the FID with freq and phase offsets and LB 
    spectUnAligned[:,kk] = fftshift(fft(FidsUnAligned[:,kk]))
    spectUnAlignedPhase[:,kk] = fftshift(fft(FidsUnAlignedPhase[:,kk]))
    
    # get the single spectra of the FID withOUT freq and phase offsets and LB 
    spectAligned[:,kk] = fftshift(fft(Fids_kk))
    spectAlignedPhase[:,kk] = fftshift(fft(Fids_kk))
    
    # get the Normalized single spectra of the FID with freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectUnAligned[:,kk])))
    spectUnAligned[:,kk] = spectUnAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectUnAlignedPhase[:,kk])))
    spectUnAlignedPhase[:,kk] = spectUnAlignedPhase[:,kk]/scalePh
    
    # get the Normalized single spectra of the FID withOUT freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectAligned[:,kk])))
    spectAligned[:,kk] = spectAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectAlignedPhase[:,kk])))
    spectAlignedPhase[:,kk] = spectAlignedPhase[:,kk]/scalePh

# %% [markdown]
# # Preparing data for the CNN-SR model

# %%
time = np.arange(2048)/2000

# The input for the networks - 1024 points
Real_spectUnAligned = np.real(spectUnAligned[512:-512,:])
Real_spectUnAligned = np.transpose(Real_spectUnAligned) # Grey #Transpose to [numSpect 2048]

# The GT real spectra for testing figures - 2048 points
Real_spectAligned_2048 = np.real(spectAligned)
Real_spectAligned_2048 = np.transpose(Real_spectAligned_2048) # Grey #Transpose to [numSpect 2048]

# The input for the networks - 1024 points
Real_spectAligned = np.real(spectAligned[512:-512,:])
Real_spectAligned = np.transpose(Real_spectAligned) # Grey #Transpose to [numSpect 2048]

# Input (will add noise later) of the model, includes both the real spectral of the unaligned data and relevant aligned data
Real_spectUnAligned_and_spectAligned = np.concatenate([Real_spectUnAligned,Real_spectAligned],axis=1)

# The GT Fids for the networks - 2048 points
Real_FidsAligned = np.real(Fids)
Real_FidsAligned = np.transpose(Real_FidsAligned) # Red #Transpose to [numSpect 2048]
Imag_FidsAligned = np.imag(Fids)
Imag_FidsAligned = np.transpose(Imag_FidsAligned) # Red #Transpose to [numSpect 2048]

# The Complex Fids - 2048 points
Complex_FidsUnAligned = np.transpose(FidsUnAligned) # Black, will derive dark red Predicted Real Spectra
Real_FidsUnAligned = np.real(Complex_FidsUnAligned)
Imag_FidsUnAligned = np.imag(Complex_FidsUnAligned)

print('Real_spectUnAligned',Real_spectUnAligned.shape)
print('Real_spectUnAligned_and_spectAligned',Real_spectUnAligned_and_spectAligned.shape)
print('Real_FidsAligned',Real_FidsAligned.shape)
print('Real_FidsUnAligned',Real_FidsUnAligned.shape)
print('Imag_FidsUnAligned',Imag_FidsUnAligned.shape)

# Saving the data
data_path = '/media/sail/Elements/JET_CNN/DL-FPC/JETCNNmodel/data/'

# ground truth
savemat(os.path.join(data_path, "F0_DLSR_wNoise1d5dB_wLB.mat"), {"F0_DLSR_wNoise1d5dB_wLB":F0})
savemat(os.path.join(data_path, "Phs_DLSR_wNoise1d5dB_wLB.mat"), {"Phs_DLSR_wNoise1d5dB_wLB":Phs})

# spect aligned
savemat(os.path.join(data_path, "spectAligned_DLSR_wNoise1d5dB_wLB.mat"), {"spectAligned_DLSR_wNoise1d5dB_wLB":spectAligned})
savemat(os.path.join(data_path, "Real_spectAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Real_spectAligned_DLSR_wNoise1d5dB_wLB":Real_spectAligned})

# spect unaligned
savemat(os.path.join(data_path, "Real_spectUnAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Real_spectUnAligned_DLSR_wNoise1d5dB_wLB":Real_spectUnAligned})
savemat(os.path.join(data_path, "Real_spectUnAligned_and_spectAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Real_spectUnAligned_and_spectAligned_DLSR_wNoise1d5dB_wLB":Real_spectUnAligned_and_spectAligned})

# Fids Aligned
savemat(os.path.join(data_path, "FidsAligned_DLSR_wNoise1d5dB_wLB.mat"), {"FidsAligned_DLSR_wNoise1d5dB_wLB":Fids})
savemat(os.path.join(data_path, "Real_FidsAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Real_FidsAligned_DLSR_wNoise1d5dB_wLB":Real_FidsAligned})
savemat(os.path.join(data_path, "Imag_FidsAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Imag_FidsAligned_DLSR_wNoise1d5dB_wLB":Imag_FidsAligned})

#Fids Unaligned
savemat(os.path.join(data_path, "Complex_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Complex_FidsUnAligned_DLSR_wNoise1d5dB_wLB":Complex_FidsUnAligned})
savemat(os.path.join(data_path, "Real_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Real_FidsUnAligned_DLSR_wNoise1d5dB_wLB":Real_FidsUnAligned})
savemat(os.path.join(data_path, "Imag_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"), {"Imag_FidsUnAligned_DLSR_wNoise1d5dB_wLB":Imag_FidsUnAligned})
# Out:
# Real_spectUnAligned (40000, 1024)
# Real_spectUnAligned_and_spectAligned (40000, 2048)
# Real_FidsAligned (40000, 2048)
# Real_FidsUnAligned (40000, 2048)
# Imag_FidsUnAligned (40000, 2048)

# %%
# Load the data
data_path = '/media/sail/Elements/JET_CNN/DL-FPC/JETCNNmodel/data/'

# ground truth
F0 = loadmat(os.path.join(data_path, "F0_DLSR_wNoise1d5dB_wLB.mat"))["F0_DLSR_wNoise1d5dB_wLB"]
Phs = loadmat(os.path.join(data_path, "Phs_DLSR_wNoise1d5dB_wLB.mat"))["Phs_DLSR_wNoise1d5dB_wLB"]

# spect aligned
spectAligned = loadmat(os.path.join(data_path, "spectAligned_DLSR_wNoise1d5dB_wLB.mat"))["spectAligned_DLSR_wNoise1d5dB_wLB"]
Real_spectAligned = loadmat(os.path.join(data_path, "Real_spectAligned_DLSR_wNoise1d5dB_wLB.mat"))["Real_spectAligned_DLSR_wNoise1d5dB_wLB"]

# spect unaligned
Real_spectUnAligned = loadmat(os.path.join(data_path, "Real_spectUnAligned_DLSR_wNoise1d5dB_wLB.mat")) ["Real_spectUnAligned_DLSR_wNoise1d5dB_wLB"]
Real_spectUnAligned_and_spectAligned = loadmat(os.path.join(data_path, "Real_spectUnAligned_and_spectAligned_DLSR_wNoise1d5dB_wLB.mat"))["Real_spectUnAligned_and_spectAligned_DLSR_wNoise1d5dB_wLB"]

# Fids Aligned
Fids = loadmat(os.path.join(data_path, "FidsAligned_DLSR_wNoise1d5dB_wLB.mat"))["FidsAligned_DLSR_wNoise1d5dB_wLB"]
Real_FidsAligned = loadmat(os.path.join(data_path, "Real_FidsAligned_DLSR_wNoise1d5dB_wLB.mat"))["Real_FidsAligned_DLSR_wNoise1d5dB_wLB"]
Imag_FidsAligned = loadmat(os.path.join(data_path, "Imag_FidsAligned_DLSR_wNoise1d5dB_wLB.mat"))["Imag_FidsAligned_DLSR_wNoise1d5dB_wLB"]

# Fids Unaligned
Complex_FidsUnAligned = loadmat(os.path.join(data_path, "Complex_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"))["Complex_FidsUnAligned_DLSR_wNoise1d5dB_wLB"]
Real_FidsUnAligned = loadmat(os.path.join(data_path, "Real_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"))["Real_FidsUnAligned_DLSR_wNoise1d5dB_wLB"]
Imag_FidsUnAligned = loadmat(os.path.join(data_path, "Imag_FidsUnAligned_DLSR_wNoise1d5dB_wLB.mat"))["Imag_FidsUnAligned_DLSR_wNoise1d5dB_wLB"]

# %% [markdown]
# # Adding noise to the input (SNR = 1.5 dB = 2.5)

# %%
#Computing std 
signal_freq=mean(np.absolute(Real_spectAligned[:,1]))
db=1.5
std_freq=signal_freq/(10**(db/20))
print(f'The noise: {std_freq}')

#Constructing noise
seed1 = 1
seed2 = 2
np.random.seed(seed1)
noise1 = np.random.normal(0, std_freq, Real_spectUnAligned_and_spectAligned.shape)

#noise is only added to the test datset
noisy_Real_spectUnAligned_and_spectAligned=np.copy(Real_spectUnAligned_and_spectAligned)
noisy_Real_spectUnAligned_and_spectAligned=Real_spectUnAligned_and_spectAligned+noise1
noisy_Real_spectUnAligned_and_spectAligned[0:18000,:]=Real_spectUnAligned_and_spectAligned[0:18000,:]
noisy_Real_spectUnAligned_and_spectAligned[20000:38000,:]=Real_spectUnAligned_and_spectAligned[20000:38000,:]

print('noisy_Real_spectUnAligned',noisy_Real_spectUnAligned_and_spectAligned.shape)
# Out:
# The noise: 0.004402057459916521
# noisy_Real_spectUnAligned (40000, 2048)

# %% [markdown]
# # Data preparation

# %%
#defining ground truths
F0_all = torch.from_numpy(np.squeeze(F0)).type(torch.FloatTensor)
Phs_all = torch.from_numpy(np.squeeze(Phs)).type(torch.FloatTensor)

time = np.arange(2048)/2000

deformation = np.zeros([F0.shape[1],2])
deformation[:,0] = F0
deformation[:,1] = Phs

#reshaping spectra unaligned and aligned data
noisy_Real_spectUnAligned_and_spectAligned_tensor_all = torch.from_numpy(noisy_Real_spectUnAligned_and_spectAligned).type(torch.FloatTensor).view(-1, 1, 2048) 

# define the template spectra of on and off spectra as the 1st acquisition of the aligned spectra

# off template=1st
Real_FidsAligned[0:20000,:] = Real_FidsAligned[0,:] # Red
Imag_FidsAligned[0:20000,:] = Imag_FidsAligned[0,:] # Red

# on template=1st
Real_FidsAligned[20000:40000,:] = Real_FidsAligned[20000,:] # Red
Imag_FidsAligned[20000:40000,:] = Imag_FidsAligned[20000,:] # Red

#Fids aligned reshape
Real_FidsAligned_tensor_all = torch.from_numpy(Real_FidsAligned).type(torch.FloatTensor).view(-1, 1, 2048) 
Imag_FidsAligned_tensor_all = torch.from_numpy(Imag_FidsAligned).type(torch.FloatTensor).view(-1, 1, 2048) 

#Fids unaligned reshape
Real_FidsUnAligned_tensor_all = torch.from_numpy(Real_FidsUnAligned).type(torch.FloatTensor).view(-1, 1, 2048) 
Imag_FidsUnAligned_tensor_all = torch.from_numpy(Imag_FidsUnAligned).type(torch.FloatTensor).view(-1, 1, 2048)

# %% [markdown]
# # Dataloader (Train, N = 32,000)

# %%
# Define variables 
batch_size_training = 320

# ============ training dataset ============
N_train = 32000
time_mat_train = np.tile(time,[N_train,1])

#defining ground truths
F0_train = torch.cat((F0_all[0:16000],\
                F0_all[20000:36000]),0)
Phs_train = torch.cat((Phs_all[0:16000],\
                Phs_all[20000:36000]),0)

#defining spectra and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_train = \
torch.cat((noisy_Real_spectUnAligned_and_spectAligned_tensor_all[0:16000,:,:],\
                noisy_Real_spectUnAligned_and_spectAligned_tensor_all[20000:36000,:,:]),0)

Real_FidsAligned_tensor_train = \
torch.cat((Real_FidsAligned_tensor_all[0:16000,:,:],\
                Real_FidsAligned_tensor_all[20000:36000,:,:]),0)

Imag_FidsAligned_tensor_train = \
torch.cat((Imag_FidsAligned_tensor_all[0:16000,:,:],\
                Imag_FidsAligned_tensor_all[20000:36000,:,:]),0)

Real_FidsUnAligned_tensor_train = \
torch.cat((Real_FidsUnAligned_tensor_all[0:16000,:,:],\
                Real_FidsUnAligned_tensor_all[20000:36000,:,:]),0)

Imag_FidsUnAligned_tensor_train = \
torch.cat((Imag_FidsUnAligned_tensor_all[0:16000,:,:],\
                Imag_FidsUnAligned_tensor_all[20000:36000,:,:]),0)

time_mat_tensor_train = torch.from_numpy(time_mat_train).type(torch.FloatTensor).view(-1, 1, 2048) 

#defining train data and train loader
train_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_train, Real_FidsAligned_tensor_train, Imag_FidsAligned_tensor_train, \
                           Real_FidsUnAligned_tensor_train, Imag_FidsUnAligned_tensor_train, time_mat_tensor_train, F0_train, Phs_train)
train_loader = DataLoader(train_data, batch_size = batch_size_training)

#printing outputs
print('F0_train',F0_train.shape)
print('Phs_train',Phs_train.shape)
print('noisy_Real_spectUnAligned_and_spectAligned_tensor_train',noisy_Real_spectUnAligned_and_spectAligned_tensor_train.shape)
print('Real_FidsAligned_tensor_train',Real_FidsAligned_tensor_train.shape)
print('Imag_FidsAligned_tensor_train',Imag_FidsAligned_tensor_train.shape)
print('Real_FidsUnAligned_tensor_train',Real_FidsUnAligned_tensor_train.shape)
print('Imag_FidsUnAligned_tensor_train',Imag_FidsUnAligned_tensor_train.shape)
print('time_mat_tensor_train',time_mat_tensor_train.shape)
# Out:
# F0_train torch.Size([32000])
# Phs_train torch.Size([32000])
# noisy_Real_spectUnAligned_and_spectAligned_tensor_train torch.Size([32000, 1, 2048])
# Real_FidsAligned_tensor_train torch.Size([32000, 1, 2048])
# Imag_FidsAligned_tensor_train torch.Size([32000, 1, 2048])
# Real_FidsUnAligned_tensor_train torch.Size([32000, 1, 2048])
# Imag_FidsUnAligned_tensor_train torch.Size([32000, 1, 2048])
# time_mat_tensor_train torch.Size([32000, 1, 2048])

# %% [markdown]
# # Dataloader (Validation)

# %%
# ============ validation dataset ============
N_val = 4000
time_mat_val = np.tile(time,[N_val,1])

#defining ground truths
F0_val = torch.cat((F0_all[16000:18000],\
                F0_all[36000:38000]),0)
Phs_val = torch.cat((Phs_all[16000:18000],\
                Phs_all[36000:38000]),0)

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_val = \
torch.cat((noisy_Real_spectUnAligned_and_spectAligned_tensor_all[16000:18000,:,:],\
                noisy_Real_spectUnAligned_and_spectAligned_tensor_all[36000:38000,:,:]),0)

Real_FidsAligned_tensor_val = \
torch.cat((Real_FidsAligned_tensor_all[16000:18000,:,:],\
                Real_FidsAligned_tensor_all[36000:38000,:,:]),0)

Imag_FidsAligned_tensor_val = \
torch.cat((Imag_FidsAligned_tensor_all[16000:18000,:,:],\
                Imag_FidsAligned_tensor_all[36000:38000,:,:]),0)

Real_FidsUnAligned_tensor_val = \
torch.cat((Real_FidsUnAligned_tensor_all[16000:18000,:,:],\
                Real_FidsUnAligned_tensor_all[36000:38000,:,:]),0)

Imag_FidsUnAligned_tensor_val = \
torch.cat((Imag_FidsUnAligned_tensor_all[16000:18000,:,:],\
                Imag_FidsUnAligned_tensor_all[36000:38000,:,:]),0)

time_mat_tensor_val = torch.from_numpy(time_mat_val).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining validation loader
val_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_val, Real_FidsAligned_tensor_val, Imag_FidsAligned_tensor_val, \
                         Real_FidsUnAligned_tensor_val, Imag_FidsUnAligned_tensor_val, time_mat_tensor_val, F0_val, Phs_val)
val_loader = DataLoader(val_data, batch_size = 1)

print('time_mat_tensor_val',time_mat_tensor_val.shape)
print('F0_val',F0_val.shape)
print('Phs_val',Phs_val.shape)
# Out:
# time_mat_tensor_val torch.Size([4000, 1, 2048])
# F0_val torch.Size([4000])
# Phs_val torch.Size([4000])

# %% [markdown]
# # Dataloader (Test)

# %%
# ============ testing dataset ============
N_test = 4000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = torch.cat((F0_all[18000:20000],\
                F0_all[38000:40000]),0)
Phs_test = torch.cat((Phs_all[18000:20000],\
                Phs_all[38000:40000]),0)

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = \
torch.cat((noisy_Real_spectUnAligned_and_spectAligned_tensor_all[18000:20000,:,:],\
                noisy_Real_spectUnAligned_and_spectAligned_tensor_all[38000:40000,:,:]),0)

Real_FidsAligned_tensor_test = \
torch.cat((Real_FidsAligned_tensor_all[18000:20000,:,:],\
                Real_FidsAligned_tensor_all[38000:40000,:,:]),0)

Imag_FidsAligned_tensor_test = \
torch.cat((Imag_FidsAligned_tensor_all[18000:20000,:,:],\
                Imag_FidsAligned_tensor_all[38000:40000,:,:]),0)

Real_FidsUnAligned_tensor_test = \
torch.cat((Real_FidsUnAligned_tensor_all[18000:20000,:,:],\
                Real_FidsUnAligned_tensor_all[38000:40000,:,:]),0)

Imag_FidsUnAligned_tensor_test = \
torch.cat((Imag_FidsUnAligned_tensor_all[18000:20000,:,:],\
                Imag_FidsUnAligned_tensor_all[38000:40000,:,:]),0)

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([4000, 1, 2048])
# F0_test torch.Size([4000])
# Phs_test torch.Size([4000])

# %% [markdown]
# # Defining CNN-SR model

# %%
class Model(nn.Module):
    '''ConvNet -> Max_Pool -> RELU -> ConvNet -> Max_Pool -> RELU -> FC -> RELU -> FC -> FC -> F0 and Phs'''
    def __init__(self):
        '''Define model modules.'''
        super(Model, self).__init__()
        self.conv1 = nn.Conv1d(1, 2, 128, 1, 64)
        self.bn1 = nn.BatchNorm1d(num_features=2)
        self.conv2 = nn.Conv1d(2, 4, 128, 1, 64)
        self.bn2 = nn.BatchNorm1d(num_features=4)
        self.conv3 = nn.Conv1d(4, 8, 128, 1, 64)
        self.bn3 = nn.BatchNorm1d(num_features=8)
        self.conv4 = nn.Conv1d(8, 16, 128, 1, 64)
        self.bn4 = nn.BatchNorm1d(num_features=16)
        self.fc1 = nn.Linear(128 * 1 * 16, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 2)

    def forward(self, x):
        '''Define the model architecture (the sequence to place the model modules).'''
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.max_pool1d(x, 2, 2)
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.max_pool1d(x, 2, 2)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.max_pool1d(x, 2, 2)
        x = F.relu(self.bn4(self.conv4(x)))
        x = F.max_pool1d(x, 2, 2)
        x = x.view(-1, 128 * 1 * 16)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

JETCNN_L = Model()

cuda = torch.cuda.is_available()
print("GPU available:", cuda)

device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
print(device)

# If GPU available, move the model to GPU.
if cuda:
    JETCNN_L.to(device)

torch.manual_seed(1102)
np.random.seed(1102)

print(JETCNN_L)
# Out:
# GPU available: True
# cuda:2
# Model(
#   (conv1): Conv1d(1, 2, kernel_size=(128,), stride=(1,), padding=(64,))
#   (bn1): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(2, 4, kernel_size=(128,), stride=(1,), padding=(64,))
#   (bn2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv1d(4, 8, kernel_size=(128,), stride=(1,), padding=(64,))
#   (bn3): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv1d(8, 16, kernel_size=(128,), stride=(1,), padding=(64,))
#   (bn4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=2048, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Model Training

# %%
# define the model
JETCNN = JETCNN_L

# define loss and optimizer
criterion = L1Loss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-4)

# define parameters
EPOCHS = 1000

train_epoch_loss = []
train_epoch_F0_MAE = [] 
train_epoch_Phs_MAE = [] 
train_epoch_p_correlation = []

val_epoch_loss = []
val_epoch_F0_MAE = [] 
val_epoch_Phs_MAE = [] 
val_epoch_p_correlation = []
val_epoch_loss_input = []
val_epoch_p_correlation_input = []

test_epoch_loss = []
test_epoch_F0_MAE = [] 
test_epoch_Phs_MAE = [] 
test_epoch_p_correlation = []

# early stopping
early_stop = 1
patience = 50

# path
best_JETCNN_path = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best.pt'
last_JETCNN_path = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_last.pt'

# Loading pretrained model 
JETCNN.load_state_dict(torch.load('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_best.pt'))

# where to calculate the spectral loss
range1 = 0
range2 = 2048

fid_range1 = 0
fid_range2 = 1024 
    
for epoch in range(EPOCHS):
     
    train_loss = []
    train_F0_MAE = [] 
    train_Phs_MAE = [] 
    train_p_correlation = []
    
    val_loss = []
    val_F0_MAE = [] 
    val_Phs_MAE = [] 
    val_p_correlation = []
    
    test_loss = []
    test_F0_MAE = [] 
    test_Phs_MAE = [] 
    test_p_correlation = []
    
    val_loss_input = []
    val_p_correlation_input = []

    #######################################################
    ####################### Train #########################
    #######################################################
    print('Training begins...')
    for batch_index, data in enumerate(train_loader):

        # If GPU is available, move the data to the GPU for faster computation.
        if cuda:
            
            # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor, F0_tensor,Phs_tensor]
            noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
            Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
            F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##
            
            
            # *** Set the model to train mode ***
            JETCNN.train()
            
            # *** zero the parameter gradients ***
            optimizer.zero_grad()
            
            # *** forward + backward + optimize ***
            
            #predict deformation from real spectra unaligned and aligned
            
            
            deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)
            
            #cloning real and imag fids unaligned tensor
            Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)
            
            Real_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Real_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            
            # *** Define loss between the real part of deformed spectra and the real part of the true spectra
            
            # cloning the ground truths (initializing)
            F0_pred_tensor = torch.clone(F0_tensor)
            Phs_pred_tensor = torch.clone(Phs_tensor)
            
            for kk in range(len(deformation_predicted[:,0])):
                
                #introducing real deformations
                freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                #introducing imaginary deformations
                freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                #defining deformations from the offsets
                deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
                deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
                #constructing tensor for the deformations
                F0_pred_tensor[kk] = deformation_predicted[kk,0] 
                Phs_pred_tensor[kk] = deformation_predicted[kk,1] 
                
                
                #contructing real and imaging fids prediction tensor
                Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                                ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
                Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                                ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)
                
                Real_pred_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                Imag_pred_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                
                Real_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
                Imag_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
            
            # flattening
            F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
            F0_tensor_vector = torch.flatten(F0_tensor) 
            Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
            Phs_tensor_vector = torch.flatten(Phs_tensor)
             
            # defining fids real and imag predicted and truth tensors
            Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            # specs
            Real_pred_spec_tensor_vector = torch.flatten(Real_pred_spec_tensor[:,:,range1:range2])
            Real_spec_tensor_vector = torch.flatten(Real_spec_tensor[:,:,range1:range2])
            
            Imag_pred_spec_tensor_vector = torch.flatten(Imag_pred_spec_tensor[:,:,range1:range2])
            Imag_spec_tensor_vector = torch.flatten(Imag_spec_tensor[:,:,range1:range2])
                        
            #predicted f0 and ph and truth f0 and phs loss computation
            loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
            loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 
            
            #predicted and truth fids loss computation
            loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
            loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)
            
            #predicted and truth spectra loss computation
            loss_spec_MSE_real = criterion(Real_pred_spec_tensor_vector, Real_spec_tensor_vector) 
            loss_spec_MSE_imag = criterion(Imag_pred_spec_tensor_vector, Imag_spec_tensor_vector)
            
            # fids correlation loss real and imag
            v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
            v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
            p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
            loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)
            v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
            v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
            p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
            loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag)
            
            # spectra correlation loss real and imag
            v_Real_pred_spec = Real_pred_spec_tensor_vector - torch.mean(Real_pred_spec_tensor_vector)
            v_Real_spec = Real_spec_tensor_vector - torch.mean(Real_spec_tensor_vector)
            spec_p_correlation_real = torch.sum(v_Real_pred_spec * v_Real_spec) / (torch.sqrt(torch.sum(v_Real_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Real_spec ** 2)))
            spec_loss_p_correlation_real = 1-torch.mul(spec_p_correlation_real,spec_p_correlation_real)
            v_Imag_pred_spec = Imag_pred_spec_tensor_vector - torch.mean(Imag_pred_spec_tensor_vector)
            v_Imag_spec = Imag_spec_tensor_vector - torch.mean(Imag_spec_tensor_vector)
            spec_p_correlation_imag = torch.sum(v_Imag_pred_spec * v_Imag_spec) / (torch.sqrt(torch.sum(v_Imag_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Imag_spec ** 2)))
            spec_loss_p_correlation_imag = 1-torch.mul(spec_p_correlation_imag,spec_p_correlation_imag)
            
            loss = 100*(loss_spec_MSE_real + loss_spec_MSE_imag)+ loss_MAE_Ph/10 + loss_MAE_F0/20 

            
            # compute the MAE of the tensors                             Check!
            F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
            Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##
            
            # compute the fids real and imag
            fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
            fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()
            
            #real spectra and predicted spectra
            Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
            Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))
            
            #correlation of spectras
            r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
            p_correlation = r[0,1]
            
            if epoch == 100 and batch_index == 1:
                plt.figure()
                plt.plot(Real_spec[range1:range2])
                plt.figure()
                plt.plot(Real_pred_spec[range1:range2])
                plt.plot(Real_spec[range1:range2])

            # backpropagate the loss
            loss.backward()
            
            # update the parameters
            optimizer.step()
            
            # store the train_loss and tran_p_correlation
            train_loss.append(loss.cpu().data.item())
            train_F0_MAE.append(F0_MAE.cpu().data.item()) ##
            train_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
            train_p_correlation.append(p_correlation)
    
    
    train_epoch_loss.append(np.mean(train_loss))
    train_epoch_F0_MAE.append(np.mean(train_F0_MAE)) ##
    train_epoch_Phs_MAE.append(np.mean(train_Phs_MAE)) ##
    train_epoch_p_correlation.append(np.mean(train_p_correlation))
    
    #######################################################
    ##################### Validation ######################
    #######################################################
    print('Validation begins...')
    for batch_index, data in enumerate(val_loader):
        
        # If GPU is available, move the data to the GPU for faster computation.
        if cuda:
            
            # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
            noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
            Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
            F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##
            
            # *** Set the model to train mode ***
            JETCNN.eval()
            
            
            # *** forward + backward + optimize ***
            deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)
            
            Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)
            
            Real_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Real_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            
            # *** Define loss between the real part of deformed spectra and the real part of the true spectra
            # apply the deformation
            F0_pred_tensor = torch.clone(F0_tensor)
            Phs_pred_tensor = torch.clone(Phs_tensor)
            for kk in range(len(deformation_predicted[:,0])):
                
                freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
                deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
                F0_pred_tensor[kk] = deformation_predicted[kk,0] 
                Phs_pred_tensor[kk] = deformation_predicted[kk,1] 
                
                Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                                ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
                Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                                ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)
                
                Real_pred_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                Imag_pred_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                
                Real_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
                Imag_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
            
            # compute the loss
            F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) ##
            F0_tensor_vector = torch.flatten(F0_tensor) ##
            Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) ##
            Phs_tensor_vector = torch.flatten(Phs_tensor) ##
             
            # fids
            Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            # specs
            Real_pred_spec_tensor_vector = torch.flatten(Real_pred_spec_tensor[:,:,range1:range2])
            Real_spec_tensor_vector = torch.flatten(Real_spec_tensor[:,:,range1:range2])
            
            Imag_pred_spec_tensor_vector = torch.flatten(Imag_pred_spec_tensor[:,:,range1:range2])
            Imag_spec_tensor_vector = torch.flatten(Imag_spec_tensor[:,:,range1:range2])
            
            loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
            loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 
            
            loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
            loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)
            
            loss_spec_MSE_real = criterion(Real_pred_spec_tensor_vector, Real_spec_tensor_vector) 
            loss_spec_MSE_imag = criterion(Imag_pred_spec_tensor_vector, Imag_spec_tensor_vector)
            
            # fids correlation loss real and imag
            v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
            v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
            p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
            loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)
            v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
            v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
            p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
            loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag)
            
            # spectra correlation loss real and imag
            v_Real_pred_spec = Real_pred_spec_tensor_vector - torch.mean(Real_pred_spec_tensor_vector)
            v_Real_spec = Real_spec_tensor_vector - torch.mean(Real_spec_tensor_vector)
            spec_p_correlation_real = torch.sum(v_Real_pred_spec * v_Real_spec) / (torch.sqrt(torch.sum(v_Real_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Real_spec ** 2)))
            spec_loss_p_correlation_real = 1-torch.mul(spec_p_correlation_real,spec_p_correlation_real)
            v_Imag_pred_spec = Imag_pred_spec_tensor_vector - torch.mean(Imag_pred_spec_tensor_vector)
            v_Imag_spec = Imag_spec_tensor_vector - torch.mean(Imag_spec_tensor_vector)
            spec_p_correlation_imag = torch.sum(v_Imag_pred_spec * v_Imag_spec) / (torch.sqrt(torch.sum(v_Imag_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Imag_spec ** 2)))
            spec_loss_p_correlation_imag = 1-torch.mul(spec_p_correlation_imag,spec_p_correlation_imag)
            
            loss = 100*(loss_spec_MSE_real + loss_spec_MSE_imag)+ loss_MAE_Ph/10 + loss_MAE_F0/20 

            # compute the MAE of offsets
            F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
            Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##
            
            # compute the correlation
            fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
            fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()
            
            Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
            Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))
            
            r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
            p_correlation = r[0,1]
            
            # store the train_loss and tran_p_correlation
            val_loss.append(loss.cpu().data.item())
            val_F0_MAE.append(F0_MAE.cpu().data.item()) 
            val_Phs_MAE.append(Phs_MAE.cpu().data.item())
            val_p_correlation.append(p_correlation)
              
    val_epoch_loss.append(np.mean(val_loss))
    val_epoch_F0_MAE.append(np.mean(val_F0_MAE)) 
    val_epoch_Phs_MAE.append(np.mean(val_Phs_MAE)) 
    val_epoch_p_correlation.append(np.mean(val_p_correlation))
    
    #######################################################
    ######################## Test #########################
    #######################################################
    print('Tesing begins...')
    for batch_index, data in enumerate(test_loader):
        
        # If GPU is available, move the data to the GPU for faster computation.       
        if cuda:
            
            # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
            noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
            Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
            F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##
            
            # *** Set the model to train mode ***
            JETCNN.eval()
            
            
            # *** forward + backward + optimize ***
            deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)
            
            Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)
            
            Real_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Real_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            
            # *** Define loss between the real part of deformed spectra and the real part of the true spectra
            # apply the deformation
            F0_pred_tensor = torch.clone(F0_tensor)
            Phs_pred_tensor = torch.clone(Phs_tensor)
            for kk in range(len(deformation_predicted[:,0])):
                
                freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
                deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
                F0_pred_tensor[kk] = deformation_predicted[kk,0] 
                Phs_pred_tensor[kk] = deformation_predicted[kk,1] 
                
                Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                                ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
                Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                                ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)
                
                Real_pred_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                Imag_pred_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                
                Real_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
                Imag_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
            
            
            # compute the loss
            F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
            F0_tensor_vector = torch.flatten(F0_tensor) 
            Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
            Phs_tensor_vector = torch.flatten(Phs_tensor) 
             
            # fids
            Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            # specs
            Real_pred_spec_tensor_vector = torch.flatten(Real_pred_spec_tensor[:,:,range1:range2])
            Real_spec_tensor_vector = torch.flatten(Real_spec_tensor[:,:,range1:range2])
            
            Imag_pred_spec_tensor_vector = torch.flatten(Imag_pred_spec_tensor[:,:,range1:range2])
            Imag_spec_tensor_vector = torch.flatten(Imag_spec_tensor[:,:,range1:range2])
            
            loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
            loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 
            
            loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
            loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)
            
            loss_spec_MSE_real = criterion(Real_pred_spec_tensor_vector, Real_spec_tensor_vector) 
            loss_spec_MSE_imag = criterion(Imag_pred_spec_tensor_vector, Imag_spec_tensor_vector)
            
            # fids correlation loss real and imag
            v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
            v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
            p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
            loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)
            v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
            v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
            p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
            loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag)
            
            # spectra correlation loss real and imag
            v_Real_pred_spec = Real_pred_spec_tensor_vector - torch.mean(Real_pred_spec_tensor_vector)
            v_Real_spec = Real_spec_tensor_vector - torch.mean(Real_spec_tensor_vector)
            spec_p_correlation_real = torch.sum(v_Real_pred_spec * v_Real_spec) / (torch.sqrt(torch.sum(v_Real_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Real_spec ** 2)))
            spec_loss_p_correlation_real = 1-torch.mul(spec_p_correlation_real,spec_p_correlation_real)
            v_Imag_pred_spec = Imag_pred_spec_tensor_vector - torch.mean(Imag_pred_spec_tensor_vector)
            v_Imag_spec = Imag_spec_tensor_vector - torch.mean(Imag_spec_tensor_vector)
            spec_p_correlation_imag = torch.sum(v_Imag_pred_spec * v_Imag_spec) / (torch.sqrt(torch.sum(v_Imag_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Imag_spec ** 2)))
            spec_loss_p_correlation_imag = 1-torch.mul(spec_p_correlation_imag,spec_p_correlation_imag)
            
            loss = 100*(loss_spec_MSE_real + loss_spec_MSE_imag)+ loss_MAE_Ph/10 + loss_MAE_F0/20 

            
            # compute the MAE of offsets
            F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
            Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##
            
            # compute the correlation
            fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
            fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()
            
            Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
            Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))
            
            r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
            p_correlation = r[0,1]
            
            # store the train_loss and tran_p_correlation
            test_loss.append(loss.cpu().data.item())
            test_F0_MAE.append(F0_MAE.cpu().data.item()) ##
            test_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
            test_p_correlation.append(p_correlation.item())
             
    test_epoch_loss.append(np.mean(test_loss))
    test_epoch_F0_MAE.append(np.mean(test_F0_MAE)) ##
    test_epoch_Phs_MAE.append(np.mean(test_Phs_MAE)) ##
    test_epoch_p_correlation.append(np.mean(test_p_correlation))
    
    print("==== Epoch: {}/{} | train_loss = {} | train_correlation_R^2 = {} ====".format(epoch+1, EPOCHS, train_epoch_loss[-1], \
                                                                                         train_epoch_p_correlation[-1]*train_epoch_p_correlation[-1]))
    print("==== Epoch: {}/{} | train_F0_MAE = {} Hz | train_Phs_MAE = {} Degree ====".format(epoch+1, EPOCHS, train_epoch_F0_MAE[-1], \
                                                                                         train_epoch_Phs_MAE[-1]))
    print("---------------------------------------------------------------------------------------------------------------------")
    print("==== Epoch: {}/{} | val_loss = {} | val_p_correlation^2 = {} ====".format(epoch+1, EPOCHS, val_epoch_loss[-1], \
                                                                                     val_epoch_p_correlation[-1]*val_epoch_p_correlation[-1]))
    print("==== Epoch: {}/{} | val_F0_MAE = {} Hz | val_Phs_MAE = {} Degree ====".format(epoch+1, EPOCHS, val_epoch_F0_MAE[-1], \
                                                                                         val_epoch_Phs_MAE[-1]))
    print("---------------------------------------------------------------------------------------------------------------------")
    print("==== Epoch: {}/{} | test_loss = {} | test_p_correlation^2 = {} ====".format(epoch+1, EPOCHS, test_epoch_loss[-1], \
                                                                                     test_epoch_p_correlation[-1]*test_epoch_p_correlation[-1]))
    print("==== Epoch: {}/{} | test_F0_MAE = {} Hz | test_Phs_MAE = {} Degree ====".format(epoch+1, EPOCHS, test_epoch_F0_MAE[-1], \
                                                                                         test_epoch_Phs_MAE[-1]))
    
    print("=======================================================================================================================")
    
    # Make sure we save the best and last unets.
    if epoch == 0:
        best_JETCNN_loss = val_epoch_loss[0]
    if val_epoch_loss[-1] < best_JETCNN_loss:
        best_JETCNN_loss = val_epoch_loss[-1]
        best_epoch = epoch
        best_JETCNN = JETCNN.state_dict()
        print(f'best model loss is {best_JETCNN_loss:0.14f} at epoch {epoch+1}' )
        torch.save(best_JETCNN, best_JETCNN_path)
    if (epoch == EPOCHS - 1):
        last_JETCNN = JETCNN.state_dict()
        torch.save(last_JETCNN, last_JETCNN_path)

    # Early stop 
    if (early_stop == 1):
        if (len(val_epoch_loss) > patience):
            if (np.min(val_epoch_loss[0:-patience+1]) <= np.min(val_epoch_loss[-patience:])):
                print('Validation loss stop decreasing. Stop training.')
                last_JETCNN = JETCNN.state_dict()
                torch.save(last_JETCNN, last_JETCNN_path)
                break
# Out:
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 1/1000 | train_loss = 0.08099461272358895 | train_correlation_R^2 = 0.9999777694075782 ====
# ==== Epoch: 1/1000 | train_F0_MAE = 0.026645428594201805 Hz | train_Phs_MAE = 0.15227494247257709 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 1/1000 | val_loss = 0.08116247139984625 | val_p_correlation^2 = 0.9999132520100773 ====
# ==== Epoch: 1/1000 | val_F0_MAE = 0.029440381122753025 Hz | val_Phs_MAE = 0.11222848539799452 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 1/1000 | test_loss = 1.4879188758479431 | test_p_correlation^2 = 0.8523657725786673 ====
# ==== Epoch: 1/1000 | test_F0_MAE = 0.7335441616633906 Hz | test_Phs_MAE = 2.1716192750968037 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 2/1000 | train_loss = 0.05099487144500017 | train_correlation_R^2 = 0.9999881095595097 ====
# ==== Epoch: 2/1000 | train_F0_MAE = 0.01707845853641629 Hz | train_Phs_MAE = 0.09165955446660519 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 2/1000 | val_loss = 0.046239808650392664 | val_p_correlation^2 = 0.999975794014885 ====
# ==== Epoch: 2/1000 | val_F0_MAE = 0.014258897980675101 Hz | val_Phs_MAE = 0.10517782081104815 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 2/1000 | test_loss = 1.4802553780043963 | test_p_correlation^2 = 0.852783362528169 ====
# ==== Epoch: 2/1000 | test_F0_MAE = 0.7222993065887131 Hz | test_Phs_MAE = 2.1173736065253617 Degree ====
# =======================================================================================================================
# best model loss is 0.04623980865039 at epoch 2
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 3/1000 | train_loss = 0.05479433696717024 | train_correlation_R^2 = 0.9999833386253818 ====
# ==== Epoch: 3/1000 | train_F0_MAE = 0.018752070292830467 Hz | train_Phs_MAE = 0.08797677710652352 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 3/1000 | val_loss = 0.054236079360329315 | val_p_correlation^2 = 0.9999667237454648 ====
# ==== Epoch: 3/1000 | val_F0_MAE = 0.017386912391521035 Hz | val_Phs_MAE = 0.1151254673236981 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 3/1000 | test_loss = 1.4769506490333006 | test_p_correlation^2 = 0.8529956995999011 ====
# ==== Epoch: 3/1000 | test_F0_MAE = 0.7126871190033853 Hz | test_Phs_MAE = 2.0954730300754307 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 4/1000 | train_loss = 0.0570730646699667 | train_correlation_R^2 = 0.9999785992113971 ====
# ==== Epoch: 4/1000 | train_F0_MAE = 0.019618391962721943 Hz | train_Phs_MAE = 0.09237561620771885 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 4/1000 | val_loss = 0.07409263771885889 | val_p_correlation^2 = 0.9999319937533258 ====
# ==== Epoch: 4/1000 | val_F0_MAE = 0.026915618909988552 Hz | val_Phs_MAE = 0.10084023963473737 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 4/1000 | test_loss = 1.4752041471903212 | test_p_correlation^2 = 0.8531226094187255 ====
# ==== Epoch: 4/1000 | test_F0_MAE = 0.7044755550315603 Hz | test_Phs_MAE = 2.0844341838806866 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 5/1000 | train_loss = 0.046811097003519535 | train_correlation_R^2 = 0.9999906748203925 ====
# ==== Epoch: 5/1000 | train_F0_MAE = 0.015399263594299556 Hz | train_Phs_MAE = 0.08796472284942865 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 5/1000 | val_loss = 0.05178198495344259 | val_p_correlation^2 = 0.9999649356233777 ====
# ==== Epoch: 5/1000 | val_F0_MAE = 0.016535625340417026 Hz | val_Phs_MAE = 0.1045633553583175 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 5/1000 | test_loss = 1.471717630895786 | test_p_correlation^2 = 0.8531405886766489 ====
# ==== Epoch: 5/1000 | test_F0_MAE = 0.7049658581037075 Hz | test_Phs_MAE = 2.0551054458245637 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 6/1000 | train_loss = 0.05232638824731112 | train_correlation_R^2 = 0.999983511518217 ====
# ==== Epoch: 6/1000 | train_F0_MAE = 0.01803864322602749 Hz | train_Phs_MAE = 0.08282960120588541 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 6/1000 | val_loss = 0.039438024694187335 | val_p_correlation^2 = 0.9999834807337924 ====
# ==== Epoch: 6/1000 | val_F0_MAE = 0.011174498105421662 Hz | val_Phs_MAE = 0.10592778555862606 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 6/1000 | test_loss = 1.4713679132079707 | test_p_correlation^2 = 0.853262218393409 ====
# ==== Epoch: 6/1000 | test_F0_MAE = 0.6992691703401506 Hz | test_Phs_MAE = 2.0576794796735047 Degree ====
# =======================================================================================================================
# best model loss is 0.03943802469419 at epoch 6
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 7/1000 | train_loss = 0.053483977504074576 | train_correlation_R^2 = 0.9999822544147717 ====
# ==== Epoch: 7/1000 | train_F0_MAE = 0.018178055956959725 Hz | train_Phs_MAE = 0.08814545754343271 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 7/1000 | val_loss = 0.0550797325624153 | val_p_correlation^2 = 0.9999641995508196 ====
# ==== Epoch: 7/1000 | val_F0_MAE = 0.018251304973848165 Hz | val_Phs_MAE = 0.10427633869089187 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 7/1000 | test_loss = 1.4698709611715748 | test_p_correlation^2 = 0.8534228806016992 ====
# ==== Epoch: 7/1000 | test_F0_MAE = 0.6914358474025503 Hz | test_Phs_MAE = 2.0505056964084507 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 8/1000 | train_loss = 0.052255438081920146 | train_correlation_R^2 = 0.9999858187545163 ====
# ==== Epoch: 8/1000 | train_F0_MAE = 0.01809524156153202 Hz | train_Phs_MAE = 0.08090767022222281 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 8/1000 | val_loss = 0.04772404287314566 | val_p_correlation^2 = 0.999978685043368 ====
# ==== Epoch: 8/1000 | val_F0_MAE = 0.01336700672097504 Hz | val_Phs_MAE = 0.1306599974296987 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 8/1000 | test_loss = 1.4701544429226778 | test_p_correlation^2 = 0.8534375245289411 ====
# ==== Epoch: 8/1000 | test_F0_MAE = 0.690925166413188 Hz | test_Phs_MAE = 2.053752969607711 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 9/1000 | train_loss = 0.054719642996788026 | train_correlation_R^2 = 0.9999860638815489 ====
# ==== Epoch: 9/1000 | train_F0_MAE = 0.018824932891875507 Hz | train_Phs_MAE = 0.0874715630337596 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 9/1000 | val_loss = 0.04458031554869376 | val_p_correlation^2 = 0.9999731759508621 ====
# ==== Epoch: 9/1000 | val_F0_MAE = 0.014814724623225629 Hz | val_Phs_MAE = 0.08113325460907071 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 9/1000 | test_loss = 1.46905453899689 | test_p_correlation^2 = 0.8531659574564998 ====
# ==== Epoch: 9/1000 | test_F0_MAE = 0.6972397262593731 Hz | test_Phs_MAE = 2.0358584254160523 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 10/1000 | train_loss = 0.05016768038272858 | train_correlation_R^2 = 0.9999889792840598 ====
# ==== Epoch: 10/1000 | train_F0_MAE = 0.01641842828132212 Hz | train_Phs_MAE = 0.09555666167289019 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 10/1000 | val_loss = 0.045297158471905276 | val_p_correlation^2 = 0.9999793130181625 ====
# ==== Epoch: 10/1000 | val_F0_MAE = 0.013678341483697296 Hz | val_Phs_MAE = 0.11124701098538935 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 10/1000 | test_loss = 1.4721901047211141 | test_p_correlation^2 = 0.8531359848630126 ====
# ==== Epoch: 10/1000 | test_F0_MAE = 0.6991839366769418 Hz | test_Phs_MAE = 2.0632286319620907 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 11/1000 | train_loss = 0.061477663069963454 | train_correlation_R^2 = 0.999981438685377 ====
# ==== Epoch: 11/1000 | train_F0_MAE = 0.021463050874881446 Hz | train_Phs_MAE = 0.09066398467868567 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 11/1000 | val_loss = 0.06551776323279773 | val_p_correlation^2 = 0.9999477425889832 ====
# ==== Epoch: 11/1000 | val_F0_MAE = 0.020101097054313868 Hz | val_Phs_MAE = 0.14851256741245744 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 11/1000 | test_loss = 1.4678004721403122 | test_p_correlation^2 = 0.8532908527590024 ====
# ==== Epoch: 11/1000 | test_F0_MAE = 0.6971428069924004 Hz | test_Phs_MAE = 2.0264100629985333 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 12/1000 | train_loss = 0.047667232770472766 | train_correlation_R^2 = 0.9999894378667608 ====
# ==== Epoch: 12/1000 | train_F0_MAE = 0.016112322257831692 Hz | train_Phs_MAE = 0.08016874309629202 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 12/1000 | val_loss = 0.046581862071804606 | val_p_correlation^2 = 0.9999754649209648 ====
# ==== Epoch: 12/1000 | val_F0_MAE = 0.014481273110024631 Hz | val_Phs_MAE = 0.10828743501193822 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 12/1000 | test_loss = 1.4708088209521957 | test_p_correlation^2 = 0.8531802628868271 ====
# ==== Epoch: 12/1000 | test_F0_MAE = 0.6959277173485607 Hz | test_Phs_MAE = 2.053304974451661 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 13/1000 | train_loss = 0.05066180344671011 | train_correlation_R^2 = 0.9999886123237612 ====
# ==== Epoch: 13/1000 | train_F0_MAE = 0.016945857908576726 Hz | train_Phs_MAE = 0.09063116353005171 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 13/1000 | val_loss = 0.06400998971919762 | val_p_correlation^2 = 0.9999389722890671 ====
# ==== Epoch: 13/1000 | val_F0_MAE = 0.021608215734362602 Hz | val_Phs_MAE = 0.100737375440076 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 13/1000 | test_loss = 1.4718320513339713 | test_p_correlation^2 = 0.853128502513566 ====
# ==== Epoch: 13/1000 | test_F0_MAE = 0.6990222425162792 Hz | test_Phs_MAE = 2.0589645817950366 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 14/1000 | train_loss = 0.04954928014427423 | train_correlation_R^2 = 0.9999922899679285 ====
# ==== Epoch: 14/1000 | train_F0_MAE = 0.016314004892483355 Hz | train_Phs_MAE = 0.09371363632380962 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 14/1000 | val_loss = 0.07038049229359604 | val_p_correlation^2 = 0.9999359631585318 ====
# ==== Epoch: 14/1000 | val_F0_MAE = 0.022888497630134223 Hz | val_Phs_MAE = 0.12953044359572233 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 14/1000 | test_loss = 1.4739808306423947 | test_p_correlation^2 = 0.8531847279190349 ====
# ==== Epoch: 14/1000 | test_F0_MAE = 0.6939191017854027 Hz | test_Phs_MAE = 2.0808686098083853 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 15/1000 | train_loss = 0.049185567032545806 | train_correlation_R^2 = 0.9999893537074391 ====
# ==== Epoch: 15/1000 | train_F0_MAE = 0.016100966674275696 Hz | train_Phs_MAE = 0.0935580152645707 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 15/1000 | val_loss = 0.08126681225979701 | val_p_correlation^2 = 0.9998965898509986 ====
# ==== Epoch: 15/1000 | val_F0_MAE = 0.02958058035047725 Hz | val_Phs_MAE = 0.09876373889297246 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 15/1000 | test_loss = 1.4774313151761889 | test_p_correlation^2 = 0.8529407677861798 ====
# ==== Epoch: 15/1000 | test_F0_MAE = 0.7008785978639498 Hz | test_Phs_MAE = 2.1032594174817203 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 16/1000 | train_loss = 0.05100880676880479 | train_correlation_R^2 = 0.999990405535641 ====
# ==== Epoch: 16/1000 | train_F0_MAE = 0.017615200616419316 Hz | train_Phs_MAE = 0.07915131468325853 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 16/1000 | val_loss = 0.05098267011638381 | val_p_correlation^2 = 0.9999673375248564 ====
# ==== Epoch: 16/1000 | val_F0_MAE = 0.017527234831359238 Hz | val_Phs_MAE = 0.08329849303141236 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 16/1000 | test_loss = 1.4753281750194729 | test_p_correlation^2 = 0.8531461507636349 ====
# ==== Epoch: 16/1000 | test_F0_MAE = 0.6914308748608455 Hz | test_Phs_MAE = 2.095600434102118 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 17/1000 | train_loss = 0.050116970911622045 | train_correlation_R^2 = 0.9999879025497481 ====
# ==== Epoch: 17/1000 | train_F0_MAE = 0.017048091255128385 Hz | train_Phs_MAE = 0.08445561245083809 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 17/1000 | val_loss = 0.06822133710441994 | val_p_correlation^2 = 0.9999272473220535 ====
# ==== Epoch: 17/1000 | val_F0_MAE = 0.024982162702362986 Hz | val_Phs_MAE = 0.07597490040678531 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 17/1000 | test_loss = 1.4717703358605505 | test_p_correlation^2 = 0.8531011301534122 ====
# ==== Epoch: 17/1000 | test_F0_MAE = 0.6955929850582033 Hz | test_Phs_MAE = 2.0596320085003974 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 18/1000 | train_loss = 0.04668123112991452 | train_correlation_R^2 = 0.9999923781573622 ====
# ==== Epoch: 18/1000 | train_F0_MAE = 0.015554353995248675 Hz | train_Phs_MAE = 0.08233934335410595 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 18/1000 | val_loss = 0.07359316660344484 | val_p_correlation^2 = 0.9999451605514253 ====
# ==== Epoch: 18/1000 | val_F0_MAE = 0.024026992353610693 Hz | val_Phs_MAE = 0.15261695736274122 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 18/1000 | test_loss = 1.4784434753945097 | test_p_correlation^2 = 0.8527947022016495 ====
# ==== Epoch: 18/1000 | test_F0_MAE = 0.7032997020538896 Hz | test_Phs_MAE = 2.111026070870459 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 19/1000 | train_loss = 0.04665986344218254 | train_correlation_R^2 = 0.9999905956421606 ====
# ==== Epoch: 19/1000 | train_F0_MAE = 0.015665563787333667 Hz | train_Phs_MAE = 0.08243907611817121 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 19/1000 | val_loss = 0.04821096362589742 | val_p_correlation^2 = 0.9999692066693863 ====
# ==== Epoch: 19/1000 | val_F0_MAE = 0.015855745751410723 Hz | val_Phs_MAE = 0.08727543750591576 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 19/1000 | test_loss = 1.4761408511847258 | test_p_correlation^2 = 0.8530950361990135 ====
# ==== Epoch: 19/1000 | test_F0_MAE = 0.6914961527818814 Hz | test_Phs_MAE = 2.10301689235121 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 20/1000 | train_loss = 0.053813272919505835 | train_correlation_R^2 = 0.9999895362400443 ====
# ==== Epoch: 20/1000 | train_F0_MAE = 0.018767967224121093 Hz | train_Phs_MAE = 0.07972582396119833 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 20/1000 | val_loss = 0.06891315690922784 | val_p_correlation^2 = 0.999926503566051 ====
# ==== Epoch: 20/1000 | val_F0_MAE = 0.025079650487285107 Hz | val_Phs_MAE = 0.07656918931100518 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 20/1000 | test_loss = 1.479712621667888 | test_p_correlation^2 = 0.8533006623617807 ====
# ==== Epoch: 20/1000 | test_F0_MAE = 0.6828771303920075 Hz | test_Phs_MAE = 2.141513645425439 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 21/1000 | train_loss = 0.04785488059744239 | train_correlation_R^2 = 0.9999931507921265 ====
# ==== Epoch: 21/1000 | train_F0_MAE = 0.015817708047106863 Hz | train_Phs_MAE = 0.08490070804953576 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 21/1000 | val_loss = 0.04107648283485469 | val_p_correlation^2 = 0.9999813618643585 ====
# ==== Epoch: 21/1000 | val_F0_MAE = 0.013098775086924433 Hz | val_Phs_MAE = 0.08915337388962508 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 21/1000 | test_loss = 1.4795136904218233 | test_p_correlation^2 = 0.8531460905071261 ====
# ==== Epoch: 21/1000 | test_F0_MAE = 0.6878296477124095 Hz | test_Phs_MAE = 2.136388092197478 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 22/1000 | train_loss = 0.05166002755984664 | train_correlation_R^2 = 0.9999860418235483 ====
# ==== Epoch: 22/1000 | train_F0_MAE = 0.01789841504767537 Hz | train_Phs_MAE = 0.08004959113895893 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 22/1000 | val_loss = 0.05445266646282835 | val_p_correlation^2 = 0.999960108079234 ====
# ==== Epoch: 22/1000 | val_F0_MAE = 0.01910114182252437 Hz | val_Phs_MAE = 0.081277085211128 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 22/1000 | test_loss = 1.4804452592274173 | test_p_correlation^2 = 0.8529846088222078 ====
# ==== Epoch: 22/1000 | test_F0_MAE = 0.6929233821583912 Hz | test_Phs_MAE = 2.1394773602932693 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 23/1000 | train_loss = 0.05144239937886596 | train_correlation_R^2 = 0.9999896775282275 ====
# ==== Epoch: 23/1000 | train_F0_MAE = 0.017525279689580203 Hz | train_Phs_MAE = 0.08258461695164442 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 23/1000 | val_loss = 0.04963560603876249 | val_p_correlation^2 = 0.9999647693674348 ====
# ==== Epoch: 23/1000 | val_F0_MAE = 0.016824726812541484 Hz | val_Phs_MAE = 0.0854268561322242 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 23/1000 | test_loss = 1.4807673529298044 | test_p_correlation^2 = 0.8528195424378756 ====
# ==== Epoch: 23/1000 | test_F0_MAE = 0.6985283105466514 Hz | test_Phs_MAE = 2.135510983243585 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 24/1000 | train_loss = 0.051606043968349696 | train_correlation_R^2 = 0.9999862456480691 ====
# ==== Epoch: 24/1000 | train_F0_MAE = 0.01745820633135736 Hz | train_Phs_MAE = 0.08756098520010709 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 24/1000 | val_loss = 0.08590887539551477 | val_p_correlation^2 = 0.9998913217402938 ====
# ==== Epoch: 24/1000 | val_F0_MAE = 0.03234593589557335 Hz | val_Phs_MAE = 0.08431894038431346 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 24/1000 | test_loss = 1.4782486651232467 | test_p_correlation^2 = 0.8529865875317517 ====
# ==== Epoch: 24/1000 | test_F0_MAE = 0.6952483573588543 Hz | test_Phs_MAE = 2.114772075712681 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 25/1000 | train_loss = 0.051055062618106606 | train_correlation_R^2 = 0.9999885402900327 ====
# ==== Epoch: 25/1000 | train_F0_MAE = 0.017547004320658744 Hz | train_Phs_MAE = 0.08035937711596489 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 25/1000 | val_loss = 0.04720509276498342 | val_p_correlation^2 = 0.9999699736256541 ====
# ==== Epoch: 25/1000 | val_F0_MAE = 0.016141727336682378 Hz | val_Phs_MAE = 0.07892447257367895 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 25/1000 | test_loss = 1.4800626191580668 | test_p_correlation^2 = 0.8529313732284797 ====
# ==== Epoch: 25/1000 | test_F0_MAE = 0.6941300047812984 Hz | test_Phs_MAE = 2.1337901454493404 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 26/1000 | train_loss = 0.04612154489383102 | train_correlation_R^2 = 0.9999925025944459 ====
# ==== Epoch: 26/1000 | train_F0_MAE = 0.01560154503211379 Hz | train_Phs_MAE = 0.07764861360192299 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 26/1000 | val_loss = 0.06427245704532834 | val_p_correlation^2 = 0.9999558374798803 ====
# ==== Epoch: 26/1000 | val_F0_MAE = 0.0219295674120076 Hz | val_Phs_MAE = 0.11663255701586604 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 26/1000 | test_loss = 1.4863257273696362 | test_p_correlation^2 = 0.8527977947401857 ====
# ==== Epoch: 26/1000 | test_F0_MAE = 0.6991120248511433 Hz | test_Phs_MAE = 2.1851135535910724 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 27/1000 | train_loss = 0.050875456854701046 | train_correlation_R^2 = 0.9999871718003405 ====
# ==== Epoch: 27/1000 | train_F0_MAE = 0.017306746393442155 Hz | train_Phs_MAE = 0.08334025170654058 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 27/1000 | val_loss = 0.055722892377030805 | val_p_correlation^2 = 0.9999510674260796 ====
# ==== Epoch: 27/1000 | val_F0_MAE = 0.019521707986481486 Hz | val_Phs_MAE = 0.0786534611149691 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 27/1000 | test_loss = 1.4828804896064103 | test_p_correlation^2 = 0.8526151256224617 ====
# ==== Epoch: 27/1000 | test_F0_MAE = 0.705693194870837 Hz | test_Phs_MAE = 2.148152912955731 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 28/1000 | train_loss = 0.05083959119394422 | train_correlation_R^2 = 0.9999861263445706 ====
# ==== Epoch: 28/1000 | train_F0_MAE = 0.01706934687681496 Hz | train_Phs_MAE = 0.08850394494831562 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 28/1000 | val_loss = 0.0625611282640457 | val_p_correlation^2 = 0.9999517057537605 ====
# ==== Epoch: 28/1000 | val_F0_MAE = 0.01920652872789651 Hz | val_Phs_MAE = 0.13743469166755676 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 28/1000 | test_loss = 1.4834900304889307 | test_p_correlation^2 = 0.8525794605331364 ====
# ==== Epoch: 28/1000 | test_F0_MAE = 0.7063507655360736 Hz | test_Phs_MAE = 2.1528072629123924 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 29/1000 | train_loss = 0.0526154156960547 | train_correlation_R^2 = 0.9999808536971643 ====
# ==== Epoch: 29/1000 | train_F0_MAE = 0.018204439356923105 Hz | train_Phs_MAE = 0.08111788053065538 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 29/1000 | val_loss = 0.0451914166722272 | val_p_correlation^2 = 0.9999693048010609 ====
# ==== Epoch: 29/1000 | val_F0_MAE = 0.014785697682294995 Hz | val_Phs_MAE = 0.08201214154064655 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 29/1000 | test_loss = 1.484821562519297 | test_p_correlation^2 = 0.8526949514814222 ====
# ==== Epoch: 29/1000 | test_F0_MAE = 0.7010585968871601 Hz | test_Phs_MAE = 2.1711470046527683 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 30/1000 | train_loss = 0.04507714487612247 | train_correlation_R^2 = 0.9999919780807939 ====
# ==== Epoch: 30/1000 | train_F0_MAE = 0.015191651475615799 Hz | train_Phs_MAE = 0.07608234774321318 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 30/1000 | val_loss = 0.05696047998433642 | val_p_correlation^2 = 0.9999529197420263 ====
# ==== Epoch: 30/1000 | val_F0_MAE = 0.020446649902034552 Hz | val_Phs_MAE = 0.07633944767806679 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 30/1000 | test_loss = 1.4858202761150896 | test_p_correlation^2 = 0.8528926251405266 ====
# ==== Epoch: 30/1000 | test_F0_MAE = 0.6933549414402805 Hz | test_Phs_MAE = 2.185791570242494 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 31/1000 | train_loss = 0.048528923261910675 | train_correlation_R^2 = 0.9999903604248358 ====
# ==== Epoch: 31/1000 | train_F0_MAE = 0.01676930676214397 Hz | train_Phs_MAE = 0.07572624556720257 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 31/1000 | val_loss = 0.049544176723946294 | val_p_correlation^2 = 0.9999617560605568 ====
# ==== Epoch: 31/1000 | val_F0_MAE = 0.017103615671396257 Hz | val_Phs_MAE = 0.07665546532243024 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 31/1000 | test_loss = 1.48512497775862 | test_p_correlation^2 = 0.8527007156040071 ====
# ==== Epoch: 31/1000 | test_F0_MAE = 0.696476946240291 Hz | test_Phs_MAE = 2.1753918671905996 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 32/1000 | train_loss = 0.0466316956654191 | train_correlation_R^2 = 0.9999920363365575 ====
# ==== Epoch: 32/1000 | train_F0_MAE = 0.015695492597296835 Hz | train_Phs_MAE = 0.07936615258455276 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 32/1000 | val_loss = 0.04062948713250807 | val_p_correlation^2 = 0.9999817218270255 ====
# ==== Epoch: 32/1000 | val_F0_MAE = 0.012415432914160193 Hz | val_Phs_MAE = 0.09499155631102621 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 32/1000 | test_loss = 1.4860954793486745 | test_p_correlation^2 = 0.8528892214679937 ====
# ==== Epoch: 32/1000 | test_F0_MAE = 0.6927164895590395 Hz | test_Phs_MAE = 2.1895058517195283 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 33/1000 | train_loss = 0.05952129691839218 | train_correlation_R^2 = 0.9999871873694208 ====
# ==== Epoch: 33/1000 | train_F0_MAE = 0.020073709385469554 Hz | train_Phs_MAE = 0.1001753944158554 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 33/1000 | val_loss = 0.0718009630398883 | val_p_correlation^2 = 0.9999293817824991 ====
# ==== Epoch: 33/1000 | val_F0_MAE = 0.022523488288279624 Hz | val_Phs_MAE = 0.14681077347509564 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 33/1000 | test_loss = 1.4886303891062271 | test_p_correlation^2 = 0.8525445858759712 ====
# ==== Epoch: 33/1000 | test_F0_MAE = 0.7067343451445922 Hz | test_Phs_MAE = 2.1988236811980606 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 34/1000 | train_loss = 0.058429656531661746 | train_correlation_R^2 = 0.9999759382683341 ====
# ==== Epoch: 34/1000 | train_F0_MAE = 0.020151626132428647 Hz | train_Phs_MAE = 0.09215699896216392 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 34/1000 | val_loss = 0.05478865078187664 | val_p_correlation^2 = 0.9999671880578764 ====
# ==== Epoch: 34/1000 | val_F0_MAE = 0.01726440051663667 Hz | val_Phs_MAE = 0.11992791042290628 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 34/1000 | test_loss = 1.482864389544353 | test_p_correlation^2 = 0.8528612433815409 ====
# ==== Epoch: 34/1000 | test_F0_MAE = 0.6945904306680896 Hz | test_Phs_MAE = 2.1585483277887105 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 35/1000 | train_loss = 0.05520117830485106 | train_correlation_R^2 = 0.9999817055795024 ====
# ==== Epoch: 35/1000 | train_F0_MAE = 0.019333778964355588 Hz | train_Phs_MAE = 0.08252980500459671 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 35/1000 | val_loss = 0.04782581091675092 | val_p_correlation^2 = 0.9999756481627732 ====
# ==== Epoch: 35/1000 | val_F0_MAE = 0.014090973322279751 Hz | val_Phs_MAE = 0.12333127845171839 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 35/1000 | test_loss = 1.4814762180936523 | test_p_correlation^2 = 0.8529645919197199 ====
# ==== Epoch: 35/1000 | test_F0_MAE = 0.6904942700811662 Hz | test_Phs_MAE = 2.151413696628064 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 36/1000 | train_loss = 0.05298000555485487 | train_correlation_R^2 = 0.9999798465707392 ====
# ==== Epoch: 36/1000 | train_F0_MAE = 0.018253671852871776 Hz | train_Phs_MAE = 0.08275094363838434 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 36/1000 | val_loss = 0.07215030502804438 | val_p_correlation^2 = 0.9999192246351031 ====
# ==== Epoch: 36/1000 | val_F0_MAE = 0.0267747225696221 Hz | val_Phs_MAE = 0.07847146689007059 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 36/1000 | test_loss = 1.484171620086301 | test_p_correlation^2 = 0.8526464359632987 ====
# ==== Epoch: 36/1000 | test_F0_MAE = 0.7008003131351433 Hz | test_Phs_MAE = 2.1617863453105093 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 37/1000 | train_loss = 0.043287063650786876 | train_correlation_R^2 = 0.9999917734815608 ====
# ==== Epoch: 37/1000 | train_F0_MAE = 0.014361571222543716 Hz | train_Phs_MAE = 0.0778375319391489 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 37/1000 | val_loss = 0.032001278679279495 | val_p_correlation^2 = 0.9999867614709816 ====
# ==== Epoch: 37/1000 | val_F0_MAE = 0.009821252510882915 Hz | val_Phs_MAE = 0.06999987062299624 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 37/1000 | test_loss = 1.4868692438891158 | test_p_correlation^2 = 0.8528060362479837 ====
# ==== Epoch: 37/1000 | test_F0_MAE = 0.6919022344127297 Hz | test_Phs_MAE = 2.197151597432792 Degree ====
# =======================================================================================================================
# best model loss is 0.03200127867928 at epoch 37
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 38/1000 | train_loss = 0.05099563030526042 | train_correlation_R^2 = 0.99998682037942 ====
# ==== Epoch: 38/1000 | train_F0_MAE = 0.017631678944453597 Hz | train_Phs_MAE = 0.07827814128249884 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 38/1000 | val_loss = 0.03953927116406703 | val_p_correlation^2 = 0.9999800254618368 ====
# ==== Epoch: 38/1000 | val_F0_MAE = 0.012582982529886067 Hz | val_Phs_MAE = 0.0803175834575668 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 38/1000 | test_loss = 1.4837960920078912 | test_p_correlation^2 = 0.8529620988512138 ====
# ==== Epoch: 38/1000 | test_F0_MAE = 0.6887562368717045 Hz | test_Phs_MAE = 2.1732897266969085 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 39/1000 | train_loss = 0.050091257076710465 | train_correlation_R^2 = 0.9999878192731675 ====
# ==== Epoch: 39/1000 | train_F0_MAE = 0.0172338174469769 Hz | train_Phs_MAE = 0.07900369446724653 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 39/1000 | val_loss = 0.042644612463744125 | val_p_correlation^2 = 0.9999752673002736 ====
# ==== Epoch: 39/1000 | val_F0_MAE = 0.013553506653755903 Hz | val_Phs_MAE = 0.08633869580645114 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 39/1000 | test_loss = 1.487327465269016 | test_p_correlation^2 = 0.8528372687765932 ====
# ==== Epoch: 39/1000 | test_F0_MAE = 0.6920593893099576 Hz | test_Phs_MAE = 2.2018204127326606 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 40/1000 | train_loss = 0.05283363420516252 | train_correlation_R^2 = 0.999984333983605 ====
# ==== Epoch: 40/1000 | train_F0_MAE = 0.017662593605928124 Hz | train_Phs_MAE = 0.09225707978010178 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 40/1000 | val_loss = 0.09846376731849159 | val_p_correlation^2 = 0.9998424306393423 ====
# ==== Epoch: 40/1000 | val_F0_MAE = 0.0371199151808396 Hz | val_Phs_MAE = 0.0836433713878505 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 40/1000 | test_loss = 1.4889744232459925 | test_p_correlation^2 = 0.8524081749964569 ====
# ==== Epoch: 40/1000 | test_F0_MAE = 0.7095378037802875 Hz | test_Phs_MAE = 2.1939067524150015 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 41/1000 | train_loss = 0.046735900733619926 | train_correlation_R^2 = 0.9999895342238596 ====
# ==== Epoch: 41/1000 | train_F0_MAE = 0.015732969641685485 Hz | train_Phs_MAE = 0.07962511360645294 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 41/1000 | val_loss = 0.04590257832398493 | val_p_correlation^2 = 0.99997115741267 ====
# ==== Epoch: 41/1000 | val_F0_MAE = 0.015585307911038399 Hz | val_Phs_MAE = 0.07922211765125393 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 41/1000 | test_loss = 1.490839645652566 | test_p_correlation^2 = 0.8527116251551009 ====
# ==== Epoch: 41/1000 | test_F0_MAE = 0.6953086310820654 Hz | test_Phs_MAE = 2.2288362918272613 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 42/1000 | train_loss = 0.044767299871891736 | train_correlation_R^2 = 0.9999915658356863 ====
# ==== Epoch: 42/1000 | train_F0_MAE = 0.01485679863486439 Hz | train_Phs_MAE = 0.08092326499521732 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 42/1000 | val_loss = 0.03801336411379452 | val_p_correlation^2 = 0.999982699592428 ====
# ==== Epoch: 42/1000 | val_F0_MAE = 0.011770579544827343 Hz | val_Phs_MAE = 0.08374988082190976 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 42/1000 | test_loss = 1.4863195728457068 | test_p_correlation^2 = 0.8528351786142203 ====
# ==== Epoch: 42/1000 | test_F0_MAE = 0.6902871314398944 Hz | test_Phs_MAE = 2.193266888964921 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 43/1000 | train_loss = 0.052101271040737626 | train_correlation_R^2 = 0.9999847364165011 ====
# ==== Epoch: 43/1000 | train_F0_MAE = 0.01792695070616901 Hz | train_Phs_MAE = 0.08192576184868812 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 43/1000 | val_loss = 0.0774702230293915 | val_p_correlation^2 = 0.9999072806579792 ====
# ==== Epoch: 43/1000 | val_F0_MAE = 0.02747975011076778 Hz | val_Phs_MAE = 0.09848349409317597 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 43/1000 | test_loss = 1.4887044469176325 | test_p_correlation^2 = 0.8524890934551399 ====
# ==== Epoch: 43/1000 | test_F0_MAE = 0.705211305623874 Hz | test_Phs_MAE = 2.198109256606549 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 44/1000 | train_loss = 0.055981796458363535 | train_correlation_R^2 = 0.9999851590631117 ====
# ==== Epoch: 44/1000 | train_F0_MAE = 0.018956843419000505 Hz | train_Phs_MAE = 0.09319424208253622 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 44/1000 | val_loss = 0.06367562593094772 | val_p_correlation^2 = 0.9999451932149926 ====
# ==== Epoch: 44/1000 | val_F0_MAE = 0.02258768359106034 Hz | val_Phs_MAE = 0.09419331844337285 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 44/1000 | test_loss = 1.4892285816613584 | test_p_correlation^2 = 0.8526620340818025 ====
# ==== Epoch: 44/1000 | test_F0_MAE = 0.6991974709127098 Hz | test_Phs_MAE = 2.2109796326234936 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 45/1000 | train_loss = 0.045236647464334964 | train_correlation_R^2 = 0.999991879286656 ====
# ==== Epoch: 45/1000 | train_F0_MAE = 0.01498990538995713 Hz | train_Phs_MAE = 0.08184724610298871 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 45/1000 | val_loss = 0.0380273091475101 | val_p_correlation^2 = 0.999984447492363 ====
# ==== Epoch: 45/1000 | val_F0_MAE = 0.011549850578419864 Hz | val_Phs_MAE = 0.08878153011761605 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 45/1000 | test_loss = 1.49051112458203 | test_p_correlation^2 = 0.8528768829588449 ====
# ==== Epoch: 45/1000 | test_F0_MAE = 0.6871372089721263 Hz | test_Phs_MAE = 2.2331371440812946 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 46/1000 | train_loss = 0.042682061288505796 | train_correlation_R^2 = 0.9999920075230123 ====
# ==== Epoch: 46/1000 | train_F0_MAE = 0.014263704791665078 Hz | train_Phs_MAE = 0.07466307003051043 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 46/1000 | val_loss = 0.0527401923249854 | val_p_correlation^2 = 0.9999710249016747 ====
# ==== Epoch: 46/1000 | val_F0_MAE = 0.01735140132624656 Hz | val_Phs_MAE = 0.10860559226153418 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 46/1000 | test_loss = 1.4899523465074598 | test_p_correlation^2 = 0.852813593188951 ====
# ==== Epoch: 46/1000 | test_F0_MAE = 0.691579850750044 Hz | test_Phs_MAE = 2.224258643977344 Degree ====
# ...
# ==== Epoch: 77/1000 | val_loss = 0.08276358337889542 | val_p_correlation^2 = 0.9999040332698813 ====
# ==== Epoch: 77/1000 | val_F0_MAE = 0.031041054769884793 Hz | val_Phs_MAE = 0.0917706459183246 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 77/1000 | test_loss = 1.493411015165504 | test_p_correlation^2 = 0.852766190855866 ====
# ==== Epoch: 77/1000 | test_F0_MAE = 0.6843062647739425 Hz | test_Phs_MAE = 2.256779859662056 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 78/1000 | train_loss = 0.06057920653373003 | train_correlation_R^2 = 0.9999693643469569 ====
# ==== Epoch: 78/1000 | train_F0_MAE = 0.02156595586799085 Hz | train_Phs_MAE = 0.08588187236338854 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 78/1000 | val_loss = 0.06033695757991518 | val_p_correlation^2 = 0.999945589078894 ====
# ==== Epoch: 78/1000 | val_F0_MAE = 0.02117602686583996 Hz | val_Phs_MAE = 0.0841591980997473 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 78/1000 | test_loss = 1.5023780808127485 | test_p_correlation^2 = 0.8525208447412248 ====
# ==== Epoch: 78/1000 | test_F0_MAE = 0.6966907801681664 Hz | test_Phs_MAE = 2.3284830413386226 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 79/1000 | train_loss = 0.05524953784421086 | train_correlation_R^2 = 0.9999816990513475 ====
# ==== Epoch: 79/1000 | train_F0_MAE = 0.01884961860254407 Hz | train_Phs_MAE = 0.08984279986470937 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 79/1000 | val_loss = 0.11901733817951754 | val_p_correlation^2 = 0.999790702008125 ====
# ==== Epoch: 79/1000 | val_F0_MAE = 0.04639872369263321 Hz | val_Phs_MAE = 0.07173376354994253 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 79/1000 | test_loss = 1.4960133945662528 | test_p_correlation^2 = 0.8527918459913362 ====
# ==== Epoch: 79/1000 | test_F0_MAE = 0.6910446178948041 Hz | test_Phs_MAE = 2.2719920845106243 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 80/1000 | train_loss = 0.053170676715672015 | train_correlation_R^2 = 0.9999808891244913 ====
# ==== Epoch: 80/1000 | train_F0_MAE = 0.018368662660941483 Hz | train_Phs_MAE = 0.08508802566677331 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 80/1000 | val_loss = 0.08755784921916347 | val_p_correlation^2 = 0.9998631498916483 ====
# ==== Epoch: 80/1000 | val_F0_MAE = 0.033864344196394086 Hz | val_Phs_MAE = 0.060152814885601404 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 80/1000 | test_loss = 1.4969752089316026 | test_p_correlation^2 = 0.852610492823237 ====
# ==== Epoch: 80/1000 | test_F0_MAE = 0.6958260104823858 Hz | test_Phs_MAE = 2.2778737937733533 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 81/1000 | train_loss = 0.0477506154589355 | train_correlation_R^2 = 0.9999906888786562 ====
# ==== Epoch: 81/1000 | train_F0_MAE = 0.015975171481259168 Hz | train_Phs_MAE = 0.08376899056136608 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 81/1000 | val_loss = 0.06509217576228547 | val_p_correlation^2 = 0.9999290299838126 ====
# ==== Epoch: 81/1000 | val_F0_MAE = 0.02210411308053881 Hz | val_Phs_MAE = 0.1009212775058113 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 81/1000 | test_loss = 1.501166091343388 | test_p_correlation^2 = 0.8526218312680934 ====
# ==== Epoch: 81/1000 | test_F0_MAE = 0.6958533965225797 Hz | test_Phs_MAE = 2.3189563290700317 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 82/1000 | train_loss = 0.05848019307479262 | train_correlation_R^2 = 0.9999777095350234 ====
# ==== Epoch: 82/1000 | train_F0_MAE = 0.020424514533951877 Hz | train_Phs_MAE = 0.08534929025918245 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 82/1000 | val_loss = 0.04408589334813587 | val_p_correlation^2 = 0.9999728467387012 ====
# ==== Epoch: 82/1000 | val_F0_MAE = 0.011471429648809135 Hz | val_Phs_MAE = 0.12329017291776836 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 82/1000 | test_loss = 1.4925314617706462 | test_p_correlation^2 = 0.8530237280170567 ====
# ==== Epoch: 82/1000 | test_F0_MAE = 0.6818046961836517 Hz | test_Phs_MAE = 2.256391080074012 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 83/1000 | train_loss = 0.04165916034951806 | train_correlation_R^2 = 0.9999900777580396 ====
# ==== Epoch: 83/1000 | train_F0_MAE = 0.014088374846614897 Hz | train_Phs_MAE = 0.07056962076574563 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 83/1000 | val_loss = 0.028768006998157944 | val_p_correlation^2 = 0.9999898368332137 ====
# ==== Epoch: 83/1000 | val_F0_MAE = 0.008252218282781542 Hz | val_Phs_MAE = 0.07080527053959668 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 83/1000 | test_loss = 1.4954016578129958 | test_p_correlation^2 = 0.852968607659432 ====
# ==== Epoch: 83/1000 | test_F0_MAE = 0.6806439124452881 Hz | test_Phs_MAE = 2.2829642558544876 Degree ====
# =======================================================================================================================
# best model loss is 0.02876800699816 at epoch 83
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 84/1000 | train_loss = 0.04819467408582568 | train_correlation_R^2 = 0.9999850202450058 ====
# ==== Epoch: 84/1000 | train_F0_MAE = 0.016976204877719284 Hz | train_Phs_MAE = 0.06875455848872662 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 84/1000 | val_loss = 0.0652055487359612 | val_p_correlation^2 = 0.9999505375470275 ====
# ==== Epoch: 84/1000 | val_F0_MAE = 0.02159906375547871 Hz | val_Phs_MAE = 0.12629920375160872 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 84/1000 | test_loss = 1.503406457511708 | test_p_correlation^2 = 0.8527595317063663 ====
# ==== Epoch: 84/1000 | test_F0_MAE = 0.6826396391661838 Hz | test_Phs_MAE = 2.348703975368291 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 85/1000 | train_loss = 0.05431827049702406 | train_correlation_R^2 = 0.9999821939285264 ====
# ==== Epoch: 85/1000 | train_F0_MAE = 0.018709651241078974 Hz | train_Phs_MAE = 0.08537193305790425 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 85/1000 | val_loss = 0.07202403422651696 | val_p_correlation^2 = 0.9999217134354625 ====
# ==== Epoch: 85/1000 | val_F0_MAE = 0.02604514832701534 Hz | val_Phs_MAE = 0.09071403878415003 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 85/1000 | test_loss = 1.4978311006431468 | test_p_correlation^2 = 0.8530245527715064 ====
# ==== Epoch: 85/1000 | test_F0_MAE = 0.6787889130115509 Hz | test_Phs_MAE = 2.303130866281688 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 86/1000 | train_loss = 0.048077922482043504 | train_correlation_R^2 = 0.9999905924395953 ====
# ==== Epoch: 86/1000 | train_F0_MAE = 0.016792625384405256 Hz | train_Phs_MAE = 0.06947791390120983 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 86/1000 | val_loss = 0.03854699907437316 | val_p_correlation^2 = 0.9999784672203278 ====
# ==== Epoch: 86/1000 | val_F0_MAE = 0.012313136697281152 Hz | val_Phs_MAE = 0.07340994294220582 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 86/1000 | test_loss = 1.4955947556653992 | test_p_correlation^2 = 0.8529396162012771 ====
# ==== Epoch: 86/1000 | test_F0_MAE = 0.6823502829549835 Hz | test_Phs_MAE = 2.2826577287539838 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 87/1000 | train_loss = 0.05938934575766325 | train_correlation_R^2 = 0.9999738791528165 ====
# ==== Epoch: 87/1000 | train_F0_MAE = 0.021055046115070582 Hz | train_Phs_MAE = 0.0821796377375722 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 87/1000 | val_loss = 0.05648045373885543 | val_p_correlation^2 = 0.9999648801515076 ====
# ==== Epoch: 87/1000 | val_F0_MAE = 0.01976692477753386 Hz | val_Phs_MAE = 0.09342412086203694 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 87/1000 | test_loss = 1.5009283922715113 | test_p_correlation^2 = 0.8528783764778537 ====
# ==== Epoch: 87/1000 | test_F0_MAE = 0.6818268778328784 Hz | test_Phs_MAE = 2.3293918387144803 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 88/1000 | train_loss = 0.0505376716889441 | train_correlation_R^2 = 0.9999824756493938 ====
# ==== Epoch: 88/1000 | train_F0_MAE = 0.017277923668734728 Hz | train_Phs_MAE = 0.07995550587773323 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 88/1000 | val_loss = 0.07751029283602838 | val_p_correlation^2 = 0.9999182218344393 ====
# ==== Epoch: 88/1000 | val_F0_MAE = 0.028957627744413912 Hz | val_Phs_MAE = 0.07977327998168766 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 88/1000 | test_loss = 1.4963084089793264 | test_p_correlation^2 = 0.8529411507341309 ====
# ==== Epoch: 88/1000 | test_F0_MAE = 0.6818220438566059 Hz | test_Phs_MAE = 2.2861468066573143 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 89/1000 | train_loss = 0.05411003703251481 | train_correlation_R^2 = 0.9999743260887519 ====
# ==== Epoch: 89/1000 | train_F0_MAE = 0.019175326055847108 Hz | train_Phs_MAE = 0.07500925224274396 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 89/1000 | val_loss = 0.04236557133278984 | val_p_correlation^2 = 0.999972155373204 ====
# ==== Epoch: 89/1000 | val_F0_MAE = 0.013320974510163069 Hz | val_Phs_MAE = 0.08397478853818029 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 89/1000 | test_loss = 1.4930831080067437 | test_p_correlation^2 = 0.8529055129059382 ====
# ==== Epoch: 89/1000 | test_F0_MAE = 0.6845882382281124 Hz | test_Phs_MAE = 2.2586739879995585 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# Tesing begins...
# ==== Epoch: 90/1000 | train_loss = 0.04733812855556607 | train_correlation_R^2 = 0.9999889486831203 ====
# ==== Epoch: 90/1000 | train_F0_MAE = 0.016286820601671935 Hz | train_Phs_MAE = 0.0744834292307496 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 90/1000 | val_loss = 0.06588081278270692 | val_p_correlation^2 = 0.9999479768279863 ====
# ==== Epoch: 90/1000 | val_F0_MAE = 0.023098327328450977 Hz | val_Phs_MAE = 0.10720965789444745 Degree ====
# ---------------------------------------------------------------------------------------------------------------------
# ==== Epoch: 90/1000 | test_loss = 1.500744221754372 | test_p_correlation^2 = 0.8527940502359634 ====
# ==== Epoch: 90/1000 | test_F0_MAE = 0.6831514442199841 Hz | test_Phs_MAE = 2.3239505533427 Degree ====
# =======================================================================================================================
# Training begins...
# Validation begins...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-7a6cac3bda8b> in <module>
#     364
#     365             # if epoch<=100: use the initial predefined template; if epoch>100: update the template (real_template=median(real_spectra_corrected))
# --> 366             loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1))
#     367             loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1))
#     368
#
# /home/raphael/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /home/raphael/anaconda3/lib/python3.7/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#      94
#      95     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# ---> 96         return F.l1_loss(input, target, reduction=self.reduction)
#      97
#      98
#
# /home/raphael/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in l1_loss(input, target, size_average, reduce, reduction)
#    2896
#    2897     expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2898     return torch._C._nn.l1_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2899
#    2900
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation Supervised#

# %% [markdown]
# ### OFF Data

# %%
# ============ testing dataset ============
N_test = 2000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = F0_all[18000:20000] 
Phs_test = Phs_all[18000:20000] 

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = noisy_Real_spectUnAligned_and_spectAligned_tensor_all[18000:20000,:,:]

Real_FidsAligned_tensor_test = Real_FidsAligned_tensor_all[18000:20000,:,:]

Imag_FidsAligned_tensor_test = Imag_FidsAligned_tensor_all[18000:20000,:,:]

Real_FidsUnAligned_tensor_test = Real_FidsUnAligned_tensor_all[18000:20000,:,:]

Imag_FidsUnAligned_tensor_test = Imag_FidsUnAligned_tensor_all[18000:20000,:,:]

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([2000, 1, 2048])
# F0_test torch.Size([2000])
# Phs_test torch.Size([2000])

# %%
# define the model 
model_n = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best.pt'

data_save_F0='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_F0_OFF_pred.npy'
data_save_Phs='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_Phs_OFF_pred.npy'

JETCNN = JETCNN_L
JETCNN.load_state_dict(torch.load(model_n))
criterion = L1Loss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-4)
test_epoch_loss = []
test_epoch_F0_MAE = [] ##
test_epoch_Phs_MAE = [] ##
test_epoch_F0_SD=[]
test_epoch_Phs_SD=[]
test_epoch_p_correlation = []
F0_ON_predicted=[]
Phs_ON_predicted=[]

# where to calculate the spectral loss
range1 = 1100
range2 = 1500

fid_range1 = 0
fid_range2 = 512
    
test_loss = []
test_F0_MAE = [] 
test_Phs_MAE = [] 
test_F0_SD=[]
test_Phs_SD=[]
test_F0_pred=[]
test_Phs_pred=[]
test_p_correlation = []

#######################################################
######################## Test #########################
#######################################################
print('Testing begins...')
for batch_index, data in enumerate(test_loader):
    
    # If GPU is available, move the data to the GPU for faster computation.
    if cuda:
        # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
        noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
        Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
        F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##


        # *** Set the model to train mode ***
        JETCNN.eval()
        
        # *** forward + backward + optimize ***
        deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)

        Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
        Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)

        # *** Define loss between the real part of deformed spectra and the real part of the true spectra
        # apply the deformation
        F0_pred_tensor = torch.clone(F0_tensor)
        Phs_pred_tensor = torch.clone(Phs_tensor)
        for kk in range(len(deformation_predicted[:,0])):

            freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
            deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
            F0_pred_tensor[kk] = deformation_predicted[kk,0] 
            Phs_pred_tensor[kk] = deformation_predicted[kk,1] 

            Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                            ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
            Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                            ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)
            
            F0_ON_predicted.append(deformation_predicted[kk,0])
            Phs_ON_predicted.append(deformation_predicted[kk,1])


        # compute the loss
        F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) ##
        F0_tensor_vector = torch.flatten(F0_tensor) ##
        Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) ##
        Phs_tensor_vector = torch.flatten(Phs_tensor) ##

        # fids
        Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])

       
        loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
        loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 

        loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
        loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)

        # fid correlation loss
        v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
        v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
        p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
        loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)

        v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
        v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
        p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
        loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag) # Correlation loss = 1-R^2 

        loss = (lamda)*(loss_fid_MSE_real + loss_fid_MSE_imag)+(1-lamda)*(loss_p_correlation_real + loss_p_correlation_imag)

        # compute the MAE of offsets
        F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
        Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##

        # compute the correlation
        fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
        fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()

        Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
        Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))

        r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
        p_correlation = r[0,1]
        
        # store the train_loss and tran_p_correlation
        test_F0_pred.append(F0_pred_tensor_vector.cpu().data.item())
        test_Phs_pred.append(Phs_pred_tensor_vector.cpu().data.item())
        test_loss.append(loss.cpu().data.item())
        test_F0_MAE.append(F0_MAE.cpu().data.item()) 
        test_Phs_MAE.append(Phs_MAE.cpu().data.item()) 
        test_p_correlation.append(p_correlation)
        
np.save(data_save_F0, test_F0_pred)
np.save(data_save_Phs,test_Phs_pred)
test_epoch_loss.append(np.mean(test_loss))
test_epoch_F0_MAE.append(np.mean(test_F0_MAE)) 
test_epoch_Phs_MAE.append(np.mean(test_Phs_MAE)) 
test_epoch_F0_SD.append(np.std(test_F0_MAE)) 
test_epoch_Phs_SD.append(np.std(test_Phs_MAE)) 
test_epoch_p_correlation.append(np.mean(test_p_correlation))

print("---------------------------------------------------------------------------------------------------------------------")
print(" test_loss = {} | test_p_correlation^2 = {} ====".format(test_epoch_loss[-1], \
                                                                                 test_epoch_p_correlation[-1]*test_epoch_p_correlation[-1]))
print(" test_F0_MAE = {} +- {} Hz | test_Phs_MAE = {} +- {} Degree ====".format(test_epoch_F0_MAE[-1],test_epoch_F0_SD[-1], \
                                                                                     test_epoch_Phs_MAE[-1],test_epoch_Phs_SD[-1]))

print("=======================================================================================================================")

prediction_F0_OFF=test_F0_pred
prediction_Phs_OFF=test_Phs_pred
# Out:
# Testing begins...
# ---------------------------------------------------------------------------------------------------------------------
#  test_loss = 0.0021121325316635193 | test_p_correlation^2 = 0.7858095127886702 ====
#  test_F0_MAE = 0.6779523724433966 +- 0.8834113955142042 Hz | test_Phs_MAE = 2.3667028571516275 +- 2.615695391357552 Degree ====
# =======================================================================================================================

# %%
# saving MAE
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_F0_OFF_MAE.npy', test_F0_MAE)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_Phs_OFF_MAE.npy', test_Phs_MAE)

# %% [markdown]
# ### ON Data

# %%
# ============ testing dataset ============
N_test = 2000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = F0_all[38000:40000] 
Phs_test = Phs_all[38000:40000] 

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = noisy_Real_spectUnAligned_and_spectAligned_tensor_all[38000:40000,:,:]

Real_FidsAligned_tensor_test = Real_FidsAligned_tensor_all[38000:40000,:,:]

Imag_FidsAligned_tensor_test = Imag_FidsAligned_tensor_all[38000:40000,:,:]

Real_FidsUnAligned_tensor_test = Real_FidsUnAligned_tensor_all[38000:40000,:,:]

Imag_FidsUnAligned_tensor_test = Imag_FidsUnAligned_tensor_all[38000:40000,:,:]

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([2000, 1, 2048])
# F0_test torch.Size([2000])
# Phs_test torch.Size([2000])

# %%
# define the model 
model_n = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best.pt'

data_save_F0='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_F0_ON_pred.npy'
data_save_Phs='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_Phs_ON_pred.npy'

JETCNN = JETCNN_L
JETCNN.load_state_dict(torch.load(model_n))
criterion = L1Loss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-4)
test_epoch_loss = []
test_epoch_F0_MAE = [] ##
test_epoch_Phs_MAE = [] ##
test_epoch_F0_SD=[]
test_epoch_Phs_SD=[]
test_epoch_p_correlation = []
F0_ON_predicted=[]
Phs_ON_predicted=[]

# where to calculate the spectral loss
range1 = 1100
range2 = 1500

fid_range1 = 0
fid_range2 = 512
    
test_loss = []
test_F0_MAE = [] ##
test_Phs_MAE = [] ##
test_F0_SD=[]
test_Phs_SD=[]
test_F0_pred=[]
test_Phs_pred=[]
test_p_correlation = []

#######################################################
######################## Test #########################
#######################################################
print('Testing begins...')
for batch_index, data in enumerate(test_loader):
    
    # If GPU is available, move the data to the GPU for faster computation.
    if cuda:
        
        # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
        noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
        Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
        F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##

        
        # *** Set the model to train mode ***
        JETCNN.eval()
        
        # *** forward + backward + optimize ***
        deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)

        Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
        Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)


        # *** Define loss between the real part of deformed spectra and the real part of the true spectra
        # apply the deformation
        F0_pred_tensor = torch.clone(F0_tensor)
        Phs_pred_tensor = torch.clone(Phs_tensor)
        for kk in range(len(deformation_predicted[:,0])):

            freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
            deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
            F0_pred_tensor[kk] = deformation_predicted[kk,0] ##
            Phs_pred_tensor[kk] = deformation_predicted[kk,1] ##


            Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                            ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
            Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                            ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)

            
            F0_ON_predicted.append(deformation_predicted[kk,0])
            Phs_ON_predicted.append(deformation_predicted[kk,1])

        # compute the loss
        F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
        F0_tensor_vector = torch.flatten(F0_tensor) 
        Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
        Phs_tensor_vector = torch.flatten(Phs_tensor) 

        # fids
        Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])


        loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
        loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 

        loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
        loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)

   
        # fid correlation loss
        v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
        v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
        p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
        loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)

        v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
        v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
        p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
        loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag) # Correlation loss = 1-R^2 

        loss = (lamda)*(loss_fid_MSE_real + loss_fid_MSE_imag)+(1-lamda)*(loss_p_correlation_real + loss_p_correlation_imag)

        # compute the MAE of offsets
        F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
        Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##

        # compute the correlation
        fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
        fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()

        Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
        Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))

        r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
        p_correlation = r[0,1]

        # store the train_loss and tran_p_correlation
        test_F0_pred.append(F0_pred_tensor_vector.cpu().data.item())
        test_Phs_pred.append(Phs_pred_tensor_vector.cpu().data.item())
        test_loss.append(loss.cpu().data.item())
        test_F0_MAE.append(F0_MAE.cpu().data.item()) ##
        test_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
        test_p_correlation.append(p_correlation)
np.save(data_save_F0, test_F0_pred)
np.save(data_save_Phs,test_Phs_pred)
test_epoch_loss.append(np.mean(test_loss))
test_epoch_F0_MAE.append(np.mean(test_F0_MAE)) ##
test_epoch_Phs_MAE.append(np.mean(test_Phs_MAE)) ##
test_epoch_F0_SD.append(np.std(test_F0_MAE)) ##
test_epoch_Phs_SD.append(np.std(test_Phs_MAE)) ##
test_epoch_p_correlation.append(np.mean(test_p_correlation))

print("---------------------------------------------------------------------------------------------------------------------")
print(" test_loss = {} | test_p_correlation^2 = {} ====".format(test_epoch_loss[-1], \
                                                                                 test_epoch_p_correlation[-1]*test_epoch_p_correlation[-1]))
print(" test_F0_MAE = {} +- {} Hz | test_Phs_MAE = {} +- {} Degree ====".format(test_epoch_F0_MAE[-1],test_epoch_F0_SD[-1], \
                                                                                     test_epoch_Phs_MAE[-1],test_epoch_Phs_SD[-1]))

print("=======================================================================================================================")

prediction_F0_ON=test_F0_pred
prediction_Phs_ON=test_Phs_pred
# Out:
# Testing begins...
# ---------------------------------------------------------------------------------------------------------------------
#  test_loss = 0.0021137939924155942 | test_p_correlation^2 = 0.740990708629063 ====
#  test_F0_MAE = 0.6701964642703533 +- 0.8665144777400836 Hz | test_Phs_MAE = 2.297079775556922 +- 2.42909624200766 Degree ====
# =======================================================================================================================

# %%
# saving MAE
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_F0_ON_MAE.npy', test_F0_MAE)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_Phs_ON_MAE.npy', test_Phs_MAE)

# %%
from scipy.io import savemat, loadmat
data_path = '/media/sail/Elements/JET_CNN/DL-FPC/JETCNNmodel/data/'

Complex_FidsUnAligned_OFF=Complex_FidsUnAligned[18000:20000,:]
print(Complex_FidsUnAligned_OFF.shape)

time = np.arange(2048)/2000
Complex_FidsUnAligned_OFF=np.transpose(Complex_FidsUnAligned_OFF)

# Perform Frequency Correction
FidsUnAlignedOFFPhase = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)
spectUnAlignedOFFPhase = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)

for kk in range(2000):
    freqPart = np.exp(1j * time * prediction_F0_OFF[kk] * 2 * cm.pi)
    FidsUnAlignedOFFPhase[:,kk] = np.multiply(Complex_FidsUnAligned_OFF[:,kk], freqPart)
    spectUnAlignedOFFPhase[:,kk] = fftshift(fft(FidsUnAlignedOFFPhase[:,kk]))

    scaleOFF = np.max(np.squeeze(np.abs(spectUnAlignedOFFPhase[:,kk])))
    spectUnAlignedOFFPhase[:,kk] = spectUnAlignedOFFPhase[:,kk]/scaleOFF
    
validationDataOFFPhase = np.real(spectUnAlignedOFFPhase[512:-512,:])
validationDataOFFPhase = np.transpose(validationDataOFFPhase)

# Perform Phase Correction
FidsOFFCorrected = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)
spectOFFCorrected = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)

for kk in range(2000):
    phasePart = np.exp(1j * prediction_Phs_OFF[kk] * cm.pi / 180)
    FidsOFFCorrected[:,kk] = np.multiply(FidsUnAlignedOFFPhase[:,kk], phasePart)
    spectOFFCorrected[:,kk] = fftshift(fft(FidsOFFCorrected[:,kk]))
    
Complex_FidsUnAligned_ON=Complex_FidsUnAligned[38000:40000,:]
Complex_FidsUnAligned_OFF.shape
time = np.arange(2048)/2000
Complex_FidsUnAligned_ON=np.transpose(Complex_FidsUnAligned_ON)
    
# Perform Frequency Correction
FidsUnAlignedONPhase = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
spectUnAlignedONPhase = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
for kk in range(2000): 
    freqPart = np.exp(1j * time * prediction_F0_ON[kk] * 2 * cm.pi)
    FidsUnAlignedONPhase[:,kk] = np.multiply(Complex_FidsUnAligned_ON[:,kk], freqPart)
    spectUnAlignedONPhase[:,kk] = fftshift(fft(FidsUnAlignedONPhase[:,kk]))

    scaleON = np.max(np.squeeze(np.abs(spectUnAlignedONPhase[:,kk])))
    spectUnAlignedONPhase[:,kk] = spectUnAlignedONPhase[:,kk]/scaleON
    
# Perform Phase Correction
FidsONCorrected = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
spectONCorrected = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
for kk in range(2000):
    phasePart = np.exp(1j * prediction_Phs_ON[kk] * cm.pi / 180)
    FidsONCorrected[:,kk] = np.multiply(FidsUnAlignedONPhase[:,kk], phasePart)
    spectONCorrected[:,kk] = fftshift(fft(FidsONCorrected[:,kk]))
    
#defining ground truths
F0_testON = F0_all[38000:40000]
Phs_testON = Phs_all[38000:40000]    
F0_testOFF = F0_all[18000:20000]
Phs_testOFF = Phs_all[18000:20000]

error_F0_OFF = F0_testOFF.numpy()-np.transpose(prediction_F0_OFF)*-1
print("OFF F0: Mean Absolute Error: ", np.mean(np.absolute(error_F0_OFF)), " +- ", np.std(np.absolute(error_F0_OFF)))

error_F0_ON = F0_testON.numpy()-np.transpose(prediction_F0_ON)*-1
print("ON F0: Mean Absolute Error: ", np.mean(np.absolute(error_F0_ON)), " +- ", np.std(np.absolute(error_F0_ON)))

error_Phs_OFF = Phs_testOFF.numpy()-np.transpose(np.array(prediction_Phs_OFF))*-1
print("OFF Phs: Mean Absolute Error: ", np.mean(np.absolute(error_Phs_OFF)), " +- ", np.std(np.absolute(error_Phs_OFF)))

error_Phs_ON = Phs_testON.numpy()-np.transpose(np.array(prediction_Phs_ON))*-1
print("ON Phs: Mean Absolute Error: ", np.mean(np.absolute(error_Phs_ON)), " +- ", np.std(np.absolute(error_Phs_ON)))
# Out:
# (2000, 2048)
# OFF F0: Mean Absolute Error:  0.6779523723027668  +-  0.8834113951407403
# ON F0: Mean Absolute Error:  0.6701964640871156  +-  0.8665144773225361
# OFF Phs: Mean Absolute Error:  2.366702857080847  +-  2.6156953912583223
# ON Phs: Mean Absolute Error:  2.29707977529522  +-  2.4290962419308078

# %%
# On-Off mismatch computation
On_F0_error=np.transpose(prediction_F0_ON)*-1-F0_testON.numpy()
Off_F0_error=np.transpose(prediction_F0_OFF)*-1-F0_testOFF.numpy()
ON_OFF_F0_mismatch=abs(On_F0_error-Off_F0_error)
ON_OFF_F0_mismatch_mean=np.mean(ON_OFF_F0_mismatch)
ON_OFF_F0_mismatch_std=np.std(ON_OFF_F0_mismatch)

On_Phs_error=np.transpose(prediction_Phs_ON)*-1-Phs_testON.numpy()
Off_Phs_error=np.transpose(prediction_Phs_OFF)*-1-Phs_testOFF.numpy()
ON_OFF_Phs_mismatch=abs(On_Phs_error-Off_Phs_error)
ON_OFF_Phs_mismatch_mean=np.mean(ON_OFF_Phs_mismatch)
ON_OFF_Phs_mismatch_std=np.std(ON_OFF_Phs_mismatch)

print("ON-OFF F0 mismatch: ", ON_OFF_F0_mismatch_mean, " +- ", ON_OFF_F0_mismatch_std)
print("ON-OFF Phs mismatch: ", ON_OFF_Phs_mismatch_mean, " +- ", ON_OFF_Phs_mismatch_std)

# saving data
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_F0_ON_OFF_Mismatching_MAE.npy', ON_OFF_F0_mismatch)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_Phs_ON_OFF_Mismatching_MAE.npy', ON_OFF_Phs_mismatch)
# Out:
# ON-OFF F0 mismatch:  1.0666222203390208  +-  1.0606029352761068
# ON-OFF Phs mismatch:  2.986724091867916  +-  2.6621499826289936

# %%
save_model_figurename1='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Figures/DLSR_wNoise1d5dB_wlb_scatterplot.png'
save_model_figurename2='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Figures/DLSR_wNoise1d5dB_wlb_DiffSpectra.png'

# defining residual offsets
F0_residual_offset_OFF=F0_testOFF.numpy()-np.transpose(prediction_F0_OFF)*-1
F0_residual_offset_ON=F0_testON.numpy()-np.transpose(prediction_F0_ON)*-1
Phs_residual_offset_OFF=Phs_testOFF.numpy()-np.transpose(prediction_Phs_OFF)*-1
Phs_residual_offset_ON=Phs_testON.numpy()-np.transpose(prediction_Phs_ON)*-1
F0_residual_offset=np.concatenate((F0_residual_offset_OFF,F0_residual_offset_ON),0)
Phs_residual_offset=np.concatenate((Phs_residual_offset_OFF,Phs_residual_offset_ON),0)

Fids_test=Fids[:,np.r_[18000:20000, 38000:40000]]

# Fids and Spec for the Unaligned data
FidsUnAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
FidsUnAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectUnAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectUnAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)

# Spec for the Aligned data
spectAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)

for kk in range(len(Fids_test[0,:])):
    Fids_kk = Fids_test[:,kk]
    
    # get the phase and freq offsets
    phasePart = np.exp(-1j * Phs_residual_offset[kk] * cm.pi / 180)
    freqPart = np.exp(-1j * time * F0_residual_offset[kk] * 2 * cm.pi)
    correction = np.multiply(freqPart,phasePart)
    
    # apply the phase and freq offsets on the FID after LB
    FidsUnAligned[:,kk] = np.multiply(Fids_kk, correction) 
    FidsUnAlignedPhase[:,kk] = np.multiply(Fids_kk, phasePart) 
    
    # get the single spectra of the FID with freq and phase offsets and LB 
    spectUnAligned[:,kk] = fftshift(fft(FidsUnAligned[:,kk]))
    spectUnAlignedPhase[:,kk] = fftshift(fft(FidsUnAlignedPhase[:,kk]))
    
    # get the single spectra of the FID withOUT freq and phase offsets and LB 
    spectAligned[:,kk] = fftshift(fft(Fids_kk))
    spectAlignedPhase[:,kk] = fftshift(fft(Fids_kk))
    
    # get the Normalized single spectra of the FID with freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectUnAligned[:,kk])))
    spectUnAligned[:,kk] = spectUnAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectUnAlignedPhase[:,kk])))
    spectUnAlignedPhase[:,kk] = spectUnAlignedPhase[:,kk]/scalePh
    
    # get the Normalized single spectra of the FID withOUT freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectAligned[:,kk])))
    spectAligned[:,kk] = spectAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectAlignedPhase[:,kk])))
    spectAlignedPhase[:,kk] = spectAlignedPhase[:,kk]/scalePh


# %% Creating plots

# scatter plot
fontsize=14

plt.rcParams['axes.linewidth']=2 
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='30'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

fig = plt.figure(figsize=(8.67, 4.4))

ax = plt.subplot(121)   

ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)     
ax.tick_params(width=1,color='k',length=4)
plt.yticks(np.arange(-5,5.1, step=5),['-5','0','5'], fontsize=fontsize)
plt.xticks(np.arange(-20,21,step=20),['-20','0','20'], fontsize=fontsize)
plt.ylabel('DL - True / Hz', fontname="Arial", fontsize=fontsize)
plt.xlabel('True / Hz', fontname="Arial", fontsize=fontsize)
plt.xlim((-20,21))
plt.ylim((-5, 5))
plt.plot(F0_testOFF.numpy(), np.squeeze(np.array(prediction_F0_OFF)*-1) - np.transpose(F0_testOFF.numpy()), 'ko', markersize=1)
plt.plot(F0_testON.numpy(), np.squeeze(np.array(prediction_F0_ON)*-1) - np.transpose(F0_testON.numpy()), 'ko', markersize=1)
plt.title('Frequency Offsets', fontname="Arial", fontsize=18)

t1 = np.mean(np.squeeze(np.array(prediction_F0_OFF)) - np.transpose(F0_testOFF.numpy()))
t2 = np.mean(np.squeeze(np.array(prediction_F0_ON)) - np.transpose(F0_testON.numpy()))
t3 = (t1 + t2)/2
e1 = np.std(np.squeeze(np.array(prediction_F0_OFF)) - np.transpose(F0_testOFF.numpy()))
e2 = np.std(np.squeeze(np.array(prediction_F0_ON)) - np.transpose(F0_testON.numpy()))
e3 = (e1 + e2)/2

rcParams['mathtext.default'] = 'regular'
     
ax = plt.subplot(122)
plt.rcParams['axes.linewidth']=2 
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='30'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)     
ax.tick_params(width=1,color='k',length=4)
plt.yticks(np.arange(-25,25.1,step=25),['-25','0','25'], fontsize=fontsize)
plt.xticks(np.arange(-90,91,step=90),['-90','0','90'], fontsize=fontsize)
plt.ylabel('DL - True /' r' $\degree $', fontname="Arial", fontsize=fontsize)
plt.xlabel('True / ' r'$\degree $', fontname="Arial", fontsize=fontsize)
plt.xlim((-90,91))
plt.ylim((-25, 25))
plt.plot(Phs_testOFF.numpy(), np.squeeze(np.array(prediction_Phs_OFF)*-1) - np.transpose(Phs_testOFF.numpy()), 'ko', markersize=1)
plt.plot(Phs_testON.numpy(), np.squeeze(np.array(prediction_Phs_ON)*-1) - np.transpose(Phs_testON.numpy()), 'ko', markersize=1)
plt.title('Phase Offsets', fontname="Arial", fontsize=18)

t1 = np.mean(np.squeeze(np.array(prediction_Phs_OFF)*-1) - Phs_testOFF.numpy())
t2 = np.mean(np.squeeze(np.array(prediction_Phs_ON)*-1) - Phs_testON.numpy())
t3 = (t1 + t2)/2
e1 = np.std(np.squeeze(np.array(prediction_Phs_OFF)*-1) - Phs_testOFF.numpy())
e2 = np.std(np.squeeze(np.array(prediction_Phs_ON)*-1) - Phs_testON.numpy())
e3 = (e1 + e2)/2
plt.subplots_adjust(wspace=0.6,left=0.18, right=0.98, top=0.8, bottom=0.25)
plt.savefig(save_model_figurename1,format='png', dpi=300,bbox_inches='tight')  
    
# Diff spectra and residuals
freqRange = 2000/127.7
ppm = np.flip((np.arange(1,2048 + 1)) / 2048 * freqRange + 4.68 - freqRange/2)
xlim = [1, 4.2]

plt.rcParams['axes.linewidth']=2
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='11'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

fig = plt.figure(figsize=(8.67, 4.5))
ax = plt.subplot(111)
ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)   
ax.tick_params(width=1,color='k',length=4)
plt.xticks(np.arange(1,5,step=1), fontsize=fontsize)
ax.set_yticklabels([])
ax.axes.get_yaxis().set_visible(False)  

lw = 0.5
spectAlignedOFF=spectAligned[:,:2000]
spectAlignedON=spectAligned[:,2000:]

spectOFFCorrected=spectUnAligned[:,:2000]
spectONCorrected=spectUnAligned[:,2000:]

k=9
spectONCorrected_real_single = spectONCorrected[:,k].real
spectOFFCorrected_real_single = spectOFFCorrected[:,k].real
spectAlignedON_real_single = spectAlignedON[:,k].real
spectAlignedOFF_real_single = spectAlignedOFF[:,k].real

plt.plot(ppm, spectONCorrected_real_single - spectOFFCorrected_real_single - (spectAlignedON_real_single - spectAlignedOFF_real_single) + 0.014,'b',linewidth=0.5)
plt.plot(ppm, spectONCorrected_real_single - spectOFFCorrected_real_single,'r',linewidth=lw)
plt.plot(ppm, spectAlignedON_real_single - spectAlignedOFF_real_single,'k',linewidth=lw)

plt.xlabel('ppm', fontname="Arial", fontsize=fontsize)
plt.xlim((xlim))
plt.gca().invert_xaxis()
plt.ylim((-0.02,0.03))
plt.legend(['CNN-SR - True [Single Residual Spetra]','CNN-SR','True'],loc="lower left")


plt.subplots_adjust(left=0.03, right=0.98, top=0.95,bottom=0.25)
plt.savefig(save_model_figurename2,format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ### GABA and Glx Residual

# %%
# Diff Spectra
freqRange = 2000/127.7
ppm = np.flip((np.arange(1,2048 + 1)) / 2048 * freqRange + 4.68 - freqRange/2)

GABA_Int = np.where((ppm <= 3.20) & (ppm >= 2.80))
Glx_Int= np.where((ppm >= 3.55) & (ppm <= 3.95))

################ GABA ##############################
spectDiffCorrected = spectONCorrected - spectOFFCorrected 
spectAlignedDiff = spectAlignedON - spectAlignedOFF

spectDiffCorrected_GABA=spectDiffCorrected[GABA_Int[0][0]:GABA_Int[0][-1]]
spectAlignedDiff_GABA=spectAlignedDiff[GABA_Int[0][0]:GABA_Int[0][-1]]

spectDiff_residue_GABA = spectDiffCorrected_GABA - spectAlignedDiff_GABA
spectDiff_residue_MAE_mean_GABA = np.mean(np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
spectDiff_residue_MAE_STD_GABA = np.std(np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
print("GABA Mean Absolute Error: ", spectDiff_residue_MAE_mean_GABA, " +- ", spectDiff_residue_MAE_STD_GABA)

################ Glx ##############################
spectDiffCorrected_Glx=spectDiffCorrected[Glx_Int[0][0]:Glx_Int[0][-1]]
spectAlignedDiff_Glx=spectAlignedDiff[Glx_Int[0][0]:Glx_Int[0][-1]]

spectDiff_residue_Glx = spectDiffCorrected_Glx - spectAlignedDiff_Glx
spectDiff_residue_MAE_mean_Glx = np.mean(np.mean(np.absolute(spectDiff_residue_Glx),axis=0))
spectDiff_residue_MAE_STD_Glx = np.std(np.mean(np.absolute(spectDiff_residue_Glx),axis=0))
print("Glx Mean Absolute Error: ", spectDiff_residue_MAE_mean_Glx, " +- ", spectDiff_residue_MAE_STD_Glx)
# Out:
# GABA Mean Absolute Error:  0.004376832308690675  +-  0.0021448161981240665
# Glx Mean Absolute Error:  0.004044894313919128  +-  0.001738381713739056

# %%
# saving data
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_spectra_DIFF_Residual_GABA_MAE.npy', np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_1d5dB_wLB_spectra_DIFF_Residual_Glx_MAE.npy', np.mean(np.absolute(spectDiff_residue_Glx),axis=0))

# %% [markdown]
# ## **JET_CNN Testing optimization with Spectral Loss only (Semi-Supervised)**

# %%
# define the model
JETCNN = JETCNN_L

# define loss and optimizer
criterion = MSELoss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-5)

# define parameters
EPOCHS = 1000

train_epoch_loss = []
train_epoch_F0_MAE = [] 
train_epoch_Phs_MAE = [] 
train_epoch_p_correlation = []

val_epoch_loss = []
val_epoch_F0_MAE = [] 
val_epoch_Phs_MAE = [] 
val_epoch_p_correlation = []
val_epoch_loss_input = []
val_epoch_p_correlation_input = []

test_epoch_loss = []
test_epoch_F0_MAE = [] 
test_epoch_Phs_MAE = [] 
test_epoch_p_correlation = []

# early stopping
early_stop = 0
patience = 50

# path
best_JETCNN_pretrained_path = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best_testing.pt'
best_JETCNN_path = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best_testing.pt'
last_JETCNN_path = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_last_testing.pt'

# Loading pretrained model 
JETCNN.load_state_dict(torch.load(best_JETCNN_pretrained_path))

# where to calculate the spectral loss
range1 = 0
range2 = 2048

fid_range1 = 0
fid_range2 = 1024 
    
for epoch in range(EPOCHS):
     
    train_loss = []
    train_F0_MAE = [] 
    train_Phs_MAE = [] 
    train_p_correlation = []
    
    val_loss = []
    val_F0_MAE = [] 
    val_Phs_MAE = [] 
    val_p_correlation = []
    
    test_loss = []
    test_F0_MAE = [] 
    test_Phs_MAE = [] 
    test_p_correlation = []
    
    val_loss_input = []
    val_p_correlation_input = []

    #######################################################
    ####################### Train #########################
    #######################################################
    print('Testing dataset unsupervised optmization begins...')
    for batch_index, data in enumerate(test_loader):
        
        # If GPU is available, move the data to the GPU for faster computation.
        if cuda:
            
            # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor, F0_tensor,Phs_tensor]
            noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
            Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
            F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##
            
            # *** Set the model to train mode ***
            JETCNN.train()
            
            # *** zero the parameter gradients ***
            optimizer.zero_grad()
            
            # *** forward + backward + optimize ***
            
            #predict deformation from real spectra unaligned and aligned
            deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)
            
            #cloning real and imag fids unaligned tensor
            Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)
            
            Real_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_pred_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Real_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            Imag_spec_tensor = torch.clone(Real_FidsUnAligned_tensor)
            
            # *** Define loss between the real part of deformed spectra and the real part of the true spectra
            
            # cloning the ground truths (initializing)
            F0_pred_tensor = torch.clone(F0_tensor)
            Phs_pred_tensor = torch.clone(Phs_tensor)
            
            for kk in range(len(deformation_predicted[:,0])):
                
                #introducing real deformations
                freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                #introducing imaginary deformations
                freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
                phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)
                
                #defining deformations from the offsets
                deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
                deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
                #constructing tensor for the deformations
                F0_pred_tensor[kk] = deformation_predicted[kk,0] 
                Phs_pred_tensor[kk] = deformation_predicted[kk,1] 
                
                #contructing real and imaging fids prediction tensor
                Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                                ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
                Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                                ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)
                
                Real_pred_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                Imag_pred_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_pred_tensor[kk,:,:]+1j*Imag_FidsAligned_pred_tensor[kk,:,:])))
                
                Real_spec_tensor[kk,:,:] = torch.real(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
                Imag_spec_tensor[kk,:,:] = torch.imag(torch.fft.fftshift(torch.fft.fft(Real_FidsAligned_tensor[kk,:,:]+1j*Imag_FidsAligned_tensor[kk,:,:])))
            
            # flattening
            F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
            F0_tensor_vector = torch.flatten(F0_tensor) 
            Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
            Phs_tensor_vector = torch.flatten(Phs_tensor) 
             
            # defining fids real and imag predicted and truth tensors
            Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
            Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])
            
            # specs
            Real_pred_spec_tensor_vector = torch.flatten(Real_pred_spec_tensor[:,:,range1:range2])
            Real_spec_tensor_vector = torch.flatten(Real_spec_tensor[:,:,range1:range2])
            
            Imag_pred_spec_tensor_vector = torch.flatten(Imag_pred_spec_tensor[:,:,range1:range2])
            Imag_spec_tensor_vector = torch.flatten(Imag_spec_tensor[:,:,range1:range2])
                        
            #predicted f0 and ph and truth f0 and phs loss computation
            loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
            loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 
            
            #predicted and truth fids loss computation
            loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
            loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)
            
            #predicted and truth spectra loss computation
            loss_spec_MSE_real = criterion(Real_pred_spec_tensor_vector, Real_spec_tensor_vector) 
            loss_spec_MSE_imag = criterion(Imag_pred_spec_tensor_vector, Imag_spec_tensor_vector)
            
            # fids correlation loss real and imag
            v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
            v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
            p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
            loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)
            v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
            v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
            p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
            loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag)
            
            # spectra correlation loss real and imag
            v_Real_pred_spec = Real_pred_spec_tensor_vector - torch.mean(Real_pred_spec_tensor_vector)
            v_Real_spec = Real_spec_tensor_vector - torch.mean(Real_spec_tensor_vector)
            spec_p_correlation_real = torch.sum(v_Real_pred_spec * v_Real_spec) / (torch.sqrt(torch.sum(v_Real_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Real_spec ** 2)))
            spec_loss_p_correlation_real = 1-torch.mul(spec_p_correlation_real,spec_p_correlation_real)
            v_Imag_pred_spec = Imag_pred_spec_tensor_vector - torch.mean(Imag_pred_spec_tensor_vector)
            v_Imag_spec = Imag_spec_tensor_vector - torch.mean(Imag_spec_tensor_vector)
            spec_p_correlation_imag = torch.sum(v_Imag_pred_spec * v_Imag_spec) / (torch.sqrt(torch.sum(v_Imag_pred_spec ** 2)) * torch.sqrt(torch.sum(v_Imag_spec ** 2)))
            spec_loss_p_correlation_imag = 1-torch.mul(spec_p_correlation_imag,spec_p_correlation_imag)
            
            loss = loss_spec_MSE_real + loss_spec_MSE_imag  # spectral loss only
        
            # compute the MAE of the tensors                             
            F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  
            Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  
            
            # compute the fids real and imag
            fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
            fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
            fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()
            
            #real spectra and predicted spectra
            Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
            Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))
            
            #correlation of spectras
            r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
            p_correlation = r[0,1]
            
            if epoch == 100 and batch_index == 1:
                plt.figure()
                plt.plot(Real_spec[range1:range2])
                plt.figure()
                plt.plot(Real_pred_spec[range1:range2])
                plt.plot(Real_spec[range1:range2])

            # backpropagate the loss
            loss.backward()
            
            # update the parameters
            optimizer.step()
            
            # store the train_loss and tran_p_correlation
            train_loss.append(loss.cpu().data.item())
            train_F0_MAE.append(F0_MAE.cpu().data.item()) ##
            train_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
            train_p_correlation.append(p_correlation)
    
    
    train_epoch_loss.append(np.mean(train_loss))
    train_epoch_F0_MAE.append(np.mean(train_F0_MAE)) ##
    train_epoch_Phs_MAE.append(np.mean(train_Phs_MAE)) ##
    train_epoch_p_correlation.append(np.mean(train_p_correlation))
    
    
    print("==== Epoch: {}/{} | testing_loss = {} | testing_correlation_R^2 = {} ====".format(epoch+1, EPOCHS, train_epoch_loss[-1], \
                                                                                         train_epoch_p_correlation[-1]*train_epoch_p_correlation[-1]))
    print("==== Epoch: {}/{} | testing_F0_MAE = {} Hz | testing_Phs_MAE = {} Degree ====".format(epoch+1, EPOCHS, train_epoch_F0_MAE[-1], \
                                                                                         train_epoch_Phs_MAE[-1]))
    
    print("=======================================================================================================================")
    
    # Make sure we save the best and last unets.
    if epoch == 0:
        best_JETCNN_loss = train_epoch_loss[0]
    if train_epoch_loss[-1] < best_JETCNN_loss:
        best_JETCNN_loss = train_epoch_loss[-1]
        best_epoch = epoch
        best_JETCNN = JETCNN.state_dict()
        print(f'best model loss is {best_JETCNN_loss:0.14f} at epoch {epoch+1}' )
        torch.save(best_JETCNN, best_JETCNN_path)
    if (epoch == EPOCHS - 1):
        last_JETCNN = JETCNN.state_dict()
        torch.save(last_JETCNN, last_JETCNN_path)

    # Early stop 
    if (early_stop == 1):
        if (len(val_epoch_loss) > patience):
            if (np.min(val_epoch_loss[0:-patience+1]) <= np.min(val_epoch_loss[-patience:])):
                print('Validation loss stop decreasing. Stop training.')
                last_JETCNN = JETCNN.state_dict()
                torch.save(last_JETCNN, last_JETCNN_path)
                break
# Out:
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 1/1000 | testing_loss = 0.002606894305726701 | testing_correlation_R^2 = 0.8670105139781629 ====
# ==== Epoch: 1/1000 | testing_F0_MAE = 0.04794783059135079 Hz | testing_Phs_MAE = 0.318337584733963 Degree ====
# =======================================================================================================================
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 2/1000 | testing_loss = 0.0026068917503443314 | testing_correlation_R^2 = 0.8670107540533076 ====
# ==== Epoch: 2/1000 | testing_F0_MAE = 0.047906691864132885 Hz | testing_Phs_MAE = 0.31799630196392537 Degree ====
# =======================================================================================================================
# best model loss is 0.00260689175034 at epoch 2
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 3/1000 | testing_loss = 0.002606890072990602 | testing_correlation_R^2 = 0.8670109062264347 ====
# ==== Epoch: 3/1000 | testing_F0_MAE = 0.047867951668798925 Hz | testing_Phs_MAE = 0.31775074963271616 Degree ====
# =======================================================================================================================
# best model loss is 0.00260689007299 at epoch 3
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 4/1000 | testing_loss = 0.0026068884066772924 | testing_correlation_R^2 = 0.8670110582251672 ====
# ==== Epoch: 4/1000 | testing_F0_MAE = 0.04783106876537204 Hz | testing_Phs_MAE = 0.31757672572880985 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688840668 at epoch 4
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 5/1000 | testing_loss = 0.0026068867947531514 | testing_correlation_R^2 = 0.8670112051667308 ====
# ==== Epoch: 5/1000 | testing_F0_MAE = 0.04779332403466106 Hz | testing_Phs_MAE = 0.3173785837851465 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688679475 at epoch 5
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 6/1000 | testing_loss = 0.0026068852694069093 | testing_correlation_R^2 = 0.8670113440995959 ====
# ==== Epoch: 6/1000 | testing_F0_MAE = 0.047754776056855915 Hz | testing_Phs_MAE = 0.3171863912679255 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688526941 at epoch 6
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 7/1000 | testing_loss = 0.0026068837359041553 | testing_correlation_R^2 = 0.8670114795983744 ====
# ==== Epoch: 7/1000 | testing_F0_MAE = 0.047719141479581596 Hz | testing_Phs_MAE = 0.31700660387799146 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688373590 at epoch 7
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 8/1000 | testing_loss = 0.0026068824075743675 | testing_correlation_R^2 = 0.867011604238664 ====
# ==== Epoch: 8/1000 | testing_F0_MAE = 0.04768702803552151 Hz | testing_Phs_MAE = 0.31685781123116613 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688240757 at epoch 8
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 9/1000 | testing_loss = 0.002606880949612638 | testing_correlation_R^2 = 0.8670117318980254 ====
# ==== Epoch: 9/1000 | testing_F0_MAE = 0.047647331647574905 Hz | testing_Phs_MAE = 0.316696128372103 Degree ====
# =======================================================================================================================
# best model loss is 0.00260688094961 at epoch 9
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 10/1000 | testing_loss = 0.002606879606457234 | testing_correlation_R^2 = 0.8670118540165382 ====
# ==== Epoch: 10/1000 | testing_F0_MAE = 0.04761517149955034 Hz | testing_Phs_MAE = 0.3164891969971359 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687960646 at epoch 10
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 11/1000 | testing_loss = 0.0026068783375392 | testing_correlation_R^2 = 0.8670119736963555 ====
# ==== Epoch: 11/1000 | testing_F0_MAE = 0.047586750458925964 Hz | testing_Phs_MAE = 0.31633501111343504 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687833754 at epoch 11
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 12/1000 | testing_loss = 0.002606876982721296 | testing_correlation_R^2 = 0.8670120906944153 ====
# ==== Epoch: 12/1000 | testing_F0_MAE = 0.047551496725529434 Hz | testing_Phs_MAE = 0.31615098229423166 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687698272 at epoch 12
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 13/1000 | testing_loss = 0.002606875748391495 | testing_correlation_R^2 = 0.8670122028039711 ====
# ==== Epoch: 13/1000 | testing_F0_MAE = 0.04752130825445056 Hz | testing_Phs_MAE = 0.3160000347532332 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687574839 at epoch 13
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 14/1000 | testing_loss = 0.0026068745318103977 | testing_correlation_R^2 = 0.8670123142640657 ====
# ==== Epoch: 14/1000 | testing_F0_MAE = 0.047494334500283 Hz | testing_Phs_MAE = 0.31585816577449444 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687453181 at epoch 14
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 15/1000 | testing_loss = 0.002606873309026643 | testing_correlation_R^2 = 0.8670124281925703 ====
# ==== Epoch: 15/1000 | testing_F0_MAE = 0.047467896461486817 Hz | testing_Phs_MAE = 0.3156995502896607 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687330903 at epoch 15
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 16/1000 | testing_loss = 0.0026068720624389525 | testing_correlation_R^2 = 0.8670125360944259 ====
# ==== Epoch: 16/1000 | testing_F0_MAE = 0.047436243925243614 Hz | testing_Phs_MAE = 0.31557188066467645 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687206244 at epoch 16
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 17/1000 | testing_loss = 0.002606870857091124 | testing_correlation_R^2 = 0.8670126443782856 ====
# ==== Epoch: 17/1000 | testing_F0_MAE = 0.047408802535384896 Hz | testing_Phs_MAE = 0.31541493103280666 Degree ====
# =======================================================================================================================
# best model loss is 0.00260687085709 at epoch 17
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 18/1000 | testing_loss = 0.002606869676978569 | testing_correlation_R^2 = 0.867012750867233 ====
# ==== Epoch: 18/1000 | testing_F0_MAE = 0.04738069663196802 Hz | testing_Phs_MAE = 0.3152678307853639 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686967698 at epoch 18
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 19/1000 | testing_loss = 0.0026068685057614653 | testing_correlation_R^2 = 0.8670128560320508 ====
# ==== Epoch: 19/1000 | testing_F0_MAE = 0.047352801017463204 Hz | testing_Phs_MAE = 0.31513744819536804 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686850576 at epoch 19
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 20/1000 | testing_loss = 0.0026068673532672086 | testing_correlation_R^2 = 0.8670129607951256 ====
# ==== Epoch: 20/1000 | testing_F0_MAE = 0.04732712044939399 Hz | testing_Phs_MAE = 0.3150072637088597 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686735327 at epoch 20
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 21/1000 | testing_loss = 0.0026068661357623313 | testing_correlation_R^2 = 0.8670130694058915 ====
# ==== Epoch: 21/1000 | testing_F0_MAE = 0.04729695294052363 Hz | testing_Phs_MAE = 0.31485401455685497 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686613576 at epoch 21
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 22/1000 | testing_loss = 0.002606865028212994 | testing_correlation_R^2 = 0.8670131683304907 ====
# ==== Epoch: 22/1000 | testing_F0_MAE = 0.04727113652601838 Hz | testing_Phs_MAE = 0.3147136765681207 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686502821 at epoch 22
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 23/1000 | testing_loss = 0.0026068639394870806 | testing_correlation_R^2 = 0.867013266951365 ====
# ==== Epoch: 23/1000 | testing_F0_MAE = 0.04724636888876557 Hz | testing_Phs_MAE = 0.3145967037715018 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686393949 at epoch 23
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 24/1000 | testing_loss = 0.002606862825201926 | testing_correlation_R^2 = 0.8670133679572205 ====
# ==== Epoch: 24/1000 | testing_F0_MAE = 0.047220122307538984 Hz | testing_Phs_MAE = 0.31445152540877463 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686282520 at epoch 24
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 25/1000 | testing_loss = 0.002606861707216325 | testing_correlation_R^2 = 0.8670134687166814 ====
# ==== Epoch: 25/1000 | testing_F0_MAE = 0.04719178054109216 Hz | testing_Phs_MAE = 0.31433452616259455 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686170722 at epoch 25
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 26/1000 | testing_loss = 0.0026068606093477306 | testing_correlation_R^2 = 0.8670135698807798 ====
# ==== Epoch: 26/1000 | testing_F0_MAE = 0.04716532645747065 Hz | testing_Phs_MAE = 0.3141870420984924 Degree ====
# =======================================================================================================================
# best model loss is 0.00260686060935 at epoch 26
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 27/1000 | testing_loss = 0.0026068595484763576 | testing_correlation_R^2 = 0.8670136662977385 ====
# ==== Epoch: 27/1000 | testing_F0_MAE = 0.047139434408396484 Hz | testing_Phs_MAE = 0.31407934145629407 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685954848 at epoch 27
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 28/1000 | testing_loss = 0.0026068584772935706 | testing_correlation_R^2 = 0.867013762605071 ====
# ==== Epoch: 28/1000 | testing_F0_MAE = 0.047114131458103656 Hz | testing_Phs_MAE = 0.31394905641674997 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685847729 at epoch 28
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 29/1000 | testing_loss = 0.00260685739048931 | testing_correlation_R^2 = 0.8670138602846496 ====
# ==== Epoch: 29/1000 | testing_F0_MAE = 0.047087905287742614 Hz | testing_Phs_MAE = 0.31380633515119555 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685739049 at epoch 29
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 30/1000 | testing_loss = 0.002606856377980563 | testing_correlation_R^2 = 0.8670139514737153 ====
# ==== Epoch: 30/1000 | testing_F0_MAE = 0.047062529664486645 Hz | testing_Phs_MAE = 0.31367956395447255 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685637798 at epoch 30
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 31/1000 | testing_loss = 0.0026068554207674096 | testing_correlation_R^2 = 0.867014038227773 ====
# ==== Epoch: 31/1000 | testing_F0_MAE = 0.0470377063639462 Hz | testing_Phs_MAE = 0.3135746876001358 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685542077 at epoch 31
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 32/1000 | testing_loss = 0.002606854347246383 | testing_correlation_R^2 = 0.867014136970193 ====
# ==== Epoch: 32/1000 | testing_F0_MAE = 0.047010960590094325 Hz | testing_Phs_MAE = 0.3134569704532623 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685434725 at epoch 32
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 33/1000 | testing_loss = 0.0026068533121880256 | testing_correlation_R^2 = 0.867014230008468 ====
# ==== Epoch: 33/1000 | testing_F0_MAE = 0.04698098327592015 Hz | testing_Phs_MAE = 0.31333539412170647 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685331219 at epoch 33
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 34/1000 | testing_loss = 0.002606852254108176 | testing_correlation_R^2 = 0.8670143268254876 ====
# ==== Epoch: 34/1000 | testing_F0_MAE = 0.04695759365335107 Hz | testing_Phs_MAE = 0.31318994039297104 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685225411 at epoch 34
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 35/1000 | testing_loss = 0.002606851243249473 | testing_correlation_R^2 = 0.8670144185178116 ====
# ==== Epoch: 35/1000 | testing_F0_MAE = 0.046928691159933804 Hz | testing_Phs_MAE = 0.31306637908518314 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685124325 at epoch 35
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 36/1000 | testing_loss = 0.002606850175934248 | testing_correlation_R^2 = 0.8670145166421048 ====
# ==== Epoch: 36/1000 | testing_F0_MAE = 0.046899986259639266 Hz | testing_Phs_MAE = 0.31292285829782485 Degree ====
# =======================================================================================================================
# best model loss is 0.00260685017593 at epoch 36
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 37/1000 | testing_loss = 0.00260684923859689 | testing_correlation_R^2 = 0.8670146029792003 ====
# ==== Epoch: 37/1000 | testing_F0_MAE = 0.04687495817616582 Hz | testing_Phs_MAE = 0.31282211568951607 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684923860 at epoch 37
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 38/1000 | testing_loss = 0.0026068482005174617 | testing_correlation_R^2 = 0.8670146969354939 ====
# ==== Epoch: 38/1000 | testing_F0_MAE = 0.04684960049390793 Hz | testing_Phs_MAE = 0.3126901025027037 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684820052 at epoch 38
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 39/1000 | testing_loss = 0.0026068471581643707 | testing_correlation_R^2 = 0.8670147905158698 ====
# ==== Epoch: 39/1000 | testing_F0_MAE = 0.04682100044190884 Hz | testing_Phs_MAE = 0.31255627989023926 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684715816 at epoch 39
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 40/1000 | testing_loss = 0.0026068461421309727 | testing_correlation_R^2 = 0.8670148826238234 ====
# ==== Epoch: 40/1000 | testing_F0_MAE = 0.04679509718716145 Hz | testing_Phs_MAE = 0.3124241073206067 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684614213 at epoch 40
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 41/1000 | testing_loss = 0.0026068451553211284 | testing_correlation_R^2 = 0.8670149719923286 ====
# ==== Epoch: 41/1000 | testing_F0_MAE = 0.046770135127007964 Hz | testing_Phs_MAE = 0.31231320757418873 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684515532 at epoch 41
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 42/1000 | testing_loss = 0.0026068441110176366 | testing_correlation_R^2 = 0.8670150704961103 ====
# ==== Epoch: 42/1000 | testing_F0_MAE = 0.046745561353862285 Hz | testing_Phs_MAE = 0.312154008820653 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684411102 at epoch 42
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 43/1000 | testing_loss = 0.0026068431111211793 | testing_correlation_R^2 = 0.8670151610107543 ====
# ==== Epoch: 43/1000 | testing_F0_MAE = 0.046719600409269334 Hz | testing_Phs_MAE = 0.31202626346051693 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684311112 at epoch 43
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 44/1000 | testing_loss = 0.0026068421225465314 | testing_correlation_R^2 = 0.8670152514428249 ====
# ==== Epoch: 44/1000 | testing_F0_MAE = 0.04669486633315682 Hz | testing_Phs_MAE = 0.3118863881789148 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684212255 at epoch 44
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 45/1000 | testing_loss = 0.0026068411441330496 | testing_correlation_R^2 = 0.8670153392520882 ====
# ==== Epoch: 45/1000 | testing_F0_MAE = 0.046671336576342586 Hz | testing_Phs_MAE = 0.31177505729719995 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684114413 at epoch 45
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 46/1000 | testing_loss = 0.002606840198309147 | testing_correlation_R^2 = 0.8670154264780826 ====
# ==== Epoch: 46/1000 | testing_F0_MAE = 0.04664691360667348 Hz | testing_Phs_MAE = 0.31165126587823033 Degree ====
# =======================================================================================================================
# best model loss is 0.00260684019831 at epoch 46
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 47/1000 | testing_loss = 0.002606839319201178 | testing_correlation_R^2 = 0.867015508286997 ====
# ==== Epoch: 47/1000 | testing_F0_MAE = 0.04662564826011658 Hz | testing_Phs_MAE = 0.31155402533337473 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683931920 at epoch 47
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 48/1000 | testing_loss = 0.002606838309282324 | testing_correlation_R^2 = 0.8670156005079973 ====
# ==== Epoch: 48/1000 | testing_F0_MAE = 0.046600552029907705 Hz | testing_Phs_MAE = 0.3114014478288591 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683830928 at epoch 48
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 49/1000 | testing_loss = 0.0026068373362331983 | testing_correlation_R^2 = 0.8670156888738862 ====
# ==== Epoch: 49/1000 | testing_F0_MAE = 0.04657677314803004 Hz | testing_Phs_MAE = 0.31126823215559124 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683733623 at epoch 49
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 50/1000 | testing_loss = 0.0026068363967560407 | testing_correlation_R^2 = 0.8670157739085756 ====
# ==== Epoch: 50/1000 | testing_F0_MAE = 0.0465516795925796 Hz | testing_Phs_MAE = 0.31112975427880885 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683639676 at epoch 50
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 51/1000 | testing_loss = 0.002606835444589901 | testing_correlation_R^2 = 0.8670158594583399 ====
# ==== Epoch: 51/1000 | testing_F0_MAE = 0.04652814513444901 Hz | testing_Phs_MAE = 0.3109567302204668 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683544459 at epoch 51
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 52/1000 | testing_loss = 0.0026068345303544406 | testing_correlation_R^2 = 0.8670159434481085 ====
# ==== Epoch: 52/1000 | testing_F0_MAE = 0.04650455094873905 Hz | testing_Phs_MAE = 0.31082918800786136 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683453035 at epoch 52
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 53/1000 | testing_loss = 0.0026068335381706866 | testing_correlation_R^2 = 0.8670160342833108 ====
# ==== Epoch: 53/1000 | testing_F0_MAE = 0.046479915264993905 Hz | testing_Phs_MAE = 0.31067933605238796 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683353817 at epoch 53
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 54/1000 | testing_loss = 0.0026068326376221976 | testing_correlation_R^2 = 0.8670161163665457 ====
# ==== Epoch: 54/1000 | testing_F0_MAE = 0.04645430149883032 Hz | testing_Phs_MAE = 0.3105738623999059 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683263762 at epoch 54
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 55/1000 | testing_loss = 0.0026068316943161987 | testing_correlation_R^2 = 0.8670162016586836 ====
# ==== Epoch: 55/1000 | testing_F0_MAE = 0.04642866910994053 Hz | testing_Phs_MAE = 0.3104458000026643 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683169432 at epoch 55
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 56/1000 | testing_loss = 0.0026068308305461584 | testing_correlation_R^2 = 0.867016279837664 ====
# ==== Epoch: 56/1000 | testing_F0_MAE = 0.04640485772490501 Hz | testing_Phs_MAE = 0.3103454258851707 Degree ====
# =======================================================================================================================
# best model loss is 0.00260683083055 at epoch 56
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 57/1000 | testing_loss = 0.002606829932020595 | testing_correlation_R^2 = 0.8670163609000234 ====
# ==== Epoch: 57/1000 | testing_F0_MAE = 0.04637995906919241 Hz | testing_Phs_MAE = 0.31021553843840954 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682993202 at epoch 57
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 58/1000 | testing_loss = 0.0026068290013678635 | testing_correlation_R^2 = 0.8670164470800951 ====
# ==== Epoch: 58/1000 | testing_F0_MAE = 0.04635446696728468 Hz | testing_Phs_MAE = 0.3100958896391094 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682900137 at epoch 58
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 59/1000 | testing_loss = 0.0026068281217116293 | testing_correlation_R^2 = 0.8670165277213657 ====
# ==== Epoch: 59/1000 | testing_F0_MAE = 0.04633150885626674 Hz | testing_Phs_MAE = 0.3099741211347282 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682812171 at epoch 59
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 60/1000 | testing_loss = 0.002606827236420635 | testing_correlation_R^2 = 0.867016609997933 ====
# ==== Epoch: 60/1000 | testing_F0_MAE = 0.04630626808106899 Hz | testing_Phs_MAE = 0.30987012157961724 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682723642 at epoch 60
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 61/1000 | testing_loss = 0.002606826325423242 | testing_correlation_R^2 = 0.8670166928105317 ====
# ==== Epoch: 61/1000 | testing_F0_MAE = 0.04628231954202056 Hz | testing_Phs_MAE = 0.3097410822175443 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682632542 at epoch 61
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 62/1000 | testing_loss = 0.0026068254274630542 | testing_correlation_R^2 = 0.8670167733438158 ====
# ==== Epoch: 62/1000 | testing_F0_MAE = 0.04625884292647243 Hz | testing_Phs_MAE = 0.30962990172579885 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682542746 at epoch 62
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 63/1000 | testing_loss = 0.0026068245027254873 | testing_correlation_R^2 = 0.8670168548954922 ====
# ==== Epoch: 63/1000 | testing_F0_MAE = 0.046234798129647973 Hz | testing_Phs_MAE = 0.3095094454400241 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682450273 at epoch 63
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 64/1000 | testing_loss = 0.002606823567597516 | testing_correlation_R^2 = 0.8670169391173381 ====
# ==== Epoch: 64/1000 | testing_F0_MAE = 0.04621036171540618 Hz | testing_Phs_MAE = 0.30938664139434696 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682356760 at epoch 64
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 65/1000 | testing_loss = 0.002606822729475322 | testing_correlation_R^2 = 0.86701701532555 ====
# ==== Epoch: 65/1000 | testing_F0_MAE = 0.046188581861555576 Hz | testing_Phs_MAE = 0.30926859640702603 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682272948 at epoch 65
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 66/1000 | testing_loss = 0.002606821800437949 | testing_correlation_R^2 = 0.8670170971049969 ====
# ==== Epoch: 66/1000 | testing_F0_MAE = 0.0461660754904151 Hz | testing_Phs_MAE = 0.3091489043273032 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682180044 at epoch 66
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 67/1000 | testing_loss = 0.0026068209134345963 | testing_correlation_R^2 = 0.8670171798322264 ====
# ==== Epoch: 67/1000 | testing_F0_MAE = 0.046141316078603264 Hz | testing_Phs_MAE = 0.30902692534402015 Degree ====
# =======================================================================================================================
# best model loss is 0.00260682091343 at epoch 67
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 68/1000 | testing_loss = 0.0026068199871648475 | testing_correlation_R^2 = 0.8670172607496778 ====
# ==== Epoch: 68/1000 | testing_F0_MAE = 0.04611504444107413 Hz | testing_Phs_MAE = 0.30889118302986024 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681998716 at epoch 68
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 69/1000 | testing_loss = 0.002606819143057891 | testing_correlation_R^2 = 0.8670173383774362 ====
# ==== Epoch: 69/1000 | testing_F0_MAE = 0.046093860514461994 Hz | testing_Phs_MAE = 0.30877988066896794 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681914306 at epoch 69
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 70/1000 | testing_loss = 0.002606818271509898 | testing_correlation_R^2 = 0.8670174168426753 ====
# ==== Epoch: 70/1000 | testing_F0_MAE = 0.0460733505114913 Hz | testing_Phs_MAE = 0.3086538043431938 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681827151 at epoch 70
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 71/1000 | testing_loss = 0.0026068173668058704 | testing_correlation_R^2 = 0.8670174989707498 ====
# ==== Epoch: 71/1000 | testing_F0_MAE = 0.04604809361696243 Hz | testing_Phs_MAE = 0.3085407835654914 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681736681 at epoch 71
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 72/1000 | testing_loss = 0.0026068164730999365 | testing_correlation_R^2 = 0.8670175789522448 ====
# ==== Epoch: 72/1000 | testing_F0_MAE = 0.046023906730115416 Hz | testing_Phs_MAE = 0.30842489754781127 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681647310 at epoch 72
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 73/1000 | testing_loss = 0.0026068156567008033 | testing_correlation_R^2 = 0.8670176521480133 ====
# ==== Epoch: 73/1000 | testing_F0_MAE = 0.046004859872162344 Hz | testing_Phs_MAE = 0.3082759041301906 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681565670 at epoch 73
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 74/1000 | testing_loss = 0.0026068147345875976 | testing_correlation_R^2 = 0.8670177361223946 ====
# ==== Epoch: 74/1000 | testing_F0_MAE = 0.0459791756272316 Hz | testing_Phs_MAE = 0.30815701478347185 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681473459 at epoch 74
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 75/1000 | testing_loss = 0.002606813895646674 | testing_correlation_R^2 = 0.867017812139096 ====
# ==== Epoch: 75/1000 | testing_F0_MAE = 0.04595650516450405 Hz | testing_Phs_MAE = 0.30805949041619896 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681389565 at epoch 75
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 76/1000 | testing_loss = 0.0026068129464695707 | testing_correlation_R^2 = 0.8670178940273369 ====
# ==== Epoch: 76/1000 | testing_F0_MAE = 0.045934049434959885 Hz | testing_Phs_MAE = 0.30790908631309866 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681294647 at epoch 76
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 77/1000 | testing_loss = 0.002606812076070369 | testing_correlation_R^2 = 0.8670179747203834 ====
# ==== Epoch: 77/1000 | testing_F0_MAE = 0.04591021988168359 Hz | testing_Phs_MAE = 0.30780275585129857 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681207607 at epoch 77
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 78/1000 | testing_loss = 0.0026068111124950485 | testing_correlation_R^2 = 0.8670180605262012 ====
# ==== Epoch: 78/1000 | testing_F0_MAE = 0.04588543220236897 Hz | testing_Phs_MAE = 0.3076732551045716 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681111250 at epoch 78
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 79/1000 | testing_loss = 0.0026068101985989287 | testing_correlation_R^2 = 0.8670181420726033 ====
# ==== Epoch: 79/1000 | testing_F0_MAE = 0.045862674802541734 Hz | testing_Phs_MAE = 0.30753782744333147 Degree ====
# =======================================================================================================================
# best model loss is 0.00260681019860 at epoch 79
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 80/1000 | testing_loss = 0.0026068093854601138 | testing_correlation_R^2 = 0.8670182179231558 ====
# ==== Epoch: 80/1000 | testing_F0_MAE = 0.04584342789649963 Hz | testing_Phs_MAE = 0.30742162296548486 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680938546 at epoch 80
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 81/1000 | testing_loss = 0.0026068084426188066 | testing_correlation_R^2 = 0.8670183009702632 ====
# ==== Epoch: 81/1000 | testing_F0_MAE = 0.04581919348239899 Hz | testing_Phs_MAE = 0.30727636271342634 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680844262 at epoch 81
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 82/1000 | testing_loss = 0.002606807637124529 | testing_correlation_R^2 = 0.867018375022755 ====
# ==== Epoch: 82/1000 | testing_F0_MAE = 0.04580070035159588 Hz | testing_Phs_MAE = 0.3071751842908561 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680763712 at epoch 82
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 83/1000 | testing_loss = 0.002606806724777776 | testing_correlation_R^2 = 0.867018458093244 ====
# ==== Epoch: 83/1000 | testing_F0_MAE = 0.04577890960127115 Hz | testing_Phs_MAE = 0.30704892867431044 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680672478 at epoch 83
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 84/1000 | testing_loss = 0.002606805854128204 | testing_correlation_R^2 = 0.8670185355308571 ====
# ==== Epoch: 84/1000 | testing_F0_MAE = 0.045756665579974654 Hz | testing_Phs_MAE = 0.30692840514704584 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680585413 at epoch 84
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 85/1000 | testing_loss = 0.002606804936707686 | testing_correlation_R^2 = 0.8670186172671818 ====
# ==== Epoch: 85/1000 | testing_F0_MAE = 0.045732997760176655 Hz | testing_Phs_MAE = 0.30681012564525006 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680493671 at epoch 85
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 86/1000 | testing_loss = 0.002606804098643437 | testing_correlation_R^2 = 0.8670186936015273 ====
# ==== Epoch: 86/1000 | testing_F0_MAE = 0.04571263415366411 Hz | testing_Phs_MAE = 0.30669572358950975 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680409864 at epoch 86
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 87/1000 | testing_loss = 0.002606803167799299 | testing_correlation_R^2 = 0.8670187759528132 ====
# ==== Epoch: 87/1000 | testing_F0_MAE = 0.04568885796517134 Hz | testing_Phs_MAE = 0.3065725905038416 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680316780 at epoch 87
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 88/1000 | testing_loss = 0.0026068023573571713 | testing_correlation_R^2 = 0.8670188502784008 ====
# ==== Epoch: 88/1000 | testing_F0_MAE = 0.0456677977219224 Hz | testing_Phs_MAE = 0.30645125478878615 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680235736 at epoch 88
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 89/1000 | testing_loss = 0.0026068015207859076 | testing_correlation_R^2 = 0.8670189280112603 ====
# ==== Epoch: 89/1000 | testing_F0_MAE = 0.04564755659177899 Hz | testing_Phs_MAE = 0.3063448284305632 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680152079 at epoch 89
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 90/1000 | testing_loss = 0.002606800658298763 | testing_correlation_R^2 = 0.8670190038288514 ====
# ==== Epoch: 90/1000 | testing_F0_MAE = 0.04562761869281531 Hz | testing_Phs_MAE = 0.30622456150874494 Degree ====
# =======================================================================================================================
# best model loss is 0.00260680065830 at epoch 90
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 91/1000 | testing_loss = 0.002606799818840486 | testing_correlation_R^2 = 0.8670190781612493 ====
# ==== Epoch: 91/1000 | testing_F0_MAE = 0.04560873413458467 Hz | testing_Phs_MAE = 0.30609391697123645 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679981884 at epoch 91
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 92/1000 | testing_loss = 0.0026067989369038995 | testing_correlation_R^2 = 0.8670191598061473 ====
# ==== Epoch: 92/1000 | testing_F0_MAE = 0.04558717324957252 Hz | testing_Phs_MAE = 0.306004320692271 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679893690 at epoch 92
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 93/1000 | testing_loss = 0.0026067981261855095 | testing_correlation_R^2 = 0.8670192319709342 ====
# ==== Epoch: 93/1000 | testing_F0_MAE = 0.04556923912838101 Hz | testing_Phs_MAE = 0.30588687817379834 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679812619 at epoch 93
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 94/1000 | testing_loss = 0.0026067972601564156 | testing_correlation_R^2 = 0.8670193112210719 ====
# ==== Epoch: 94/1000 | testing_F0_MAE = 0.04554895626008511 Hz | testing_Phs_MAE = 0.30577809282764795 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679726016 at epoch 94
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 95/1000 | testing_loss = 0.002606796432025298 | testing_correlation_R^2 = 0.8670193850133081 ====
# ==== Epoch: 95/1000 | testing_F0_MAE = 0.045529670793563126 Hz | testing_Phs_MAE = 0.30567309745773674 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679643203 at epoch 95
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 96/1000 | testing_loss = 0.002606795604713646 | testing_correlation_R^2 = 0.8670194606595466 ====
# ==== Epoch: 96/1000 | testing_F0_MAE = 0.045506628975272176 Hz | testing_Phs_MAE = 0.3055746621154249 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679560471 at epoch 96
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 97/1000 | testing_loss = 0.0026067947560734195 | testing_correlation_R^2 = 0.8670195359418612 ====
# ==== Epoch: 97/1000 | testing_F0_MAE = 0.04548699024319649 Hz | testing_Phs_MAE = 0.305456829149276 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679475607 at epoch 97
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 98/1000 | testing_loss = 0.0026067939051082865 | testing_correlation_R^2 = 0.8670196133308186 ====
# ==== Epoch: 98/1000 | testing_F0_MAE = 0.04546446869522333 Hz | testing_Phs_MAE = 0.305344836268574 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679390511 at epoch 98
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 99/1000 | testing_loss = 0.002606793135017092 | testing_correlation_R^2 = 0.8670196822356696 ====
# ==== Epoch: 99/1000 | testing_F0_MAE = 0.0454447777941823 Hz | testing_Phs_MAE = 0.3052645863778889 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679313502 at epoch 99
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 100/1000 | testing_loss = 0.002606792242391325 | testing_correlation_R^2 = 0.8670197629925432 ====
# ==== Epoch: 100/1000 | testing_F0_MAE = 0.04542263053357601 Hz | testing_Phs_MAE = 0.30515723864361644 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679224239 at epoch 100
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 101/1000 | testing_loss = 0.0026067914674576934 | testing_correlation_R^2 = 0.867019832827287 ====
# ==== Epoch: 101/1000 | testing_F0_MAE = 0.045402084056288004 Hz | testing_Phs_MAE = 0.30505469762906434 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679146746 at epoch 101
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 102/1000 | testing_loss = 0.0026067906390105193 | testing_correlation_R^2 = 0.8670199076944252 ====
# ==== Epoch: 102/1000 | testing_F0_MAE = 0.04538109242543578 Hz | testing_Phs_MAE = 0.30494229976460335 Degree ====
# =======================================================================================================================
# best model loss is 0.00260679063901 at epoch 102
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 103/1000 | testing_loss = 0.0026067898438253074 | testing_correlation_R^2 = 0.8670199794099788 ====
# ==== Epoch: 103/1000 | testing_F0_MAE = 0.04536141514033079 Hz | testing_Phs_MAE = 0.30485925868526104 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678984383 at epoch 103
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 104/1000 | testing_loss = 0.002606789010847244 | testing_correlation_R^2 = 0.8670200541908849 ====
# ==== Epoch: 104/1000 | testing_F0_MAE = 0.0453400930762291 Hz | testing_Phs_MAE = 0.30474511406198146 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678901085 at epoch 104
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 105/1000 | testing_loss = 0.0026067882133263714 | testing_correlation_R^2 = 0.8670201288873963 ====
# ==== Epoch: 105/1000 | testing_F0_MAE = 0.04532039394974709 Hz | testing_Phs_MAE = 0.30464524038508534 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678821333 at epoch 105
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 106/1000 | testing_loss = 0.002606787417341401 | testing_correlation_R^2 = 0.8670201981364587 ====
# ==== Epoch: 106/1000 | testing_F0_MAE = 0.04529885905981064 Hz | testing_Phs_MAE = 0.30453320571407677 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678741734 at epoch 106
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 107/1000 | testing_loss = 0.0026067866026058583 | testing_correlation_R^2 = 0.8670202715479219 ====
# ==== Epoch: 107/1000 | testing_F0_MAE = 0.045277959186583755 Hz | testing_Phs_MAE = 0.304427862662822 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678660261 at epoch 107
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 108/1000 | testing_loss = 0.002606785734654391 | testing_correlation_R^2 = 0.8670203500159146 ====
# ==== Epoch: 108/1000 | testing_F0_MAE = 0.045255762416869405 Hz | testing_Phs_MAE = 0.3043134024105966 Degree ====
# =======================================================================================================================
# best model loss is 0.00260678573465 at epoch 108
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 109/1000 | testing_loss = 0.0026067848805200883 | testing_correlation_R^2 = 0.8670204271167186 ====
# ...
# best model loss is 0.00260671599170 at epoch 208
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 209/1000 | testing_loss = 0.0026067153794747215 | testing_correlation_R^2 = 0.8670267028008126 ====
# ==== Epoch: 209/1000 | testing_F0_MAE = 0.04345190911181271 Hz | testing_Phs_MAE = 0.29553183997049925 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671537947 at epoch 209
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 210/1000 | testing_loss = 0.002606714781723241 | testing_correlation_R^2 = 0.8670267577886701 ====
# ==== Epoch: 210/1000 | testing_F0_MAE = 0.04343759675137698 Hz | testing_Phs_MAE = 0.2954630643092096 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671478172 at epoch 210
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 211/1000 | testing_loss = 0.002606714148017659 | testing_correlation_R^2 = 0.8670268172323383 ====
# ==== Epoch: 211/1000 | testing_F0_MAE = 0.043418666930869224 Hz | testing_Phs_MAE = 0.29538507740572095 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671414802 at epoch 211
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 212/1000 | testing_loss = 0.0026067134878020397 | testing_correlation_R^2 = 0.8670268747199944 ====
# ==== Epoch: 212/1000 | testing_F0_MAE = 0.04340287427790463 Hz | testing_Phs_MAE = 0.295313676442951 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671348780 at epoch 212
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 213/1000 | testing_loss = 0.00260671297743594 | testing_correlation_R^2 = 0.8670269193478124 ====
# ==== Epoch: 213/1000 | testing_F0_MAE = 0.04339262334443629 Hz | testing_Phs_MAE = 0.2952526706196368 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671297744 at epoch 213
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 214/1000 | testing_loss = 0.002606712320820943 | testing_correlation_R^2 = 0.8670269782066522 ====
# ==== Epoch: 214/1000 | testing_F0_MAE = 0.04337693801708519 Hz | testing_Phs_MAE = 0.29518629337474706 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671232082 at epoch 214
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 215/1000 | testing_loss = 0.002606711781109894 | testing_correlation_R^2 = 0.8670270267180054 ====
# ==== Epoch: 215/1000 | testing_F0_MAE = 0.04336192886717617 Hz | testing_Phs_MAE = 0.2951116677038372 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671178111 at epoch 215
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 216/1000 | testing_loss = 0.0026067111418091892 | testing_correlation_R^2 = 0.867027083558597 ====
# ==== Epoch: 216/1000 | testing_F0_MAE = 0.04334618398733437 Hz | testing_Phs_MAE = 0.2950524447374046 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671114181 at epoch 216
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 217/1000 | testing_loss = 0.0026067105430466883 | testing_correlation_R^2 = 0.8670271376701907 ====
# ==== Epoch: 217/1000 | testing_F0_MAE = 0.04333135624416173 Hz | testing_Phs_MAE = 0.29498018155619504 Degree ====
# =======================================================================================================================
# best model loss is 0.00260671054305 at epoch 217
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 218/1000 | testing_loss = 0.002606709986754069 | testing_correlation_R^2 = 0.867027186508035 ====
# ==== Epoch: 218/1000 | testing_F0_MAE = 0.04331780699826777 Hz | testing_Phs_MAE = 0.29492025199905036 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670998675 at epoch 218
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 219/1000 | testing_loss = 0.00260670938192413 | testing_correlation_R^2 = 0.8670272416352696 ====
# ==== Epoch: 219/1000 | testing_F0_MAE = 0.043300621511414644 Hz | testing_Phs_MAE = 0.29484134997799993 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670938192 at epoch 219
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 220/1000 | testing_loss = 0.00260670877151707 | testing_correlation_R^2 = 0.8670272965230699 ====
# ==== Epoch: 220/1000 | testing_F0_MAE = 0.04328711828403175 Hz | testing_Phs_MAE = 0.29477392888441684 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670877152 at epoch 220
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 221/1000 | testing_loss = 0.0026067081902568672 | testing_correlation_R^2 = 0.8670273506496782 ====
# ==== Epoch: 221/1000 | testing_F0_MAE = 0.04327059016562998 Hz | testing_Phs_MAE = 0.2947034002952278 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670819026 at epoch 221
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 222/1000 | testing_loss = 0.0026067075696119347 | testing_correlation_R^2 = 0.8670274044624657 ====
# ==== Epoch: 222/1000 | testing_F0_MAE = 0.043257164077833296 Hz | testing_Phs_MAE = 0.2946433803476393 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670756961 at epoch 222
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 223/1000 | testing_loss = 0.002606707026721104 | testing_correlation_R^2 = 0.8670274578134177 ====
# ==== Epoch: 223/1000 | testing_F0_MAE = 0.04323949815891683 Hz | testing_Phs_MAE = 0.2945639943368733 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670702672 at epoch 223
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 224/1000 | testing_loss = 0.0026067064782882314 | testing_correlation_R^2 = 0.8670275060948683 ====
# ==== Epoch: 224/1000 | testing_F0_MAE = 0.043226255359128114 Hz | testing_Phs_MAE = 0.294506121661514 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670647829 at epoch 224
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 225/1000 | testing_loss = 0.002606705871219006 | testing_correlation_R^2 = 0.8670275608145285 ====
# ==== Epoch: 225/1000 | testing_F0_MAE = 0.04320978299714625 Hz | testing_Phs_MAE = 0.2944253205098212 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670587122 at epoch 225
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 226/1000 | testing_loss = 0.002606705321959417 | testing_correlation_R^2 = 0.8670276118599234 ====
# ==== Epoch: 226/1000 | testing_F0_MAE = 0.043194144325330856 Hz | testing_Phs_MAE = 0.29437954116240145 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670532196 at epoch 226
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 227/1000 | testing_loss = 0.0026067047199225825 | testing_correlation_R^2 = 0.8670276648148358 ====
# ==== Epoch: 227/1000 | testing_F0_MAE = 0.04317891803570092 Hz | testing_Phs_MAE = 0.2942865603081882 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670471992 at epoch 227
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 228/1000 | testing_loss = 0.0026067041266291044 | testing_correlation_R^2 = 0.8670277170329385 ====
# ==== Epoch: 228/1000 | testing_F0_MAE = 0.043163544392213225 Hz | testing_Phs_MAE = 0.29421299278363583 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670412663 at epoch 228
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 229/1000 | testing_loss = 0.002606703620539683 | testing_correlation_R^2 = 0.8670277626549519 ====
# ==== Epoch: 229/1000 | testing_F0_MAE = 0.04315042862482369 Hz | testing_Phs_MAE = 0.2941570373885333 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670362054 at epoch 229
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 230/1000 | testing_loss = 0.002606703067917746 | testing_correlation_R^2 = 0.8670278126265213 ====
# ==== Epoch: 230/1000 | testing_F0_MAE = 0.043134602295234796 Hz | testing_Phs_MAE = 0.29410063183680174 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670306792 at epoch 230
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 231/1000 | testing_loss = 0.002606702484254253 | testing_correlation_R^2 = 0.8670278623950121 ====
# ==== Epoch: 231/1000 | testing_F0_MAE = 0.04311962416954339 Hz | testing_Phs_MAE = 0.29402445343509315 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670248425 at epoch 231
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 232/1000 | testing_loss = 0.002606701936150863 | testing_correlation_R^2 = 0.8670279123209328 ====
# ==== Epoch: 232/1000 | testing_F0_MAE = 0.04310457638092339 Hz | testing_Phs_MAE = 0.2939777309112251 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670193615 at epoch 232
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 233/1000 | testing_loss = 0.002606701362397029 | testing_correlation_R^2 = 0.8670279626351494 ====
# ==== Epoch: 233/1000 | testing_F0_MAE = 0.043090015402063725 Hz | testing_Phs_MAE = 0.29387852835282685 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670136240 at epoch 233
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 234/1000 | testing_loss = 0.0026067008087697447 | testing_correlation_R^2 = 0.8670280107942638 ====
# ==== Epoch: 234/1000 | testing_F0_MAE = 0.04307470123656094 Hz | testing_Phs_MAE = 0.29382629792019727 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670080877 at epoch 234
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 235/1000 | testing_loss = 0.0026067002447435995 | testing_correlation_R^2 = 0.867028062346256 ====
# ==== Epoch: 235/1000 | testing_F0_MAE = 0.04306187999434769 Hz | testing_Phs_MAE = 0.29375946697220207 Degree ====
# =======================================================================================================================
# best model loss is 0.00260670024474 at epoch 235
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 236/1000 | testing_loss = 0.002606699656679805 | testing_correlation_R^2 = 0.8670281149126423 ====
# ==== Epoch: 236/1000 | testing_F0_MAE = 0.043045468153432014 Hz | testing_Phs_MAE = 0.29368218273296953 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669965668 at epoch 236
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 237/1000 | testing_loss = 0.0026066990961763495 | testing_correlation_R^2 = 0.8670281649031758 ====
# ==== Epoch: 237/1000 | testing_F0_MAE = 0.04303162534721196 Hz | testing_Phs_MAE = 0.2936012754179537 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669909618 at epoch 237
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 238/1000 | testing_loss = 0.00260669853815952 | testing_correlation_R^2 = 0.86702821516866 ====
# ==== Epoch: 238/1000 | testing_F0_MAE = 0.043013872316107156 Hz | testing_Phs_MAE = 0.293542337898165 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669853816 at epoch 238
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 239/1000 | testing_loss = 0.002606698024136833 | testing_correlation_R^2 = 0.8670282600625543 ====
# ==== Epoch: 239/1000 | testing_F0_MAE = 0.04300089884735644 Hz | testing_Phs_MAE = 0.2934736112244427 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669802414 at epoch 239
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 240/1000 | testing_loss = 0.0026066974494686796 | testing_correlation_R^2 = 0.8670283125154016 ====
# ==== Epoch: 240/1000 | testing_F0_MAE = 0.04298635634221137 Hz | testing_Phs_MAE = 0.29339186086133123 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669744947 at epoch 240
# Testing dataset unsupervised optmization begins...
# ==== Epoch: 241/1000 | testing_loss = 0.0026066968463986555 | testing_correlation_R^2 = 0.8670283645886444 ====
# ==== Epoch: 241/1000 | testing_F0_MAE = 0.042971685776486995 Hz | testing_Phs_MAE = 0.2933368933163583 Degree ====
# =======================================================================================================================
# best model loss is 0.00260669684640 at epoch 241
# Testing dataset unsupervised optmization begins...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-c8861f183620> in <module>
#     239
#     240             #real spectra and predicted spectra
# --> 241             Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
#     242             Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))
#     243
#
# <__array_function__ internals> in fftshift(*args, **kwargs)
#
# /home/raphael/anaconda3/lib/python3.7/site-packages/numpy/fft/helper.py in fftshift(x, axes)
#      72         shift = [x.shape[ax] // 2 for ax in axes]
#      73
# ---> 74     return roll(x, shift, axes)
#      75
#      76
#
# <__array_function__ internals> in roll(*args, **kwargs)
#
# /home/raphael/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in roll(a, shift, axis)
#    1197
#    1198         rolls = [((slice(None), slice(None)),)] * a.ndim
# -> 1199         for ax, offset in shifts.items():
#    1200             offset %= a.shape[ax] or 1  # If `a` is empty, nothing matters.
#    1201             if offset:
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Evaluation**

# %% [markdown]
# #### OFF

# %%
# ============ testing dataset ============
N_test = 2000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = F0_all[18000:20000] 
Phs_test = Phs_all[18000:20000] 

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = noisy_Real_spectUnAligned_and_spectAligned_tensor_all[18000:20000,:,:]

Real_FidsAligned_tensor_test = Real_FidsAligned_tensor_all[18000:20000,:,:]

Imag_FidsAligned_tensor_test = Imag_FidsAligned_tensor_all[18000:20000,:,:]

Real_FidsUnAligned_tensor_test = Real_FidsUnAligned_tensor_all[18000:20000,:,:]

Imag_FidsUnAligned_tensor_test = Imag_FidsUnAligned_tensor_all[18000:20000,:,:]

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([2000, 1, 2048])
# F0_test torch.Size([2000])
# Phs_test torch.Size([2000])

# %%
# ============ testing dataset ============
N_test = 2000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = F0_all[18000:20000]
Phs_test = Phs_all[18000:20000]

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = noisy_Real_spectUnAligned_and_spectAligned_tensor_all[18000:20000,:,:]

Real_FidsAligned_tensor_test = Real_FidsAligned_tensor_all[18000:20000,:,:]

Imag_FidsAligned_tensor_test = Imag_FidsAligned_tensor_all[18000:20000,:,:]

Real_FidsUnAligned_tensor_test = Real_FidsUnAligned_tensor_all[18000:20000,:,:]

Imag_FidsUnAligned_tensor_test = Imag_FidsUnAligned_tensor_all[18000:20000,:,:]

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([2000, 1, 2048])
# F0_test torch.Size([2000])
# Phs_test torch.Size([2000])

# %%
# define the model
model_n = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best_testing.pt'
data_save_F0='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_testing_finetuned_F0_OFF_pred.npy'
data_save_Phs='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_testing_finetuned_Phs_OFF_pred.npy'

JETCNN = JETCNN_L
JETCNN.load_state_dict(torch.load(model_n))
criterion = L1Loss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-4)
test_epoch_loss = []
test_epoch_F0_MAE = [] 
test_epoch_Phs_MAE = [] 
test_epoch_F0_SD=[]
test_epoch_Phs_SD=[]
test_epoch_p_correlation = []
F0_ON_predicted=[]
Phs_ON_predicted=[]

# where to calculate the spectral loss
range1 = 1100
range2 = 1500

fid_range1 = 0
fid_range2 = 512
    
test_loss = []
test_F0_MAE = [] 
test_Phs_MAE = [] 
test_F0_SD=[]
test_Phs_SD=[]
test_F0_pred=[]
test_Phs_pred=[]
test_p_correlation = []

#######################################################
######################## Test #########################
#######################################################
print('Testing begins...')
for batch_index, data in enumerate(test_loader):
    
    # If GPU is available, move the data to the GPU for faster computation.
    if cuda:
        
        # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
        noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
        Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
        F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##

        # *** Set the model to train mode ***
        JETCNN.train()
        
        # *** forward + backward + optimize ***
        deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)

        Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
        Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)

        # *** Define loss between the real part of deformed spectra and the real part of the true spectra
        # apply the deformation
        F0_pred_tensor = torch.clone(F0_tensor)
        Phs_pred_tensor = torch.clone(Phs_tensor)
        for kk in range(len(deformation_predicted[:,0])):

            freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
            deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
            F0_pred_tensor[kk] = deformation_predicted[kk,0] 
            Phs_pred_tensor[kk] = deformation_predicted[kk,1] 

            Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                            ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
            Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                            ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)

            F0_ON_predicted.append(deformation_predicted[kk,0])
            Phs_ON_predicted.append(deformation_predicted[kk,1])

        # compute the loss
        F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
        F0_tensor_vector = torch.flatten(F0_tensor) 
        Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
        Phs_tensor_vector = torch.flatten(Phs_tensor) 

        # fids
        Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
        loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 

        loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
        loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)

        # fid correlation loss
        v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
        v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
        p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
        loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)

        v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
        v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
        p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
        loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag) # Correlation loss = 1-R^2 

        loss = (lamda)*(loss_fid_MSE_real + loss_fid_MSE_imag)+(1-lamda)*(loss_p_correlation_real + loss_p_correlation_imag)

        # compute the MAE of offsets
        F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
        Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##

        # compute the correlation
        fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
        fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()

        Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
        Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))

        r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
        p_correlation = r[0,1]
    
        # store the train_loss and tran_p_correlation
        test_F0_pred.append(F0_pred_tensor_vector.cpu().data.item())
        test_Phs_pred.append(Phs_pred_tensor_vector.cpu().data.item())
        test_loss.append(loss.cpu().data.item())
        test_F0_MAE.append(F0_MAE.cpu().data.item()) ##
        test_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
        test_p_correlation.append(p_correlation)
np.save(data_save_F0, test_F0_pred)
np.save(data_save_Phs,test_Phs_pred)
test_epoch_loss.append(np.mean(test_loss))
test_epoch_F0_MAE.append(np.mean(test_F0_MAE)) ##
test_epoch_Phs_MAE.append(np.mean(test_Phs_MAE)) ##
test_epoch_F0_SD.append(np.std(test_F0_MAE)) ##
test_epoch_Phs_SD.append(np.std(test_Phs_MAE)) ##
test_epoch_p_correlation.append(np.mean(test_p_correlation))

print("---------------------------------------------------------------------------------------------------------------------")
print(" test_loss = {} | test_p_correlation^2 = {} ====".format(test_epoch_loss[-1], \
                                                                                 test_epoch_p_correlation[-1]*test_epoch_p_correlation[-1]))
print(" test_F0_MAE = {} +- {} Hz | test_Phs_MAE = {} +- {} Degree ====".format(test_epoch_F0_MAE[-1],test_epoch_F0_SD[-1], \
                                                                                     test_epoch_Phs_MAE[-1],test_epoch_Phs_SD[-1]))

print("=======================================================================================================================")

prediction_F0_OFF=test_F0_pred
prediction_Phs_OFF=test_Phs_pred
# Out:
# Testing begins...
# ---------------------------------------------------------------------------------------------------------------------
#  test_loss = 0.0020659461424002074 | test_p_correlation^2 = 0.7904320492795687 ====
#  test_F0_MAE = 0.057804234275594356 +- 0.050331929474720816 Hz | test_Phs_MAE = 0.4157604534365237 +- 0.31746532471561584 Degree ====
# =======================================================================================================================

# %%
# saving MAE
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_F0_OFF_MAE.npy', test_F0_MAE)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_Phs_OFF_MAE.npy', test_Phs_MAE)

# %%
# ============ testing dataset ============
N_test = 2000
time_mat_test = np.tile(time,[N_test,1])

#defining ground truths
F0_test = F0_all[38000:40000]
Phs_test = Phs_all[38000:40000]

#defining spectras and fids
noisy_Real_spectUnAligned_and_spectAligned_tensor_test = noisy_Real_spectUnAligned_and_spectAligned_tensor_all[38000:40000,:,:]

Real_FidsAligned_tensor_test = Real_FidsAligned_tensor_all[38000:40000,:,:]

Imag_FidsAligned_tensor_test = Imag_FidsAligned_tensor_all[38000:40000,:,:]

Real_FidsUnAligned_tensor_test = Real_FidsUnAligned_tensor_all[38000:40000,:,:]

Imag_FidsUnAligned_tensor_test = Imag_FidsUnAligned_tensor_all[38000:40000,:,:]

time_mat_tensor_test = torch.from_numpy(time_mat_test).type(torch.FloatTensor).view(-1, 1, 2048) # Imag part of Dard Red

#defining test loader
test_data = TensorDataset(noisy_Real_spectUnAligned_and_spectAligned_tensor_test, Real_FidsAligned_tensor_test, Imag_FidsAligned_tensor_test, Real_FidsUnAligned_tensor_test, \
                           Imag_FidsUnAligned_tensor_test, time_mat_tensor_test, F0_test, Phs_test)
test_loader = DataLoader(test_data, batch_size = 1)

#printing outputs
print('time_mat_tensor_test',time_mat_tensor_test.shape)
print('F0_test',F0_test.shape)
print('Phs_test',Phs_test.shape)
# Out:
# time_mat_tensor_test torch.Size([2000, 1, 2048])
# F0_test torch.Size([2000])
# Phs_test torch.Size([2000])

# %%
# define the model
model_n = '/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/SR_spectra_3dB/checkpoint_1d5dB_wLB_best_testing.pt'

data_save_F0='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_testing_finetuned_F0_ON_pred.npy'
data_save_Phs='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/SR_Spectra_1d5dB_wLB_testing_finetuned_Phs_ON_pred.npy'

JETCNN = JETCNN_L
JETCNN.load_state_dict(torch.load(model_n))
criterion = L1Loss() 
lamda = 1

optimizer = Adam(JETCNN.parameters(),lr=1e-4)
test_epoch_loss = []
test_epoch_F0_MAE = [] 
test_epoch_Phs_MAE = [] 
test_epoch_F0_SD=[]
test_epoch_Phs_SD=[]
test_epoch_p_correlation = []
F0_ON_predicted=[]
Phs_ON_predicted=[]

# where to calculate the spectral loss
range1 = 1100
range2 = 1500

fid_range1 = 0
fid_range2 = 512
    
test_loss = []
test_F0_MAE = [] 
test_Phs_MAE = [] 
test_F0_SD=[]
test_Phs_SD=[]
test_F0_pred=[]
test_Phs_pred=[]
test_p_correlation = []

#######################################################
######################## Test #########################
#######################################################
print('Testing begins...')
for batch_index, data in enumerate(test_loader):
    
    # If GPU is available, move the data to the GPU for faster computation.
    if cuda:
        
        # *** get the inputs; data is a list of [noisy_Real_spectUnAligned_tensor, Real_FidsAligned_tensor, Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor]
        noisy_Real_spectUnAligned_and_spectAligned_tensor, Real_FidsAligned_tensor, Imag_FidsAligned_tensor =  data[0].to(device), data[1].to(device), data[2].to(device)
        Real_FidsUnAligned_tensor, Imag_FidsUnAligned_tensor, time_mat_tensor = data[3].to(device), data[4].to(device), data[5].to(device)
        F0_tensor, Phs_tensor = data[6].to(device), data[7].to(device) ##

        # *** Set the model to train mode ***
        JETCNN.train()
        
        # *** forward + backward + optimize ***
        deformation_predicted = JETCNN(noisy_Real_spectUnAligned_and_spectAligned_tensor)

        Real_FidsAligned_pred_tensor = torch.clone(Real_FidsUnAligned_tensor)
        Imag_FidsAligned_pred_tensor = torch.clone(Imag_FidsUnAligned_tensor)

        # *** Define loss between the real part of deformed spectra and the real part of the true spectra
        # apply the deformation
        F0_pred_tensor = torch.clone(F0_tensor)
        Phs_pred_tensor = torch.clone(Phs_tensor)
        for kk in range(len(deformation_predicted[:,0])):

            freqPart_real = torch.cos(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_real = torch.cos(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            freqPart_imag = torch.sin(-1 * time_mat_tensor[kk,:,:] * deformation_predicted[kk,0] * 2 * cm.pi)
            phasePart_imag = torch.sin(-1 * deformation_predicted[kk,1] * cm.pi / 180)

            deformation_real = torch.mul(freqPart_real,phasePart_real) - torch.mul(freqPart_imag,phasePart_imag)
            deformation_imag = torch.mul(freqPart_real,phasePart_imag) + torch.mul(freqPart_imag,phasePart_real)
                
            F0_pred_tensor[kk] = deformation_predicted[kk,0] 
            Phs_pred_tensor[kk] = deformation_predicted[kk,1] 

            Real_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_real
                                                            ) - torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_imag)
            Imag_FidsAligned_pred_tensor[kk,:,:] = torch.mul(Real_FidsUnAligned_tensor[kk,:,:],deformation_imag
                                                            ) + torch.mul(Imag_FidsUnAligned_tensor[kk,:,:],deformation_real)

            F0_ON_predicted.append(deformation_predicted[kk,0])
            Phs_ON_predicted.append(deformation_predicted[kk,1])

        # compute the loss
        F0_pred_tensor_vector = torch.flatten(F0_pred_tensor) 
        F0_tensor_vector = torch.flatten(F0_tensor) 
        Phs_pred_tensor_vector = torch.flatten(Phs_pred_tensor) 
        Phs_tensor_vector = torch.flatten(Phs_tensor) 

        # fids
        Real_FidsAligned_pred_tensor_vector = torch.flatten(Real_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Real_FidsAligned_tensor_vector = torch.flatten(Real_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        Imag_FidsAligned_pred_tensor_vector = torch.flatten(Imag_FidsAligned_pred_tensor[:,:,fid_range1:fid_range2])
        Imag_FidsAligned_tensor_vector = torch.flatten(Imag_FidsAligned_tensor[:,:,fid_range1:fid_range2])

        
        loss_MAE_F0 = criterion(F0_pred_tensor_vector, torch.mul(F0_tensor_vector,-1)) 
        loss_MAE_Ph = criterion(Phs_pred_tensor_vector, torch.mul(Phs_tensor_vector,-1)) 

        loss_fid_MSE_real = criterion(Real_FidsAligned_pred_tensor_vector, Real_FidsAligned_tensor_vector) 
        loss_fid_MSE_imag = criterion(Imag_FidsAligned_pred_tensor_vector, Imag_FidsAligned_tensor_vector)

        # fid correlation loss
        v_Real_pred_fid = Real_FidsAligned_pred_tensor_vector - torch.mean(Real_FidsAligned_pred_tensor_vector)
        v_Real_fid = Real_FidsAligned_tensor_vector - torch.mean(Real_FidsAligned_tensor_vector)
        p_correlation_real = torch.sum(v_Real_pred_fid * v_Real_fid) / (torch.sqrt(torch.sum(v_Real_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Real_fid ** 2)))
        loss_p_correlation_real = 1-torch.mul(p_correlation_real,p_correlation_real)

        v_Imag_pred_fid = Imag_FidsAligned_pred_tensor_vector - torch.mean(Imag_FidsAligned_pred_tensor_vector)
        v_Imag_fid = Imag_FidsAligned_tensor_vector - torch.mean(Imag_FidsAligned_tensor_vector)
        p_correlation_imag = torch.sum(v_Imag_pred_fid * v_Imag_fid) / (torch.sqrt(torch.sum(v_Imag_pred_fid ** 2)) * torch.sqrt(torch.sum(v_Imag_fid ** 2)))
        loss_p_correlation_imag = 1-torch.mul(p_correlation_imag,p_correlation_imag) # Correlation loss = 1-R^2 

        loss = (lamda)*(loss_fid_MSE_real + loss_fid_MSE_imag)+(1-lamda)*(loss_p_correlation_real + loss_p_correlation_imag)

        # compute the MAE of offsets
        F0_MAE = torch.abs(F0_pred_tensor_vector + F0_tensor_vector).mean().data  ##
        Phs_MAE = torch.abs(Phs_pred_tensor_vector + Phs_tensor_vector).mean().data  ##

        # compute the correlation
        fid_pred_real = torch.flatten(torch.mean(Real_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_real = torch.flatten(torch.mean(Real_FidsAligned_tensor,0)).cpu().detach().numpy()
        fid_pred_imag = torch.flatten(torch.mean(Imag_FidsAligned_pred_tensor,0)).cpu().detach().numpy()
        fid_imag = torch.flatten(torch.mean(Imag_FidsAligned_tensor,0)).cpu().detach().numpy()

        Real_pred_spec = np.real(fftshift(fft(fid_pred_real+1j*fid_pred_imag)))
        Real_spec = np.real(fftshift(fft(fid_real+1j*fid_imag)))

        r = np.corrcoef(Real_pred_spec[range1:range2],Real_spec[range1:range2])
        p_correlation = r[0,1]
        
        # store the train_loss and tran_p_correlation
        test_F0_pred.append(F0_pred_tensor_vector.cpu().data.item())
        test_Phs_pred.append(Phs_pred_tensor_vector.cpu().data.item())
        test_loss.append(loss.cpu().data.item())
        test_F0_MAE.append(F0_MAE.cpu().data.item()) ##
        test_Phs_MAE.append(Phs_MAE.cpu().data.item()) ##
        test_p_correlation.append(p_correlation)
np.save(data_save_F0, test_F0_pred)
np.save(data_save_Phs,test_Phs_pred)
test_epoch_loss.append(np.mean(test_loss))
test_epoch_F0_MAE.append(np.mean(test_F0_MAE)) ##
test_epoch_Phs_MAE.append(np.mean(test_Phs_MAE)) ##
test_epoch_F0_SD.append(np.std(test_F0_MAE)) ##
test_epoch_Phs_SD.append(np.std(test_Phs_MAE)) ##
test_epoch_p_correlation.append(np.mean(test_p_correlation))

print("---------------------------------------------------------------------------------------------------------------------")
print(" test_loss = {} | test_p_correlation^2 = {} ====".format(test_epoch_loss[-1], \
                                                                                 test_epoch_p_correlation[-1]*test_epoch_p_correlation[-1]))
print(" test_F0_MAE = {} +- {} Hz | test_Phs_MAE = {} +- {} Degree ====".format(test_epoch_F0_MAE[-1],test_epoch_F0_SD[-1], \
                                                                                     test_epoch_Phs_MAE[-1],test_epoch_Phs_SD[-1]))

print("=======================================================================================================================")

prediction_F0_ON=test_F0_pred
prediction_Phs_ON=test_Phs_pred
# Out:
# Testing begins...
# ---------------------------------------------------------------------------------------------------------------------
#  test_loss = 0.002067715484125074 | test_p_correlation^2 = 0.7383561501242628 ====
#  test_F0_MAE = 0.05318498120084405 +- 0.04395596665309177 Hz | test_Phs_MAE = 0.36554873821139333 +- 0.29345801518743814 Degree ====
# =======================================================================================================================

# %%
# saving MAE
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_F0_ON_MAE.npy', test_F0_MAE)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_Phs_ON_MAE.npy', test_Phs_MAE)

# %%
from scipy.io import savemat, loadmat
data_path = '/media/sail/Elements/JET_CNN/DL-FPC/JETCNNmodel/data/'

Complex_FidsUnAligned_OFF=Complex_FidsUnAligned[18000:20000,:]
print(Complex_FidsUnAligned_OFF.shape)

time = np.arange(2048)/2000
Complex_FidsUnAligned_OFF=np.transpose(Complex_FidsUnAligned_OFF)

# Perform Frequency Correction
FidsUnAlignedOFFPhase = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)
spectUnAlignedOFFPhase = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)

for kk in range(2000):
    freqPart = np.exp(1j * time * prediction_F0_OFF[kk] * 2 * cm.pi)
    FidsUnAlignedOFFPhase[:,kk] = np.multiply(Complex_FidsUnAligned_OFF[:,kk], freqPart)
    spectUnAlignedOFFPhase[:,kk] = fftshift(fft(FidsUnAlignedOFFPhase[:,kk]))

    scaleOFF = np.max(np.squeeze(np.abs(spectUnAlignedOFFPhase[:,kk])))
    spectUnAlignedOFFPhase[:,kk] = spectUnAlignedOFFPhase[:,kk]/scaleOFF
    
validationDataOFFPhase = np.real(spectUnAlignedOFFPhase[512:-512,:])
validationDataOFFPhase = np.transpose(validationDataOFFPhase)

# Perform Phase Correction
FidsOFFCorrected = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)
spectOFFCorrected = np.empty((len(Complex_FidsUnAligned_OFF[:,0]), len(Complex_FidsUnAligned_OFF[0,:])), dtype = np.complex_)

for kk in range(2000):
    phasePart = np.exp(1j * prediction_Phs_OFF[kk] * cm.pi / 180)
    FidsOFFCorrected[:,kk] = np.multiply(FidsUnAlignedOFFPhase[:,kk], phasePart)
    spectOFFCorrected[:,kk] = fftshift(fft(FidsOFFCorrected[:,kk]))
    
Complex_FidsUnAligned_ON=Complex_FidsUnAligned[38000:40000,:]
time = np.arange(2048)/2000
Complex_FidsUnAligned_ON=np.transpose(Complex_FidsUnAligned_ON)
    
# Perform Frequency Correction
FidsUnAlignedONPhase = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
spectUnAlignedONPhase = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
for kk in range(2000): 
    freqPart = np.exp(1j * time * prediction_F0_ON[kk] * 2 * cm.pi)
    FidsUnAlignedONPhase[:,kk] = np.multiply(Complex_FidsUnAligned_ON[:,kk], freqPart)
    spectUnAlignedONPhase[:,kk] = fftshift(fft(FidsUnAlignedONPhase[:,kk]))

    scaleON = np.max(np.squeeze(np.abs(spectUnAlignedONPhase[:,kk])))
    spectUnAlignedONPhase[:,kk] = spectUnAlignedONPhase[:,kk]/scaleON
    
# Perform Phase Correction
FidsONCorrected = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
spectONCorrected = np.empty((len(Complex_FidsUnAligned_ON[:,0]), len(Complex_FidsUnAligned_ON[0,:])), dtype = np.complex_)
for kk in range(2000):
    phasePart = np.exp(1j * prediction_Phs_ON[kk] * cm.pi / 180)
    FidsONCorrected[:,kk] = np.multiply(FidsUnAlignedONPhase[:,kk], phasePart)
    spectONCorrected[:,kk] = fftshift(fft(FidsONCorrected[:,kk]))
    
#defining ground truths
F0_testON = F0_all[38000:40000]
Phs_testON = Phs_all[38000:40000]
F0_testOFF = F0_all[18000:20000]
Phs_testOFF = Phs_all[18000:20000]

error_F0_OFF = F0_testOFF.numpy()-np.transpose(prediction_F0_OFF)*-1
print("OFF F0: Mean Absolute Error: ", np.mean(np.absolute(error_F0_OFF)), " +- ", np.std(np.absolute(error_F0_OFF)))

error_F0_ON = F0_testON.numpy()-np.transpose(prediction_F0_ON)*-1
print("ON F0: Mean Absolute Error: ", np.mean(np.absolute(error_F0_ON)), " +- ", np.std(np.absolute(error_F0_ON)))

error_Phs_OFF = Phs_testOFF.numpy()-np.transpose(np.array(prediction_Phs_OFF))*-1
print("OFF Phs: Mean Absolute Error: ", np.mean(np.absolute(error_Phs_OFF)), " +- ", np.std(np.absolute(error_Phs_OFF)))

error_Phs_ON = Phs_testON.numpy()-np.transpose(np.array(prediction_Phs_ON))*-1
print("ON Phs: Mean Absolute Error: ", np.mean(np.absolute(error_Phs_ON)), " +- ", np.std(np.absolute(error_Phs_ON)))
# Out:
# (2000, 2048)
# OFF F0: Mean Absolute Error:  0.057804234275128694  +-  0.05033192947495415
# ON F0: Mean Absolute Error:  0.053184981201076884  +-  0.04395596665356698
# OFF Phs: Mean Absolute Error:  0.4157604534216225  +-  0.317465324702367
# ON Phs: Mean Absolute Error:  0.36554873821511863  +-  0.29345801517306025

# %%
# On-Off mismatch

On_F0_error=np.transpose(prediction_F0_ON)*-1-F0_testON.numpy()
Off_F0_error=np.transpose(prediction_F0_OFF)*-1-F0_testOFF.numpy()
ON_OFF_F0_mismatch=abs(On_F0_error-Off_F0_error)
ON_OFF_F0_mismatch_mean=np.mean(ON_OFF_F0_mismatch)
ON_OFF_F0_mismatch_std=np.std(ON_OFF_F0_mismatch)

On_Phs_error=np.transpose(prediction_Phs_ON)*-1-Phs_testON.numpy()
Off_Phs_error=np.transpose(prediction_Phs_OFF)*-1-Phs_testOFF.numpy()
ON_OFF_Phs_mismatch=abs(On_Phs_error-Off_Phs_error)
ON_OFF_Phs_mismatch_mean=np.mean(ON_OFF_Phs_mismatch)
ON_OFF_Phs_mismatch_std=np.std(ON_OFF_Phs_mismatch)

print("ON-OFF F0 mismatch: ", ON_OFF_F0_mismatch_mean, " +- ", ON_OFF_F0_mismatch_std)
print("ON-OFF Phs mismatch: ", ON_OFF_Phs_mismatch_mean, " +- ", ON_OFF_Phs_mismatch_std)

# saving data
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_F0_ON_OFF_Mismatching_MAE.npy', ON_OFF_F0_mismatch)
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_Phs_ON_OFF_Mismatching_MAE.npy', ON_OFF_Phs_mismatch)
# Out:
# ON-OFF F0 mismatch:  0.0804292625465896  +-  0.06526800218085889
# ON-OFF Phs mismatch:  0.5544236147403717  +-  0.4255788983793996

# %%
save_model_figurename1='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Figures/DLSR_refined_wNoise1d5dB_wlb_scatterplot.png'
save_model_figurename2='/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Figures/DLSR_refined_wNoise1d5dB_wlb_DiffSpectra.png'

# defining residual offsets
F0_residual_offset_OFF=F0_testOFF.numpy()-np.transpose(prediction_F0_OFF)*-1
F0_residual_offset_ON=F0_testON.numpy()-np.transpose(prediction_F0_ON)*-1
Phs_residual_offset_OFF=Phs_testOFF.numpy()-np.transpose(prediction_Phs_OFF)*-1
Phs_residual_offset_ON=Phs_testON.numpy()-np.transpose(prediction_Phs_ON)*-1
F0_residual_offset=np.concatenate((F0_residual_offset_OFF,F0_residual_offset_ON),0)
Phs_residual_offset=np.concatenate((Phs_residual_offset_OFF,Phs_residual_offset_ON),0)

Fids_test=Fids[:,np.r_[18000:20000, 38000:40000]]

# Fids and Spec for the Unaligned data
FidsUnAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
FidsUnAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectUnAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectUnAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)

# Aligned spectra
spectAligned = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)
spectAlignedPhase = np.empty((len(Fids_test[:,0]), len(Fids_test[0,:])), dtype = np.complex_)

for kk in range(len(Fids_test[0,:])):
    
    Fids_kk = Fids_test[:,kk]
    
    # get the phase and freq offsets
    phasePart = np.exp(-1j * Phs_residual_offset[kk] * cm.pi / 180)
    freqPart = np.exp(-1j * time * F0_residual_offset[kk] * 2 * cm.pi)
    correction = np.multiply(freqPart,phasePart)
    
    # apply the phase and freq offsets on the FID after LB
    FidsUnAligned[:,kk] = np.multiply(Fids_kk, correction) #[2048, 10000]
    FidsUnAlignedPhase[:,kk] = np.multiply(Fids_kk, phasePart) #[2048, 10000]
    
    # get the single spectra of the FID with freq and phase offsets and LB 
    spectUnAligned[:,kk] = fftshift(fft(FidsUnAligned[:,kk]))
    spectUnAlignedPhase[:,kk] = fftshift(fft(FidsUnAlignedPhase[:,kk]))
    
    # get the single spectra of the FID withOUT freq and phase offsets and LB 
    spectAligned[:,kk] = fftshift(fft(Fids_kk))
    spectAlignedPhase[:,kk] = fftshift(fft(Fids_kk))
    
    # get the Normalized single spectra of the FID with freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectUnAligned[:,kk])))
    spectUnAligned[:,kk] = spectUnAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectUnAlignedPhase[:,kk])))
    spectUnAlignedPhase[:,kk] = spectUnAlignedPhase[:,kk]/scalePh
    
    # get the Normalized single spectra of the FID withOUT freq and phase offsets and LB 
    scale = np.max(np.squeeze(np.abs(spectAligned[:,kk])))
    spectAligned[:,kk] = spectAligned[:,kk]/scale
    scalePh = np.max(np.squeeze(np.abs(spectAlignedPhase[:,kk])))
    spectAlignedPhase[:,kk] = spectAlignedPhase[:,kk]/scalePh


# %% Creating the figures

# scatter plot
fontsize=14

plt.rcParams['axes.linewidth']=2 
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='30'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

fig = plt.figure(figsize=(8.67, 4.4))

ax = plt.subplot(121)   

ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)     
ax.tick_params(width=1,color='k',length=4)
plt.yticks(np.arange(-5,5.1, step=5),['-5','0','5'], fontsize=fontsize)
plt.xticks(np.arange(-20,21,step=20),['-20','0','20'], fontsize=fontsize)
plt.ylabel('DL - True / Hz', fontname="Arial", fontsize=fontsize)
plt.xlabel('True / Hz', fontname="Arial", fontsize=fontsize)
plt.xlim((-20,21))
plt.ylim((-5, 5))
plt.plot(F0_testOFF.numpy(), np.squeeze(np.array(prediction_F0_OFF)*-1) - np.transpose(F0_testOFF.numpy()), 'ko', markersize=1)
plt.plot(F0_testON.numpy(), np.squeeze(np.array(prediction_F0_ON)*-1) - np.transpose(F0_testON.numpy()), 'ko', markersize=1)
plt.title('Frequency Offsets', fontname="Arial", fontsize=18)

t1 = np.mean(np.squeeze(np.array(prediction_F0_OFF)) - np.transpose(F0_testOFF.numpy()))
t2 = np.mean(np.squeeze(np.array(prediction_F0_ON)) - np.transpose(F0_testON.numpy()))
t3 = (t1 + t2)/2
e1 = np.std(np.squeeze(np.array(prediction_F0_OFF)) - np.transpose(F0_testOFF.numpy()))
e2 = np.std(np.squeeze(np.array(prediction_F0_ON)) - np.transpose(F0_testON.numpy()))
e3 = (e1 + e2)/2

rcParams['mathtext.default'] = 'regular'
     
ax = plt.subplot(122)
plt.rcParams['axes.linewidth']=2 
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='30'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)     
ax.tick_params(width=1,color='k',length=4)
plt.yticks(np.arange(-25,25.1,step=25),['-25','0','25'], fontsize=fontsize)
plt.xticks(np.arange(-90,91,step=90),['-90','0','90'], fontsize=fontsize)
plt.ylabel('DL - True /' r' $\degree $', fontname="Arial", fontsize=fontsize)
plt.xlabel('True / ' r'$\degree $', fontname="Arial", fontsize=fontsize)
plt.xlim((-90,91))
plt.ylim((-25, 25))
plt.plot(Phs_testOFF.numpy(), np.squeeze(np.array(prediction_Phs_OFF)*-1) - np.transpose(Phs_testOFF.numpy()), 'ko', markersize=1)
plt.plot(Phs_testON.numpy(), np.squeeze(np.array(prediction_Phs_ON)*-1) - np.transpose(Phs_testON.numpy()), 'ko', markersize=1)
plt.title('Phase Offsets', fontname="Arial", fontsize=18)

t1 = np.mean(np.squeeze(np.array(prediction_Phs_OFF)*-1) - Phs_testOFF.numpy())
t2 = np.mean(np.squeeze(np.array(prediction_Phs_ON)*-1) - Phs_testON.numpy())
t3 = (t1 + t2)/2
e1 = np.std(np.squeeze(np.array(prediction_Phs_OFF)*-1) - Phs_testOFF.numpy())
e2 = np.std(np.squeeze(np.array(prediction_Phs_ON)*-1) - Phs_testON.numpy())
e3 = (e1 + e2)/2
plt.subplots_adjust(wspace=0.6,left=0.18, right=0.98, top=0.8, bottom=0.25)
plt.savefig(save_model_figurename1,format='png', dpi=300,bbox_inches='tight')  

# plotting diff spectra and residual spectra
freqRange = 2000/127.7
ppm = np.flip((np.arange(1,2048 + 1)) / 2048 * freqRange + 4.68 - freqRange/2)
xlim = [1, 4.2]

plt.rcParams['axes.linewidth']=2
plt.rcParams['lines.linewidth']=2 
plt.rcParams['font.size']='11'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

fig = plt.figure(figsize=(8.67, 4.5))
ax = plt.subplot(111)
ax.spines["top"].set_visible(False)       
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)   
ax.tick_params(width=1,color='k',length=4)
plt.xticks(np.arange(1,5,step=1), fontsize=fontsize)
ax.set_yticklabels([])
ax.axes.get_yaxis().set_visible(False)  

lw = 0.5
spectAlignedOFF=spectAligned[:,:2000]
spectAlignedON=spectAligned[:,2000:]

spectOFFCorrected=spectUnAligned[:,:2000]
spectONCorrected=spectUnAligned[:,2000:]

k=10
spectONCorrected_real_single = spectONCorrected[:,k].real
spectOFFCorrected_real_single = spectOFFCorrected[:,k].real
spectAlignedON_real_single = spectAlignedON[:,k].real
spectAlignedOFF_real_single = spectAlignedOFF[:,k].real

plt.plot(ppm, spectONCorrected_real_single - spectOFFCorrected_real_single - (spectAlignedON_real_single - spectAlignedOFF_real_single) + 0.014,'b',linewidth=0.5)
plt.plot(ppm, spectONCorrected_real_single - spectOFFCorrected_real_single,'r',linewidth=lw)
plt.plot(ppm, spectAlignedON_real_single - spectAlignedOFF_real_single,'k',linewidth=lw)

plt.xlabel('ppm', fontname="Arial", fontsize=fontsize)
plt.xlim((xlim))
plt.gca().invert_xaxis()
plt.ylim((-0.02,0.03))
plt.legend(['CNN-SR+ - True [Single Residual Spetra]','CNN-SR+','True'],loc="lower left")


plt.subplots_adjust(left=0.03, right=0.98, top=0.95,bottom=0.25)
plt.savefig(save_model_figurename2,format='png', dpi=300,bbox_inches='tight')

# %% [markdown]
# #### GABA and GLX residual

# %%
# Diff Spectra
freqRange = 2000/127.7
ppm = np.flip((np.arange(1,2048 + 1)) / 2048 * freqRange + 4.68 - freqRange/2)

GABA_Int = np.where((ppm <= 3.20) & (ppm >= 2.80))
Glx_Int= np.where((ppm >= 3.55) & (ppm <= 3.95))

################ GABA ##############################
spectDiffCorrected = spectONCorrected - spectOFFCorrected 
spectAlignedDiff = spectAlignedON - spectAlignedOFF

spectDiffCorrected_GABA=spectDiffCorrected[GABA_Int[0][0]:GABA_Int[0][-1]]
spectAlignedDiff_GABA=spectAlignedDiff[GABA_Int[0][0]:GABA_Int[0][-1]]

spectDiff_residue_GABA = spectDiffCorrected_GABA - spectAlignedDiff_GABA
spectDiff_residue_MAE_mean_GABA = np.mean(np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
spectDiff_residue_MAE_STD_GABA = np.std(np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
print("GABA Mean Absolute Error: ", spectDiff_residue_MAE_mean_GABA, " +- ", spectDiff_residue_MAE_STD_GABA)

################ Glx ##############################
spectDiffCorrected_Glx=spectDiffCorrected[Glx_Int[0][0]:Glx_Int[0][-1]]
spectAlignedDiff_Glx=spectAlignedDiff[Glx_Int[0][0]:Glx_Int[0][-1]]

spectDiff_residue_Glx = spectDiffCorrected_Glx - spectAlignedDiff_Glx
spectDiff_residue_MAE_mean_Glx = np.mean(np.mean(np.absolute(spectDiff_residue_Glx),axis=0))
spectDiff_residue_MAE_STD_Glx = np.std(np.mean(np.absolute(spectDiff_residue_Glx),axis=0))
print("Glx Mean Absolute Error: ", spectDiff_residue_MAE_mean_Glx, " +- ", spectDiff_residue_MAE_STD_Glx)
# Out:
# GABA Mean Absolute Error:  0.0008372089714050314  +-  0.00045538669057014437
# Glx Mean Absolute Error:  0.0008504522857880234  +-  0.0004426791760333327

# %%
# saving MAE
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_spectra_DIFF_Residual_GABA_MAE.npy', np.mean(np.absolute(spectDiff_residue_GABA),axis=0))
np.save('/media/sail/Elements/JET_CNN/DL-FPC/MRS_SR_DL_scripts/Prediction_data/MAE_data/SR_Refined_1d5dB_wLB_spectra_DIFF_Residual_Glx_MAE.npy', np.mean(np.absolute(spectDiff_residue_Glx),axis=0))
